# %% [markdown]
# # Quantitative Stock Selection

# %%
import yfinance as yf 

import pandas as pd
from matplotlib import pylab as plt
import numpy as np
from datetime import datetime
import math
from time import sleep
import quandl
import seaborn as sns
import sys
from scipy.stats import norm
from sklearn.linear_model import LinearRegression
import sys
import scipy.stats 
import ezodf
import scipy.optimize as sco
import scipy
import re
import os.path
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.8) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %% [markdown]
# ## Functions

# %%
# FUNCTIONS FOR VIEWING SINGLE COMPANY RANKINGS 

def company(company):
    for i in data['Company']:
        if company in i or company in i.lower():
            return data.loc[data['Company'] == i]
    print('No company found')
    
def Company(company):
    for i in data['Company']:
        if company in i or company in i.lower():
            stock = data.loc[data['Company'] == i]
            stock = stock[compact]
            return stock
    print('No company found')

# %%
def mod_Z_score(data):
    mean = np.mean(data.iloc[:-1])
    deviation_from_med = np.array(data.iloc[:-1]) - mean
    MAD = np.mean(np.abs(deviation_from_med))
    mod_Z = (data[-1:] - mean)/(MAD * 1.4826)
    return mod_Z

# %% [markdown]
# ## Data Import and Wrangling

# %%
# IMPORT LATEST DATA 

path_import = "../equity_data/Borsdata_2022-01-30.xlsx"
data_tmp = pd.read_excel(path_import, sheet_name="Export")
data_tmp = data_tmp[1:]

data_tmp = data_tmp.rename({'Performance - Perform. 3m' : 'Return 3m','Performance - Perform. 6m' : 'Return 6m',
                            'Performance - Perform. 1y' : 'Return 1y',
                            'Div. Yield - Current': 'Yield', 
                            'Total Equity  - Millions':'Total Equity', 'FCF - Millions': 'FCF','ROE - Current':'ROE',
                            'Volatility - St.Dev. 100d':'Volatility','Market Cap - Current': 'Market Cap', 
                            'ROC - Current':'ROC', 'Tot. Assets - Millions':'Tot. Assets', 
                            'Gross profit - Millions':'Gross profit', 'Assets Turn - Current': 'Assets Turn',
                            'P/FCF - Current':'P/FCF', 'P/E - Current':'P/E', 'P/S - Current':'P/S',
                            'P/B - Current':'P/B','EV/EBIT - Current':'EV/EBIT',
                            'Info - Country' : 'Country','F-Score - Point':'F-Score',
                            'Info - List' : 'List', 'Info - Sector' : 'Sector', 'Info - Industry' : 'Industry',
                            'Info - Ticker' : 'Tick', 'Info - Yahoo':'Yahoo', 'Info - Last Report': 'Last Report',
                           'Volume - Average 50d Mill' : 'Volume'}, axis=1)

# FORMAT FOR VIEWING PLEASURE
pd.set_option("display.max_rows", None, "display.max_columns", None)
pd.options.display.float_format = "{:,.2f}".format

# %%
# MAKE NUMBERS FLOATS 

data_tmp['Market Cap'] = data_tmp['Market Cap'].replace(',', '') # remove , as 1000 separator

param_list = ['P/E', 'EV/EBIT', 'P/FCF', 'P/S', 'P/B', 'Assets Turn', 'Gross profit', 'Tot. Assets', 'ROC', 'Yield', 'Market Cap', 'Volatility', 'ROC', 'ROE', 'FCF', 'Total Equity', 
        'Return 3m', 'Return 6m', 'Return 1y']

for i in param_list: 
    data_tmp[i] = pd.to_numeric(data_tmp[i]) # make every number numeric


data_tmp['FCFROE'] = data_tmp['FCF']/data_tmp['Total Equity'] # calc FCFROE
data_tmp['GPA'] = data_tmp['Gross profit']/data_tmp['Tot. Assets']

# %%
# Manage negativ equity

data_tmp.loc[(data_tmp['Total Equity'] < 0), ['ROE', 'FCFROE', 'P/B']] = np.nan

# %%
### FILTER DATA FOR VOLUME, LIST AND MARKET CAP

data_tmp = data_tmp.loc[data_tmp['Market Cap'] > 400] #Market cap filter


data_tmp = data_tmp.loc[ (data_tmp['List'] != 'Spotlight') 
                        & (data_tmp['List'] != 'NGM')]

#Volume Filter
data_tmp = data_tmp.loc[data_tmp['Volume'] > 0.5] 

# Set to dattime
data_tmp['Last Report'] = pd.to_datetime(data_tmp['Last Report'])

#set new index
data_tmp.index = range(len(data_tmp.index))

# %%
print("Companies in data: ",len(data_tmp))
print("Missing Report Dates: ",sum(data_tmp['Last Report'].isna()))
# Out:
# Companies in data:  465
# Missing Report Dates:  6

# %%
### Sector
data_tmp.groupby('Sector').mean()['Return 3m']
# Out:
# Sector
# Consumer Durables   -0.02
# Energy               0.03
# Financials          -0.05
# Food and Beverage   -0.14
# Health Care         -0.13
# Industrials         -0.06
# Materials            0.07
# Technology          -0.08
# Telecom              0.01
# Utilities           -0.06
# Name: Return 3m, dtype: float64

# %%
#data_tmp.groupby("Sector")["Return 3m"].transform('mean')

# %%
#data_tmp

# %%
data_tmp.groupby('Sector').size()
# Out:
# Sector
# Consumer Durables    73
# Energy                9
# Financials           88
# Food and Beverage    19
# Health Care          74
# Industrials          96
# Materials            26
# Technology           60
# Telecom               7
# Utilities            13
# dtype: int64

# %% [markdown]
# ## Calculate Price Based Data from Yahoo Finance

# %%
## Get PEAD
data_tmp["EA ret"] = np.nan
data_tmp["EA ret std"] = np.nan
data_tmp['1 Year Volatility'] = np.nan
data_tmp['1 Year MAD'] = np.nan
data_tmp['1 Month Return'] = np.nan
data_tmp['EA Volatility'] = np.nan
data_tmp['Beta'] = np.nan
data_tmp['Res_Mom'] = np.nan


index = yf.download('^OMXSPI',start='2018-01-01', threads = False, progress = False)
index = index['Close']

error_count = 0
error_list = []

# %%
for i in range(len(data_tmp)):
    try:
        stock = yf.download(data_tmp.iloc[i]['Yahoo'],start='2020-01-01', progress = False, threads = False)
        stock = stock['Adj Close']
        import_data = pd.concat([stock, index], axis = 1)
        import_data.columns = ['stock', 'index']
        import_data = import_data.dropna()
        
        # get index of date of report
        idx = import_data.index.get_loc(data_tmp.iloc[i]['Last Report'], method='nearest')
        EA_data = import_data.iloc[idx - 2 : idx +2 ]
        
        stock_idx = stock.index.get_loc(data_tmp.iloc[i]['Last Report'], method='nearest')
        
        EA_ret = (EA_data.pct_change().dropna()+1).cumprod().tail(1)
        pead_ret = float(EA_ret['stock'] - EA_ret['index'])
        data_tmp.loc[i,"EA ret"]= pead_ret
        
        data_tmp.loc[i,"1 Month Return"]= float((stock.pct_change().tail(5).dropna()+1).cumprod().tail(1)) - 1
        
        data_tmp.loc[i, 'EA Volatility'] = np.log(stock.iloc[:idx]/stock.iloc[:idx].shift()).tail(60).std()*252**.5 
        #Get MAD of stock
        data_tmp.loc[i,"1 Year MAD"]= np.log(stock/stock.shift()).tail(252).mad()*252**.5*1.25
        # Get volatility of stock
        data_tmp.loc[i,"1 Year Volatility"]= np.log(stock/stock.shift()).tail(252).std()*252**.5 
        
        
        ### BETA AND RESIDUAL MOMENTUM, USE STATSMODELS INSTEAD??
        long_df = import_data.copy()
        long_df = long_df.resample('m').last()
        ret_df = np.log(long_df/long_df.shift()).dropna()
        reg_df = ret_df.tail(36)
        y = reg_df['stock']
        X = np.array(reg_df['index']).reshape(-1, 1)
        reg = LinearRegression().fit(X, y)
        beta = reg.coef_[0]
        residuals = y - reg.predict(X)
        res_mom = residuals.tail(12).mean()/residuals.tail(12).std()
        data_tmp.loc[i,"Beta"] = beta
        data_tmp.loc[i,"Res_Mom"] = res_mom
       
    except:
        #data_tmp.loc[i,"EA ret"]= np.nan
        #print("ERROR! INDEX: ", i, ', TICKER: ', data_tmp.iloc[i]['Yahoo'])
        error_count = error_count + 1
        error_list.append(i)
# Out:
# 1 Failed download:
# - FLAT-B-ST: No data found, symbol may be delisted
#
# 1 Failed download:
# - SPLTN.ST: No data found, symbol may be delisted
#
# 1 Failed download:
# - SDIP.ST: No data found, symbol may be delisted

# %%
### NA ANALYTICS
print("Amount of Errors: ",error_count )
print("Missing EA rets: ",sum(data_tmp["EA ret"].isna()) )
print("Missing EA volatility: ",sum(data_tmp["EA Volatility"].isna()) )
print("Missing 1 Year volatility: ",sum(data_tmp["1 Year Volatility"].isna()) )
# Out:
# Amount of Errors:  9
# Missing EA rets:  9
# Missing EA volatility:  9
# Missing 1 Year volatility:  9

# %%
## Show errors
data_tmp[data_tmp['EA ret'].isna()][['Company', 'Yahoo', 'Last Report', 'EA ret']]
# Out:
#                    Company           Yahoo Last Report  EA ret
# 19      Aligro Planet SPAC  APAC-SPAC-A.ST         NaT     NaN
# 83               Byggfakta          BFG.ST         NaT     NaN
# 90              Cary Group         CARY.ST         NaT     NaN
# 169           Flat Capital       FLAT-B-ST  2021-10-26     NaN
# 202          Hilbert Group       HILB-B.ST         NaT     NaN
# 226  Investment AB Spiltan        SPLTN.ST  2022-01-28     NaN
# 331                 Pfizer          PFE.ST         NaT     NaN
# 372               Sdiptech         SDIP.ST  2021-10-26     NaN
# 391            Smart Wires   GOGRID-SDB.ST         NaT     NaN

# %% [markdown]
# ### TESTING TICKERS ONCE AGAIN, RE ENTER FAILED TICKERS BY HAND

# %%
##### TESTING TICKERS ONCE AGAIN, RE ENTER FAILED TICKERS BY HAND #####
j = 217
if j != None:
    stock = yf.download(data_tmp.iloc[j]['Yahoo'],start='2018-01-01', progress = False, threads = False)
    stock = stock['Adj Close']
    import_data = pd.concat([stock, index], axis = 1)
    import_data.columns = ['stock', 'index']
    import_data = import_data.dropna()

    # get index of date of report
    idx = import_data.index.get_loc(data_tmp.iloc[j]['Last Report'], method='nearest')
    EA_data = import_data.iloc[idx - 2 : idx +2 ]

    stock_idx = stock.index.get_loc(data_tmp.iloc[j]['Last Report'])

    EA_ret = (EA_data.pct_change().dropna()+1).cumprod().tail(1)
    pead_ret = float(EA_ret['stock'] - EA_ret['index'])
    data_tmp.loc[j,"EA ret"]= pead_ret
    data_tmp.loc[j, 'EA Volatility'] = np.log(stock.iloc[:idx]/stock.iloc[:idx].shift()).tail(60).std()*252**.5 
    #Get MAD of stock
    data_tmp.loc[j,"1 Year MAD"]= np.log(stock/stock.shift()).tail(252).mad()*252**.5*1.25
    # Get volatility of stock
    data_tmp.loc[j,"1 Year Volatility"]= np.log(stock/stock.shift()).tail(252).std()*252**.5 
    
    
    ### BETA AND RESIDUAL MOMENTUM
    long_df = import_data.copy()
    long_df = long_df.resample('m').last()
    ret_df = np.log(long_df/long_df.shift()).dropna()
    reg_df = ret_df.tail(36)
    y = reg_df['stock']
    X = np.array(reg_df['index']).reshape(-1, 1)
    reg = LinearRegression().fit(X, y)
    beta = reg.coef_[0]
    residuals = y - reg.predict(X)
    res_mom = residuals.tail(12).mean()/residuals.tail(12).std()

# %%
data_tmp.sort_values(by='Res_Mom', ascending=False)[['Company', 'EA ret', 'Res_Mom', 'Beta']].head(30)
# Out:
#                      Company  EA ret  Res_Mom  Beta
# 217    InDex Pharmaceuticals    0.07     0.84  1.25
# 70                Björn Borg    0.12     0.70  2.22
# 163            Fastpartner D    0.01     0.63  0.46
# 302                    Nokia   -0.03     0.57  1.02
# 157                   Fabege   -0.03     0.50  0.98
# 316                  Ogunsen   -0.06     0.48  1.73
# 193            Hanza Holding    0.21     0.47  2.16
# 313                   Nyfosa    0.04     0.47  1.84
# 38               AstraZeneca   -0.07     0.46  0.12
# 206           Hufvudstaden A   -0.04     0.46  0.94
# 40          Atrium Ljungberg   -0.03     0.46  0.90
# 420                  Tele2 B   -0.05     0.45  0.35
# 109  Coor Service Management    0.04     0.45  1.85
# 124         Diös Fastigheter    0.01     0.45  1.23
# 49               Balco Group    0.07     0.44  0.54
# 398   Stendörren Fastigheter   -0.01     0.44  1.76
# 47             B3 Consulting    0.12     0.44  0.83
# 445                   Vestum    0.02     0.43  2.71
# 177                     Fuud   -0.07     0.39  1.20
# 312          NP3 Fastigheter    0.07     0.38  2.10
# 160              Fast Balder   -0.02     0.37  1.09
# 102              Clas Ohlson    0.08     0.37  1.45
# 51                  BE Group    0.12     0.36  0.94
# 104                  Cloetta    0.02     0.36  1.25
# 111         Corem Property A   -0.02     0.36  1.17
# 52               Beijer Alma    0.09     0.36  1.60
# 444                Vertiseit    0.18     0.35  1.05
# 100             Cibus Nordic    0.01     0.35  1.22
# 143                Endomines   -0.08     0.34  0.57
# 30               Arion Banki   -0.01     0.34  0.99

# %%
data_tmp[data_tmp['Company'] == 'Poolia']
# Out:
#      Börsdata ID Company     Industry  Volume  P/FCF  Assets Turn  \
# 337          177  Poolia  Outsourcing    2.11  13.96         3.09
#
#      Gross profit  Tot. Assets  ROC  Market Cap  Volatility  ROE   FCF  \
# 337        139.10       574.70 0.56      893.10       44.89 0.29 64.00
#
#      Total Equity  Return 3m  Return 6m  Return 1y Country       List    Tick  \
# 337        180.60       0.23       0.53       2.00  Sweden  Small Cap  POOL B
#
#      EV/EBIT Last Report      Yahoo  Performance - Perform. 1y.1  Yield   P/E  \
# 337    12.64  2021-10-26  POOL-B.ST                         2.00   0.03 16.91
#
#      P/S  P/B  Tot. Assets - Growth 1y Info - Stock price Info - Report  \
# 337 0.50 4.95                     0.21         2022-01-28       Q3-2021
#
#           Sector  FCFROE  GPA  EA ret  EA ret std  1 Year Volatility  \
# 337  Industrials    0.35 0.24    0.05         NaN               0.50
#
#      1 Year MAD  1 Month Return  EA Volatility  Beta  Res_Mom
# 337        0.45           -0.05           0.34  1.83     0.33

# %% [markdown]
# ### Handel NANs

# %%
# MANAGE NaNs and NEGATIVE EARNINGS  
# set nan to min
for i in ['Return 3m', 'Return 6m', 'Return 1y', 'Res_Mom']:
    data_tmp.loc[data_tmp[i].isna() ,i] = data_tmp[i].min()
    
data_tmp.loc[data_tmp['Volatility'].isna(),'Volatility'] = data_tmp['Volatility'].median()

data_tmp.loc[data_tmp['EA ret'].isna(),'EA ret'] = data_tmp['EA ret'].median()
data_tmp.loc[data_tmp['EA Volatility'].isna(),'EA Volatility'] = data_tmp['Volatility'].median()/100

#Impute 100 day volatility for NANs
data_tmp.loc[data_tmp['1 Year Volatility'].isna(),'1 Year Volatility'] = data_tmp.loc[data_tmp['1 Year Volatility'].isna(),'Volatility']/100

#Impute median for NAN MAD
data_tmp.loc[data_tmp['1 Year MAD'].isna(),'1 Year MAD'] = data_tmp['1 Year MAD'].median()

# %%
## Impute EA std and calculate EA STD after everything has been imputed
data_tmp["EA ret std"] = data_tmp["EA ret"]/((data_tmp["EA Volatility"]*np.sqrt(3))/np.sqrt(252))

#Impute median for NAN EA STD
data_tmp.loc[data_tmp['EA ret std'].isna(),'EA ret std'] = data_tmp['EA ret std'].median()

# %%
### SAVE cleaned file into a CSV
save = "NO"
if save == "YES":
    data_date  = re.search(r'\d{4}-\d{2}-\d{2}', path_import)
    folder = 'clean_equity_data'
    exp_file_name = "clean_equity_data_{}".format(data_date.group(0))+ ".csv"
    data_tmp.to_csv(os.path.join(folder, exp_file_name))

# %% [markdown]
# # DATA handling

# %%
####### FILTER DATA FOR SUB STRATEGIES
data_full = data_tmp.copy()
### MOMENTUM
data_mom = data_tmp.copy()
data_mom = data_mom.loc[(data_mom['Industry'] != 'Holding Companies')]
#data_mom = data_tmp.loc[(data_tmp['Sector'] != 'Financials')]

data = data_tmp.copy()
### GESTALT
data = data.loc[(data_tmp['Sector'] != 'Financials')]

# %% [markdown]
# ## MOMENTUM

# %%
# RANK ON DIFFERENT METRICS 

data_mom['3m Rank'] = data_mom['Return 3m'].rank(ascending = False)
data_mom['6m Rank'] = data_mom['Return 6m'].rank(ascending = False)
data_mom['1y Rank'] = data_mom['Return 1y'].rank(ascending = False)
data_mom['1y Res Mom Rank'] = data_mom['Res_Mom'].rank(ascending = False)


data_mom['EA Rank'] = data_mom['EA ret'].rank(ascending = False)
data_mom['EA Std Rank'] = data_mom['EA ret std'].rank(ascending = False)
data_mom['Volatility Rank'] = data_mom['1 Year Volatility'].rank(ascending = True)
data_mom['MAD Rank'] = data_mom['1 Year Volatility'].rank(ascending = True)

# MOMENTUM WITH VOLATILITY
#data_mom['Momentum Rank'] = (data_mom['Return 3m'].rank(ascending = False) + data_mom['Return 6m'].rank(ascending = False) + 
#                              data_mom['Return 1y'].rank(ascending = False) + data_mom['Volatility'].rank(ascending = True)).rank(ascending = True)

# PURE MOMENTUM
#data_mom['Momentum Rank'] = (data_mom['Return 3m'].rank(ascending = False) + data_mom['Return 6m'].rank(ascending = False) + 
#                              data_mom['Return 1y'].rank(ascending = False)).rank(ascending = True)

# MOMENTUM WITH WOLATILITY AND EA
data_mom['Momentum Rank'] = (data_mom['3m Rank'] + data_mom['6m Rank'] +  data_mom['1y Rank'] + data_mom['Volatility Rank'] + data_mom['EA Std Rank']).rank(ascending = True)

# %% [markdown]
# ## GESTALT

# %%
# MANAGE NaNs and NEGATIVE EARNINGS  

# set nan to median, only fundamental data
columns = ['P/E', 'EV/EBIT', 'P/FCF', 'P/S', 'P/B', 'ROC', 'ROE',
            'GPA', 'Assets Turn', 'FCFROE']
for i in columns: 
    data.loc[data[i].isna() ,i] = data[i].median()

# set nan to min
#for i in ['Return 3m', 'Return 6m', 'Return 1y']:
#    data.loc[data[i].isna() ,i] = data[i].min()
    
# set negative values to max
for i in ['P/E', 'EV/EBIT', 'P/FCF', 'P/S', 'P/B']:
    data.loc[data[i] < 0 ,i] = data[i].max()
    
# set nan yield & vol to 0
data.loc[data['Yield'].isna(),'Yield'] = 0

# %%
#data_mom.isna().sum()

# %% [markdown]
# ### Test

# %%
#data['1m Rank'] = data['1 Month Return'].rank(ascending = True,pct=True) #high rank means high return
#data['Sector Rank'] = data['Sector Mom'].rank(ascending = False,pct=True) # Low rank means high return

#comb rank, high is good

#low means strong sector, weak stocks = buy
#data['High Freq Combo'] = (data['1m Rank'] + data['Sector Rank']).rank(ascending = False,pct=True)

# %% [markdown]
# ## Rankings and Sorting

# %%
# RANK ON DIFFERENT METRICS 


data['3m Rank'] = data['Return 3m'].rank(ascending = False)
data['6m Rank'] = data['Return 6m'].rank(ascending = False)
data['1y Rank'] = data['Return 1y'].rank(ascending = False)
data['EA Rank'] = data['EA ret'].rank(ascending = False)
data['EA Std Rank'] = data['EA ret std'].rank(ascending = False)


data['Momentum Rank'] = (data['3m Rank'] + data['6m Rank'] + data['1y Rank'] + data['EA Std Rank']).rank(ascending = True)

#data['Momentum'] = (data['Return 3m'] + data['Return 6m'] + data['Return 1y'])

# Ranking where lower value is better
for i in ['P/E', 'P/B', 'P/S', 'P/FCF', 'EV/EBIT']:
    data[i +' Rank'] = data[i].rank()
    
# Ranking where higher value is better
#for i in ['Yield', 'ROE', 'ROC', 'FCFROE', 'Momentum', 'GPA', 'Assets Turn']:
for i in ['Yield', 'ROE', 'ROC', 'FCFROE', 'GPA', 'Assets Turn']:
    data[i + ' Rank'] = (-data[i]).rank()
    
# Composite ranks
data['Quality Rank'] = (data['ROE Rank'] + data['ROC Rank'] + data['FCFROE Rank'] + 
                        data['GPA Rank'] + data['Assets Turn Rank']).rank()
data['Value Rank'] = (data['P/E Rank'] + data['P/B Rank'] + data['P/S Rank'] + data['P/FCF Rank'] + 
                      data['EV/EBIT Rank'] + data['Yield Rank']).rank()
 
data['Magic Formula'] = (data['ROC Rank'] + data['EV/EBIT Rank']).rank()
data['Siegfrieds'] = (data['ROC Rank'] + data['P/B Rank']).rank()
data['Triple Sort'] = ((data['Value Rank'] + data['Momentum Rank'] + data['Quality Rank'])).rank()
data['Double Sort'] = (data['Value Rank'] + data['Quality Rank']).rank()

# %%
# SORTING 

# number of stocks to choose before momentum screen
trend_screen = 40
double_sort_break_off = 40

value_tmp = data.sort_values(by=['Value Rank'])
quality_tmp = data.sort_values(by=['Quality Rank'])
#### MOMENTUM DATA FRAME
momentum_tmp = data_mom.sort_values(by=['Momentum Rank'])


trending_value_tmp = value_tmp[0:trend_screen]
trending_value_tmp = trending_value_tmp.sort_values(by='Momentum Rank')
trending_quality_tmp = quality_tmp[0:trend_screen]
trending_quality_tmp = trending_quality_tmp.sort_values(by='Momentum Rank')
magic_formula_tmp = data.sort_values(by=['Magic Formula'])
siegfrieds_tmp = data.sort_values(by=['Siegfrieds'])
triple_sort_tmp = data.sort_values(by=['Triple Sort'])
double_sort = data.sort_values(by=['Double Sort'])
double_sort_mom_tmp = double_sort[0:double_sort_break_off]
double_sort_mom = double_sort_mom_tmp.sort_values(by=['Momentum Rank'])

# %%
# FACTOR STRATEGIES 

compact = ['Company', 'List','Tick', 'Quality Rank', 'Value Rank', 'Momentum Rank', 'EA Std Rank', '1 Year Volatility', 'Res_Mom']
compact_mom = ['Company', 'List','Tick', 'Momentum Rank','Volatility Rank','EA Std Rank', '1 Year Volatility', 'Res_Mom']

# numbers of stocks to select for diff strategies

stocks = 20
magic_formula_stocks = 10
siegfried_stocks = 10
triple_sort_stocks = 20
double_sort_mom_stocks = 10

## VALUE ## 
value = value_tmp[0:stocks]
Value = value[compact]

## QUALITY ## 
quality = quality_tmp[0:stocks]
Quality = quality[compact]

## MOMENTUM ##
momentum = momentum_tmp[0:stocks]
Momentum = momentum[compact_mom]

## TRENDING VALUE ##
trending_value = trending_value_tmp[0:stocks]
Trending_Value = trending_value[compact]

## TRENDING QUALITY ##
trending_quality = trending_quality_tmp[0:stocks]
Trending_Quality = trending_quality[compact]

## MAGIC FORMULA ##
magic_formula = magic_formula_tmp[0:magic_formula_stocks]
Magic_Formula = magic_formula[compact]

## SIEGFRIEDS ##
siegfrieds = siegfrieds_tmp[0:siegfried_stocks]
Siegfrieds = siegfrieds[compact]

## TRIPLE SORT ##
triple_sort = triple_sort_tmp[0:triple_sort_stocks]
Triple_Sort = triple_sort[compact]

## DOUBLE SORT + Momentum ##
double_sort_mom = double_sort_mom[0:double_sort_mom_stocks]
Double_Sort_Mom = double_sort_mom[compact]

# %%
company('Samhallsbyggnadsbolag B')
# Out:
# No company found

# %% [markdown]
# ## Print Stock Selection

# %%
#Triple_Sort 
th_props = [
  ('font-size', '14px'),
  ('text-align', 'center'),
  ('font-weight', 'bold'),
  ('color', 'Black'),
  ('background-color', '#f7f7f9')
  ]
# Set CSS properties for td elements in dataframe
td_props = [('font-size', '12px'), ('text-align', 'center')]
#set caption props
caption_props = [('color', 'black'),('font-size', '22px'),
        ("text-align", "center"),
        ('font-weight', 'bold')]
# Set table styles
styles = [
    dict(selector="th", props=th_props),
    dict(selector="td", props=td_props),
    dict(selector="caption", props=caption_props)
]
Triple_Sort.index = range(1, len(Triple_Sort)+1)
Triple_Sort_view = (Triple_Sort.style.apply(lambda x: ['background: lightgreen' if x.name in range(1, 10+1) 
                              else '' for i in x], axis=1).set_table_styles(styles)
                 .format({'1 Year Volatility': "{:.1%}"})
                 .set_caption("Gestalt"))
Triple_Sort_view
# Out:
# <style type="text/css">
# #T_b9d1a_ th {
#   font-size: 14px;
#   text-align: center;
#   font-weight: bold;
#   color: Black;
#   background-color: #f7f7f9;
# }
# #T_b9d1a_ td {
#   font-size: 12px;
#   text-align: center;
# }
# #T_b9d1a_ caption {
#   color: black;
#   font-size: 22px;
#   text-align: center;
#   font-weight: bold;
# }
# #T_b9d1a_row0_col0, #T_b9d1a_row0_col1, #T_b9d1a_row0_col2, #T_b9d1a_row0_col3, #T_b9d1a_row0_col4, #T_b9d1a_row0_col5, #T_b9d1a_row0_col6, #T_b9d1a_row0_col7, #T_b9d1a_row0_col8, #T_b9d1a_row1_col0, #T_b9d1a_row1_col1, #T_b9d1a_row1_col2, #T_b9d1a_row1_col3, #T_b9d1a_row1_col4, #T_b9d1a_row1_col5, #T_b9d1a_row1_col6, #T_b9d1a_row1_col7, #T_b9d1a_row1_col8, #T_b9d1a_row2_col0, #T_b9d1a_row2_col1, #T_b9d1a_row2_col2, #T_b9d1a_row2_col3, #T_b9d1a_row2_col4, #T_b9d1a_row2_col5, #T_b9d1a_row2_col6, #T_b9d1a_row2_col7, #T_b9d1a_row2_col8, #T_b9d1a_row3_col0, #T_b9d1a_row3_col1, #T_b9d1a_row3_col2, #T_b9d1a_row3_col3, #T_b9d1a_row3_col4, #T_b9d1a_row3_col5, #T_b9d1a_row3_col6, #T_b9d1a_row3_col7, #T_b9d1a_row3_col8, #T_b9d1a_row4_col0, #T_b9d1a_row4_col1, #T_b9d1a_row4_col2, #T_b9d1a_row4_col3, #T_b9d1a_row4_col4, #T_b9d1a_row4_col5, #T_b9d1a_row4_col6, #T_b9d1a_row4_col7, #T_b9d1a_row4_col8, #T_b9d1a_row5_col0, #T_b9d1a_row5_col1, #T_b9d1a_row5_col2, #T_b9d1a_row5_col3, #T_b9d1a_row5_col4, #T_b9d1a_row5_col5, #T_b9d1a_row5_col6, #T_b9d1a_row5_col7, #T_b9d1a_row5_col8, #T_b9d1a_row6_col0, #T_b9d1a_row6_col1, #T_b9d1a_row6_col2, #T_b9d1a_row6_col3, #T_b9d1a_row6_col4, #T_b9d1a_row6_col5, #T_b9d1a_row6_col6, #T_b9d1a_row6_col7, #T_b9d1a_row6_col8, #T_b9d1a_row7_col0, #T_b9d1a_row7_col1, #T_b9d1a_row7_col2, #T_b9d1a_row7_col3, #T_b9d1a_row7_col4, #T_b9d1a_row7_col5, #T_b9d1a_row7_col6, #T_b9d1a_row7_col7, #T_b9d1a_row7_col8, #T_b9d1a_row8_col0, #T_b9d1a_row8_col1, #T_b9d1a_row8_col2, #T_b9d1a_row8_col3, #T_b9d1a_row8_col4, #T_b9d1a_row8_col5, #T_b9d1a_row8_col6, #T_b9d1a_row8_col7, #T_b9d1a_row8_col8, #T_b9d1a_row9_col0, #T_b9d1a_row9_col1, #T_b9d1a_row9_col2, #T_b9d1a_row9_col3, #T_b9d1a_row9_col4, #T_b9d1a_row9_col5, #T_b9d1a_row9_col6, #T_b9d1a_row9_col7, #T_b9d1a_row9_col8 {
#   background: lightgreen;
# }
# </style>
# <table id="T_b9d1a_">
#   <caption>Gestalt</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Company</th>
#       <th class="col_heading level0 col1" >List</th>
#       <th class="col_heading level0 col2" >Tick</th>
#       <th class="col_heading level0 col3" >Quality Rank</th>
#       <th class="col_heading level0 col4" >Value Rank</th>
#       <th class="col_heading level0 col5" >Momentum Rank</th>
#       <th class="col_heading level0 col6" >EA Std Rank</th>
#       <th class="col_heading level0 col7" >1 Year Volatility</th>
#       <th class="col_heading level0 col8" >Res_Mom</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b9d1a_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_b9d1a_row0_col0" class="data row0 col0" >BE Group</td>
#       <td id="T_b9d1a_row0_col1" class="data row0 col1" >Small Cap</td>
#       <td id="T_b9d1a_row0_col2" class="data row0 col2" >BEGR</td>
#       <td id="T_b9d1a_row0_col3" class="data row0 col3" >42.000000</td>
#       <td id="T_b9d1a_row0_col4" class="data row0 col4" >5.000000</td>
#       <td id="T_b9d1a_row0_col5" class="data row0 col5" >6.000000</td>
#       <td id="T_b9d1a_row0_col6" class="data row0 col6" >40.000000</td>
#       <td id="T_b9d1a_row0_col7" class="data row0 col7" >52.6%</td>
#       <td id="T_b9d1a_row0_col8" class="data row0 col8" >0.358742</td>
#     </tr>
#     <tr>
#       <th id="T_b9d1a_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_b9d1a_row1_col0" class="data row1 col0" >Clas Ohlson</td>
#       <td id="T_b9d1a_row1_col1" class="data row1 col1" >Mid Cap</td>
#       <td id="T_b9d1a_row1_col2" class="data row1 col2" >CLAS B</td>
#       <td id="T_b9d1a_row1_col3" class="data row1 col3" >22.000000</td>
#       <td id="T_b9d1a_row1_col4" class="data row1 col4" >36.000000</td>
#       <td id="T_b9d1a_row1_col5" class="data row1 col5" >15.000000</td>
#       <td id="T_b9d1a_row1_col6" class="data row1 col6" >23.000000</td>
#       <td id="T_b9d1a_row1_col7" class="data row1 col7" >34.7%</td>
#       <td id="T_b9d1a_row1_col8" class="data row1 col8" >0.365674</td>
#     </tr>
#     <tr>
#       <th id="T_b9d1a_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_b9d1a_row2_col0" class="data row2 col0" >Björn Borg</td>
#       <td id="T_b9d1a_row2_col1" class="data row2 col1" >Small Cap</td>
#       <td id="T_b9d1a_row2_col2" class="data row2 col2" >BORG</td>
#       <td id="T_b9d1a_row2_col3" class="data row2 col3" >26.000000</td>
#       <td id="T_b9d1a_row2_col4" class="data row2 col4" >44.000000</td>
#       <td id="T_b9d1a_row2_col5" class="data row2 col5" >9.000000</td>
#       <td id="T_b9d1a_row2_col6" class="data row2 col6" >22.000000</td>
#       <td id="T_b9d1a_row2_col7" class="data row2 col7" >40.5%</td>
#       <td id="T_b9d1a_row2_col8" class="data row2 col8" >0.702133</td>
#     </tr>
#     <tr>
#       <th id="T_b9d1a_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_b9d1a_row3_col0" class="data row3 col0" >Nilörngruppen</td>
#       <td id="T_b9d1a_row3_col1" class="data row3 col1" >Small Cap</td>
#       <td id="T_b9d1a_row3_col2" class="data row3 col2" >NIL B</td>
#       <td id="T_b9d1a_row3_col3" class="data row3 col3" >13.000000</td>
#       <td id="T_b9d1a_row3_col4" class="data row3 col4" >42.000000</td>
#       <td id="T_b9d1a_row3_col5" class="data row3 col5" >29.000000</td>
#       <td id="T_b9d1a_row3_col6" class="data row3 col6" >9.000000</td>
#       <td id="T_b9d1a_row3_col7" class="data row3 col7" >41.2%</td>
#       <td id="T_b9d1a_row3_col8" class="data row3 col8" >0.231387</td>
#     </tr>
#     <tr>
#       <th id="T_b9d1a_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_b9d1a_row4_col0" class="data row4 col0" >Poolia</td>
#       <td id="T_b9d1a_row4_col1" class="data row4 col1" >Small Cap</td>
#       <td id="T_b9d1a_row4_col2" class="data row4 col2" >POOL B</td>
#       <td id="T_b9d1a_row4_col3" class="data row4 col3" >25.000000</td>
#       <td id="T_b9d1a_row4_col4" class="data row4 col4" >50.000000</td>
#       <td id="T_b9d1a_row4_col5" class="data row4 col5" >11.000000</td>
#       <td id="T_b9d1a_row4_col6" class="data row4 col6" >87.000000</td>
#       <td id="T_b9d1a_row4_col7" class="data row4 col7" >50.4%</td>
#       <td id="T_b9d1a_row4_col8" class="data row4 col8" >0.327802</td>
#     </tr>
#     <tr>
#       <th id="T_b9d1a_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_b9d1a_row5_col0" class="data row5 col0" >Electra Gruppen</td>
#       <td id="T_b9d1a_row5_col1" class="data row5 col1" >Small Cap</td>
#       <td id="T_b9d1a_row5_col2" class="data row5 col2" >ELEC</td>
#       <td id="T_b9d1a_row5_col3" class="data row5 col3" >41.000000</td>
#       <td id="T_b9d1a_row5_col4" class="data row5 col4" >6.000000</td>
#       <td id="T_b9d1a_row5_col5" class="data row5 col5" >53.000000</td>
#       <td id="T_b9d1a_row5_col6" class="data row5 col6" >281.000000</td>
#       <td id="T_b9d1a_row5_col7" class="data row5 col7" >42.8%</td>
#       <td id="T_b9d1a_row5_col8" class="data row5 col8" >-0.044961</td>
#     </tr>
#     <tr>
#       <th id="T_b9d1a_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_b9d1a_row6_col0" class="data row6 col0" >Nobina</td>
#       <td id="T_b9d1a_row6_col1" class="data row6 col1" >Mid Cap</td>
#       <td id="T_b9d1a_row6_col2" class="data row6 col2" >NOBINA</td>
#       <td id="T_b9d1a_row6_col3" class="data row6 col3" >20.000000</td>
#       <td id="T_b9d1a_row6_col4" class="data row6 col4" >43.000000</td>
#       <td id="T_b9d1a_row6_col5" class="data row6 col5" >39.000000</td>
#       <td id="T_b9d1a_row6_col6" class="data row6 col6" >225.000000</td>
#       <td id="T_b9d1a_row6_col7" class="data row6 col7" >34.6%</td>
#       <td id="T_b9d1a_row6_col8" class="data row6 col8" >0.335403</td>
#     </tr>
#     <tr>
#       <th id="T_b9d1a_level0_row7" class="row

# %%
th_props = [
  ('font-size', '14px'),
  ('text-align', 'center'),
  ('font-weight', 'bold'),
  ('color', 'Black'),
  ('background-color', '#f7f7f9')
  ]
# Set CSS properties for td elements in dataframe
td_props = [('font-size', '12px'), ('text-align', 'center')]
#set caption props
caption_props = [('color', 'black'),('font-size', '22px'),
        ("text-align", "center"),
        ('font-weight', 'bold')]
# Set table styles
styles = [
    dict(selector="th", props=th_props),
    dict(selector="td", props=td_props),
    dict(selector="caption", props=caption_props)
]
Momentum.index = range(1,len(Momentum)+1)
Momentum_view = (Momentum.style.apply(lambda x: ['background: lightgreen' if x.name in range(1,10+1) 
                              else '' for i in x], axis=1).set_table_styles(styles).format({'1 Year Volatility': "{:.1%}"})
                 .set_caption("Focused Momentum"))
Momentum_view
# Out:
# <style type="text/css">
# #T_849be_ th {
#   font-size: 14px;
#   text-align: center;
#   font-weight: bold;
#   color: Black;
#   background-color: #f7f7f9;
# }
# #T_849be_ td {
#   font-size: 12px;
#   text-align: center;
# }
# #T_849be_ caption {
#   color: black;
#   font-size: 22px;
#   text-align: center;
#   font-weight: bold;
# }
# #T_849be_row0_col0, #T_849be_row0_col1, #T_849be_row0_col2, #T_849be_row0_col3, #T_849be_row0_col4, #T_849be_row0_col5, #T_849be_row0_col6, #T_849be_row0_col7, #T_849be_row1_col0, #T_849be_row1_col1, #T_849be_row1_col2, #T_849be_row1_col3, #T_849be_row1_col4, #T_849be_row1_col5, #T_849be_row1_col6, #T_849be_row1_col7, #T_849be_row2_col0, #T_849be_row2_col1, #T_849be_row2_col2, #T_849be_row2_col3, #T_849be_row2_col4, #T_849be_row2_col5, #T_849be_row2_col6, #T_849be_row2_col7, #T_849be_row3_col0, #T_849be_row3_col1, #T_849be_row3_col2, #T_849be_row3_col3, #T_849be_row3_col4, #T_849be_row3_col5, #T_849be_row3_col6, #T_849be_row3_col7, #T_849be_row4_col0, #T_849be_row4_col1, #T_849be_row4_col2, #T_849be_row4_col3, #T_849be_row4_col4, #T_849be_row4_col5, #T_849be_row4_col6, #T_849be_row4_col7, #T_849be_row5_col0, #T_849be_row5_col1, #T_849be_row5_col2, #T_849be_row5_col3, #T_849be_row5_col4, #T_849be_row5_col5, #T_849be_row5_col6, #T_849be_row5_col7, #T_849be_row6_col0, #T_849be_row6_col1, #T_849be_row6_col2, #T_849be_row6_col3, #T_849be_row6_col4, #T_849be_row6_col5, #T_849be_row6_col6, #T_849be_row6_col7, #T_849be_row7_col0, #T_849be_row7_col1, #T_849be_row7_col2, #T_849be_row7_col3, #T_849be_row7_col4, #T_849be_row7_col5, #T_849be_row7_col6, #T_849be_row7_col7, #T_849be_row8_col0, #T_849be_row8_col1, #T_849be_row8_col2, #T_849be_row8_col3, #T_849be_row8_col4, #T_849be_row8_col5, #T_849be_row8_col6, #T_849be_row8_col7, #T_849be_row9_col0, #T_849be_row9_col1, #T_849be_row9_col2, #T_849be_row9_col3, #T_849be_row9_col4, #T_849be_row9_col5, #T_849be_row9_col6, #T_849be_row9_col7 {
#   background: lightgreen;
# }
# </style>
# <table id="T_849be_">
#   <caption>Focused Momentum</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Company</th>
#       <th class="col_heading level0 col1" >List</th>
#       <th class="col_heading level0 col2" >Tick</th>
#       <th class="col_heading level0 col3" >Momentum Rank</th>
#       <th class="col_heading level0 col4" >Volatility Rank</th>
#       <th class="col_heading level0 col5" >EA Std Rank</th>
#       <th class="col_heading level0 col6" >1 Year Volatility</th>
#       <th class="col_heading level0 col7" >Res_Mom</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_849be_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_849be_row0_col0" class="data row0 col0" >ALM Equity</td>
#       <td id="T_849be_row0_col1" class="data row0 col1" >First North</td>
#       <td id="T_849be_row0_col2" class="data row0 col2" >ALM</td>
#       <td id="T_849be_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_849be_row0_col4" class="data row0 col4" >113.000000</td>
#       <td id="T_849be_row0_col5" class="data row0 col5" >19.000000</td>
#       <td id="T_849be_row0_col6" class="data row0 col6" >32.8%</td>
#       <td id="T_849be_row0_col7" class="data row0 col7" >-0.163841</td>
#     </tr>
#     <tr>
#       <th id="T_849be_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_849be_row1_col0" class="data row1 col0" >Clas Ohlson</td>
#       <td id="T_849be_row1_col1" class="data row1 col1" >Mid Cap</td>
#       <td id="T_849be_row1_col2" class="data row1 col2" >CLAS B</td>
#       <td id="T_849be_row1_col3" class="data row1 col3" >2.000000</td>
#       <td id="T_849be_row1_col4" class="data row1 col4" >129.000000</td>
#       <td id="T_849be_row1_col5" class="data row1 col5" >27.000000</td>
#       <td id="T_849be_row1_col6" class="data row1 col6" >34.7%</td>
#       <td id="T_849be_row1_col7" class="data row1 col7" >0.365674</td>
#     </tr>
#     <tr>
#       <th id="T_849be_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_849be_row2_col0" class="data row2 col0" >Amasten</td>
#       <td id="T_849be_row2_col1" class="data row2 col1" >First North</td>
#       <td id="T_849be_row2_col2" class="data row2 col2" >AMAST</td>
#       <td id="T_849be_row2_col3" class="data row2 col3" >3.000000</td>
#       <td id="T_849be_row2_col4" class="data row2 col4" >38.000000</td>
#       <td id="T_849be_row2_col5" class="data row2 col5" >146.000000</td>
#       <td id="T_849be_row2_col6" class="data row2 col6" >25.5%</td>
#       <td id="T_849be_row2_col7" class="data row2 col7" >0.331725</td>
#     </tr>
#     <tr>
#       <th id="T_849be_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_849be_row3_col0" class="data row3 col0" >Björn Borg</td>
#       <td id="T_849be_row3_col1" class="data row3 col1" >Small Cap</td>
#       <td id="T_849be_row3_col2" class="data row3 col2" >BORG</td>
#       <td id="T_849be_row3_col3" class="data row3 col3" >4.000000</td>
#       <td id="T_849be_row3_col4" class="data row3 col4" >201.000000</td>
#       <td id="T_849be_row3_col5" class="data row3 col5" >26.000000</td>
#       <td id="T_849be_row3_col6" class="data row3 col6" >40.5%</td>
#       <td id="T_849be_row3_col7" class="data row3 col7" >0.702133</td>
#     </tr>
#     <tr>
#       <th id="T_849be_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_849be_row4_col0" class="data row4 col0" >Raketech</td>
#       <td id="T_849be_row4_col1" class="data row4 col1" >First North</td>
#       <td id="T_849be_row4_col2" class="data row4 col2" >RAKE</td>
#       <td id="T_849be_row4_col3" class="data row4 col3" >5.000000</td>
#       <td id="T_849be_row4_col4" class="data row4 col4" >222.000000</td>
#       <td id="T_849be_row4_col5" class="data row4 col5" >6.000000</td>
#       <td id="T_849be_row4_col6" class="data row4 col6" >42.4%</td>
#       <td id="T_849be_row4_col7" class="data row4 col7" >-0.187466</td>
#     </tr>
#     <tr>
#       <th id="T_849be_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_849be_row5_col0" class="data row5 col0" >Awardit</td>
#       <td id="T_849be_row5_col1" class="data row5 col1" >First North</td>
#       <td id="T_849be_row5_col2" class="data row5 col2" >AWRD</td>
#       <td id="T_849be_row5_col3" class="data row5 col3" >6.000000</td>
#       <td id="T_849be_row5_col4" class="data row5 col4" >256.000000</td>
#       <td id="T_849be_row5_col5" class="data row5 col5" >49.000000</td>
#       <td id="T_849be_row5_col6" class="data row5 col6" >46.2%</td>
#       <td id="T_849be_row5_col7" class="data row5 col7" >0.289597</td>
#     </tr>
#     <tr>
#       <th id="T_849be_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_849be_row6_col0" class="data row6 col0" >B3 Consulting</td>
#       <td id="T_849be_row6_col1" class="data row6 col1" >Small Cap</td>
#       <td id="T_849be_row6_col2" class="data row6 col2" >B3</td>
#       <td id="T_849be_row6_col3" class="data row6 col3" >7.000000</td>
#       <td id="T_849be_row6_col4" class="data row6 col4" >226.000000</td>
#       <td id="T_849be_row6_col5" class="data row6 col5" >29.000000</td>
#       <td id="T_849be_row6_col6" class="data row6 col6" >42.8%</td>
#       <td id="T_849be_row6_col7" class="data row6 col7" >0.438238</td>
#     </tr>
#     <tr>
#       <th id="T_849be_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_849be_row7_col0" class="data row7 col0" >Alcadon Group</td>
#       <td id="T_849be_row7_col1" class="data row7 col1" >First North</td>
#       <td id="T_849be_row7_col2" class="data row7 col2" >ALCA</td>
#       <td id="T_849be_row7_col3" class="data row7 col3" >8.500000</td>
#       <td id="T_849be_row7_col4" class="data row7 col4" >243.000000</td>
#       <td id="T_849be_row7_col5" class="data row7 col5" >103.000000</td>
#       <td id="T_849be_row7_col6" class="data row7 col6" >44.8%</td>
#       <td id="T_849be_row7_col7" class="data row7 col7" >0.102590</td>
#     </tr>
#     <tr>
#       <th id="T_849be_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_849be_row8_col0" class="data row8 c

# %%
company('Evolution')
# Out:
#      Börsdata ID    Company            Industry   Volume  P/FCF  Assets Turn  \
# 153          750  Evolution  Gambling & Casinos 1,965.43  55.30         0.24
#
#      Gross profit  Tot. Assets  ROC  Market Cap  Volatility  ROE      FCF  \
# 153      7,798.85    40,927.43 0.18  240,924.30       64.94 0.16 4,356.57
#
#      Total Equity  Return 3m  Return 6m  Return 1y Country       List Tick  \
# 153     32,919.03      -0.21      -0.29       0.33  Sweden  Large Cap  EVO
#
#      EV/EBIT Last Report   Yahoo  Performance - Perform. 1y.1  Yield   P/E  \
# 153    41.53  2021-10-28  EVO.ST                         0.33   0.01 45.38
#
#       P/S  P/B  Tot. Assets - Growth 1y Info - Stock price Info - Report  \
# 153 24.68 7.32                     5.48         2022-01-28       Q3-2021
#
#                 Sector  FCFROE  GPA  EA ret  EA ret std  1 Year Volatility  \
# 153  Consumer Durables    0.13 0.19   -0.09       -2.07               0.57
#
#      1 Year MAD  1 Month Return  EA Volatility  Beta  Res_Mom  3m Rank  \
# 153        0.51           -0.10           0.42  1.04    -0.29   302.00
#
#      6m Rank  1y Rank  EA Rank  EA Std Rank  Momentum Rank  P/E Rank  \
# 153   287.00   104.00   329.00       322.00         297.00    180.00
#
#      P/B Rank  P/S Rank  P/FCF Rank  EV/EBIT Rank  Yield Rank  ROE Rank  \
# 153    291.00    319.00      134.00        203.00      147.00    105.00
#
#      ROC Rank  FCFROE Rank  GPA Rank  Assets Turn Rank  Quality Rank  \
# 153     95.00       104.00    241.00            303.00        173.50
#
#      Value Rank  Magic Formula  Siegfrieds  Triple Sort  Double Sort
# 153      201.00         162.00      217.50       238.00       198.00

# %%
#data.sort_values(by=['Momentum Rank'])

# %% [markdown]
# ## Data Illustartion

# %%
plt.scatter(data['1 Year MAD'],data['1 Year Volatility']);
plt.xlabel('MAD');
plt.ylabel('Vol');

# %%
plt.scatter(data['Volatility']/100,data['1 Year Volatility']);
plt.xlabel('vol 100 dagars');
plt.ylabel('Vol 1år');

# %%
data[['1 Year MAD', '1 Year Volatility']].corr()
# Out:
#                    1 Year MAD  1 Year Volatility
# 1 Year MAD               1.00               0.94
# 1 Year Volatility        0.94               1.00

# %%
data_mom.sort_values(by='1 Year Volatility')[['Company','1 Year MAD', '1 Year Volatility' ]]
# Out:
#                        Company  1 Year MAD  1 Year Volatility
# 19          Aligro Planet SPAC        0.38               0.09
# 163              Fastpartner D        0.08               0.09
# 116              Creaspac SPAC        0.08               0.09
# 112           Corem Property D        0.09               0.11
# 7                ACQ Bure SPAC        0.10               0.12
# 421              Telia Company        0.14               0.15
# 45                      Axfood        0.15               0.16
# 104                    Cloetta        0.16               0.17
# 1                          AAK        0.17               0.18
# 420                    Tele2 B        0.17               0.18
# 152                   Essity B        0.17               0.19
# 410                   Swedbank        0.17               0.19
# 191            Handelsbanken A        0.18               0.19
# 130                   Eastnine        0.18               0.20
# 427                  TietoEVRY        0.19               0.21
# 2                          ABB        0.19               0.21
# 77                   Bredband2        0.19               0.21
# 304                Nordea Bank        0.19               0.21
# 374                      SEB A        0.20               0.22
# 386                    Skanska        0.20               0.22
# 376                  Securitas        0.20               0.22
# 413              Swedish Match        0.20               0.23
# 205                   Holmen B        0.22               0.23
# 289                      NCC B        0.20               0.23
# 206             Hufvudstaden A        0.22               0.23
# 139                      Eltel        0.21               0.23
# 456                   Wästbygg        0.21               0.23
# 37                  Assa Abloy        0.21               0.23
# 38                 AstraZeneca        0.21               0.23
# 367                      SCA B        0.23               0.24
# 329                       Peab        0.22               0.24
# 454                    Volvo B        0.22               0.24
# 440                 Wallenstam        0.25               0.25
# 402               Stora Enso R        0.24               0.25
# 109    Coor Service Management        0.24               0.25
# 91                   Castellum        0.24               0.25
# 40            Atrium Ljungberg        0.24               0.25
# 24                     Amasten        0.21               0.25
# 135               Electrolux B        0.24               0.25
# 280                   Millicom        0.22               0.26
# 360                       Saab        0.22               0.26
# 16                        AFRY        0.24               0.26
# 76                     Bravida        0.25               0.26
# 62             BillerudKorsnäs        0.23               0.26
# 441                  VBG Group        0.25               0.26
# 434                 Trelleborg        0.24               0.26
# 238                         JM        0.25               0.26
# 201                     Hexpol        0.23               0.26
# 157                     Fabege        0.25               0.26
# 381                    Serneke        0.25               0.27
# 39               Atlas Copco A        0.25               0.27
# 93                      Catena        0.26               0.27
# 20                      Alimak        0.25               0.27
# 148                   Epiroc B        0.26               0.27
# 18                  Alfa Laval        0.25               0.27
# 433                     Traton        0.26               0.27
# 42                     Autoliv        0.25               0.27
# 363                    Sandvik        0.26               0.27
# 198                    Hexagon        0.27               0.27
# 33                 Arlandastad        0.25               0.28
# 41                     Attendo        0.25               0.28
# 368            Scandi Standard        0.23               0.28
# 447      Wihlborgs Fastigheter        0.27               0.28
# 197           Hennes & Mauritz        0.27               0.28
# 34      Aros Bostadsutveckling        0.25               0.28
# 160                Fast Balder        0.27               0.28
# 124           Diös Fastigheter        0.28               0.28
# 209                Husqvarna B        0.26               0.29
# 72                    Bonava B        0.27               0.29
# 174                  Fortinova        0.26               0.29
# 239               John Mattson        0.26               0.29
# 429         Torslanda Property        0.26               0.29
# 261                     Loomis        0.26               0.29
# 137                     Elekta        0.26               0.29
# 245                Karo Pharma        0.24               0.29
# 302                      Nokia        0.27               0.29
# 185                    Getinge        0.27               0.29
# 100               Cibus Nordic        0.23               0.29
# 294              Netel Holding        0.30               0.30
# 250                Kjell Group        0.28               0.30
# 125                    Dometic        0.29               0.30
# 151                 Ericsson B        0.24               0.30
# 225                     Intrum        0.26               0.30
# 398     Stendörren Fastigheter        0.29               0.30
# 326                     Pandox        0.29               0.30
# 158                  Fagerhult        0.28               0.30
# 387                      SKF B        0.28               0.30
# 30                 Arion Banki        0.29               0.30
# 416      Svenska Nyttobostäder        0.25               0.30
# 384                 SinterCast        0.26               0.30
# 303                     Nolato        0.29               0.31
# 219                  Indutrade        0.29               0.31
# 425                      Thule        0.28               0.31
# 207                     Humana        0.28               0.31
# 71                     Boliden        0.30               0.31
# 195                       Heba        0.28               0.31
# 186         GHP Specialty Care        0.29               0.31
# 409                    Sweco B        0.27               0.31
# 313                     Nyfosa        0.29               0.31
# 388                    SkiStar        0.29               0.31
# 300                      Nobia        0.27               0.31
# 358                  Rottneros        0.28               0.32
# 335        Platzer Fastigheter        0.30               0.32
# 348                   Railcare        0.25               0.32
# 26         Annehem Fastigheter        0.29               0.32
# 267                       Lyko        0.27               0.32
# 228                     Inwido        0.31               0.32
# 161                   Fastator        0.30               0.32
# 61                       Bilia        0.30               0.32
# 164              Fenix Outdoor        0.31               0.32
# 306               Nordic Paper        0.32               0.33
# 140                 Embellence        0.30               0.33
# 23                  ALM Equity        0.29               0.33
# 159               Fasadgruppen        0.31               0.33
# 107                  Concejo B        0.27               0.33
# 407                   Studsvik        0.29               0.33
# 259                     Lindab        0.29               0.33
# 362    Samhällsbyggnadsbolag B        0.32               0.34
# 128                       Duni        0.29               0.34
# 359                   RugVista        0.31               0.34
# 119                CTT Systems        0.32               0.34
# 244                     Karnov        0.28               0.34
# 154                      eWork        0.31               0.34
# 356             Resurs Holding        0.25               0.34
# 25                       Ambea        0.31               0.34
# 286                   Mycronic        0.30               0.35
# 301                     Nobina        0.23               0.35
# 285                    Munters        0.32               0.35
# 102                Clas Ohlson        0.27               0.35
# 32                        Arjo        0.30               0.35
# 43                 Avanza Bank        0.35               0.35
# 86                 Byggpartner        0.32               0.35
# 309                    Nordnet        0.34               0.35
# 48                  Bactiguard        0.33               0.35
# 217      InDex Pharmaceuticals        0.35               0.35
# 299                     Nimbus        0.32               0.35
# 431             Train Alliance        0.34               0.35
# 316                    Ogunsen        0.29               0.35
# 49                 Balco Group        0.33               0.35
# 27                    AQ Group        0.33               0.35
# 136  Electrolux Professional B        0.34               0.35
# 162              Fastpartner A        0.33               0.36
# 380                    Senzime        0.31               0.36
# 396                     SSAB B        0.35               0.36
# 265                Lundin Gold        0.35               0.36
# 4                   AcadeMedia        0.32               0.36
# 331                     Pfizer        0.38               0.36
# 264              Lundin Energy        0.32               0.36
# 287                   Nanoform        0.32               0.36
# 3            Absolent Air Care        0.33               0.36
# 67                     Biotage        0.34               0.36
# 52                 Beijer Alma        0.34               0.36
# 355                    Rejlers        0.36               0.36
# 65                     BioGaia        0.30               0.36
# 204              Hoist Finance        0.33               0.37
# 54                  Beijer Ref        0.35               0.37
# 277                  Midsona B        0.33               0.37
# 262             Lucara Diamond        0.33               0.37
# 84                     Byggmax        0.34               0.37
# 305     Nordic Entertainment B        0.33               0.37
# 342                  Proact IT        0.32               0.37
# 133                   Elanders        0.34               0.37
# 165                   Ferroamp        0.33               0.37
# 81                      Bulten        0.34               0.37
# 297            NIBE Industrier        0.35               0.37
# 379               Sensys Gatso        0.33               0.37
# 270                     MedCap        0.34               0.38
# 114                      C-RAD        0.35               0.38
# 252                Lagercrantz        0.36               0.38
# 251                     KnowIT        0.34               0.38
# 129               Dustin Group        0.33               0.38
# 255                   LeoVegas        0.34               0.38
# 183            Genova Property        0.36               0.38
# 296             Nexam Chemical        0.36               0.38
# 211              I.A.R Systems        0.32               0.38
# 9                      Addnode        0.33               0.38
# 55            Bergman & Beving        0.37               0.39
# 352     RaySearch Laboratories        0.36               0.39
# 35              Ascelia Pharma        0.37               0.39
# 378                     Semcon        0.35               0.39
# 189                    Gränges        0.33               0.39
# 242                       Kabe        0.35               0.39
# 57                     Betsson        0.35               0.39
# 274                  Mekonomen        0.33               0.39
# 29                Arctic Paper        0.37               0.40
# 144                       Enea        0.37               0.40
# 361                    Sagax A        0.37               0.40
# 223    International Petroleum        0.38               0.40
# 423                 Tethys Oil        0.34               0.40
# 74                       Boozt        0.37               0.40
# 221                   Instalco        0.37               0.40
# 312            NP3 Fastigheter        0.39               0.40
# 229                    Invisio        0.37               0.40
# 341                     Pricer        0.34               0.40
# 273                    Medivir        0.35               0.40
# 92                   Catella B        0.32               0.40
# 120                   Dedicare        0.38               0.40
# 449             Vitec Software        0.38               0.40
# 10                     Addtech        0.37               0.41
# 78         Brinova Fastigheter        0.39               0.41
# 70                  Björn Borg        0.36               0.41
# 340                     Prevas        0.36               0.41
# 392                  Softronic        0.37               0.41
# 15                  Africa Oil        0.38               0.41
# 438                     Unibap        0.34               0.41
# 435                    Trianon        0.39               0.41
# 369             Scandic Hotels        0.39               0.41
# 298              Nilörngruppen        0.34               0.41
# 375                     Sectra        0.39               0.41
# 22                      Alligo        0.38               0.41
# 307       Nordic Waterproofing        0.36               0.41
# 190                     Haldex        0.35               0.42
# 203               HMS Networks        0.39               0.42
# 389                Sleep Cycle        0.39               0.42
# 248                    Kindred        0.39               0.42
# 461                    Zinzino        0.39               0.42
# 99       Christian Berner Tech        0.38               0.42
# 272                  Medicover        0.38               0.42
# 75           Boule Diagnostics        0.37               0.42
# 97                 CellaVision        0.37               0.42
# 88                     Camurus        0.37               0.42
# 349                   Raketech        0.37               0.42
# 241                        K2A        0.40               0.43
# 134            Electra Gruppen        0.35               0.43
# 237                     Jetpak        0.40               0.43
# 47               B3 Consulting        0.40               0.43
# 14               Africa Energy        0.37               0.43
# 80                       Bufab        0.41               0.43
# 291                Nelly Group        0.38               0.43
# 357             Revolutionrace        0.39               0.43
# 108                 Concentric        0.37               0.43
# 399        Stenhus Fastigheter        0.38               0.43
# 90                  Cary Group        0.38               0.43
# 83                   Byggfakta        0.38               0.43
# 235          ITAB Shop Concept        0.40               0.44
# 66                   Bioinvent        0.40               0.44
# 419                  Systemair        0.39               0.44
# 347                    Q-Linea        0.41               0.45
# 414   Swedish Orphan Biovitrum        0.26               0.45
# 236                     I-Tech        0.37               0.45
# 436                Troax Group        0.40               0.45
# 345                   QleanAir        0.42               0.45
# 17               Alcadon Group        0.39               0.45
# 324                        OX2        0.41               0.45
# 295                   New Wave        0.41               0.45
# 320                      Orexo        0.39               0.45
# 131                   Ecoclime        0.40               0.45
# 166                Ferronordic        0.39               0.45
# 173          Formpipe Software        0.40               0.46
# 210                    Hövding        0.35               0.46
# 290                   Nederman        0.43               0.46
# 268            MAG Interactive        0.43               0.46
# 141                   Embracer        0.44               0.46
# 426                 Thunderful        0.43               0.46
# 110                Copperstone        0.41               0.46
# 44                     Awardit        0.42               0.46
# 106                  Collector        0.43               0.46
# 172                FM Mattsson        0.42               0.46
# 59                   BHG Group        0.42               0.47
# 450                  Vitrolife        0.42               0.47
# 336                  Polygiene        0.41               0.47
# 397               Starbreeze B        0.40               0.47
# 31             Arise Windpower        0.44               0.47
# 180                   Gapwaves        0.42               0.47
# 370        Scandinavian Enviro        0.42               0.47
# 327        Paradox Interactive        0.41               0.47
# 216                 Implantica        0.44               0.47
# 330                 Permascand        0.43               0.47
# 424                    TF Bank        0.45               0.47
# 315          OEM International        0.44               0.48
# 460            Xvivo Perfusion        0.46               0.48
# 266              Lundin Mining        0.43               0.48
# 344                    Profoto        0.42               0.48
# 79                   BTS Group        0.38               0.48
# 101                 Cint Group        0.43               0.48
# 311                    Novotek        0.43               0.48
# 111           Corem Property A        0.40               0.48
# 405                      Strax        0.39               0.49
# 269                Maha Energy        0.45               0.49
# 292                       Nepa        0.41               0.49
# 178           G5 Entertainment        0.45               0.49
# 132        Egetis Therapeutics        0.42               0.50
# 36               Aspire Global        0.38               0.50
# 382                   ShaMaran        0.45               0.50
# 281                    Minesto        0.45               0.50
# 53          Beijer Electronics        0.47               0.50
# 343                      Probi        0.44               0.50
# 181                       Garo        0.46               0.50
# 284                      MTG B        0.36               0.50
# 337                     Poolia        0.45               0.50
# 94                Catena Media        0.47               0.51
# 377             Sedana Medical        0.45               0.51
# 328                     Paxman        0.42               0.51
# 0              AAC Clyde Space        0.45               0.51
# 56                Bergs Timber        0.48               0.51
# 439                     Urb-it        0.44               0.51
# 366                   SaveLend        0.44               0.51
# 58           Better Collective        0.46               0.52
# 279               Mildef Group        0.46               0.52
# 240        Josemaria Resources        0.44               0.52
# 310                       NOTE        0.47               0.52
# 323                      Ovzon        0.51               0.53
# 51                    BE Group        0.45               0.53
# 257          Lime Technologies        0.48               0.53
# 432                  Transtema        0.47               0.53
# 276          Micro Systemation        0.46               0.53
# 171                  FluoGuide        0.49               0.53
# 220           Infant Bacterial        0.44               0.53
# 353                 Re:NewCell        0.49               0.53
# 188          Green Landscaping        0.50               0.54
# 147                 Eolus Vind        0.47               0.54
# 260                  LMK Group        0.45               0.54
# 457              XANO Industri        0.52               0.54
# 196                     Hemnet        0.46               0.54
# 187                   GomSpace        0.48               0.55
# 448               Vimian Group        0.54               0.55
# 393             SolTech Energy        0.54               0.55
# 390                  Smart Eye        0.51               0.55
# 325               Pagero Group        0.51               0.55
# 411                  Svedbergs        0.46               0.55
# 232         IRLAB Therapeutics        0.42               0.55
# 271            Media and Games        0.53               0.55
# 365                        SAS        0.48               0.56
# 282                       Mips        0.47               0.56
# 63                   BIMobject        0.47               0.56
# 412                 Swedencare        0.53               0.56
# 314      Oasmia Pharmaceutical        0.47               0.56
# 208               Humble Group        0.52               0.56
# 446              Vicore Pharma        0.46               0.56
# 145                    EnQuest        0.54               0.56
# 156                    Exsitec        0.51               0.56
# 123                     DistIT        0.52               0.57
# 443                    Veoneer        0.29               0.57
# 64                   BioArctic        0.45               0.57
# 199                 Hexatronic        0.50               0.57
# 275                    Mentice        0.53               0.57
# 247             K-Fast Holding        0.51               0.57
# 278                  Midsummer        0.45               0.57
# 143                  Endomines        0.44               0.57
# 333               Pierce Group        0.48               0.57
# 194                Haypp Group        0.52               0.57
# 415           Swedish Stirling        0.50               0.57
# 168          Fingerprint Cards        0.49               0.57
# 153                  Evolution        0.51               0.57
# 231                    Irisity        0.50               0.57
# 321                OrganoClick        0.51               0.58
# 418                     Synsam        0.54               0.58
# 463                      Zwipe        0.54               0.58
# 354                     Readly        0.54               0.58
# 68                     Biovica        0.53               0.58
# 371          Scandion Oncology        0.49               0.59
# 192            Hansa Biopharma        0.52               0.59
# 149            Episurf Medical        0.50               0.59
# 385      Sivers Semiconductors        0.53               0.59
# 334                 PiezoMotor        0.51               0.59
# 21        Alligator Bioscience        0.45               0.59
# 346                      QLife        0.51               0.59
# 215            Impact Coatings        0.55               0.59
# 372                   Sdiptech        0.38               0.60
# 404                   Storytel        0.48               0.60
# 332                 Physitrack        0.57               0.61
# 170             Flexion Mobile        0.56               0.61
# 458           Xbrane Biopharma        0.56               0.61
# 193              Hanza Holding        0.50               0.61
# 391                Smart Wires        0.38               0.61
# 8                      AddLife        0.52               0.62
# 462                     Zordix        0.56               0.62
# 175             Fractal Gaming        0.42               0.62
# 69                   Bio-Works        0.57               0.62
# 243                      Kambi        0.51               0.62
# 444                  Vertiseit        0.54               0.62
# 319      OptiCept Technologies        0.55               0.62
# 422                    Teqnion        0.59               0.63
# 400                 Stillfront        0.55               0.63
# 364                    Saniona        0.56               0.63
# 146                 Enzymatica        0.51               0.63
# 293                Net Insight        0.53               0.63
# 288                 NCAB Group        0.59               0.63
# 5                        Acast        0.57               0.64
# 338                  PowerCell        0.61               0.64
# 408           Surgical Science        0.58               0.64
# 383                      Sinch        0.56               0.65
# 182             Generic Sweden        0.60               0.65
# 200                    Hexicon        0.59               0.66
# 50                    Bambuser        0.62               0.67
# 322           Oscar Properties        0.58               0.67
# 214                  Immunovia        0.58               0.68
# 213                  Immunicum        0.53               0.68
# 60                  BICO Group        0.61               0.69
# 184                    Genovis        0.59               0.69
# 395                SpectrumOne        0.59               0.69
# 455                  Volvo Car        0.66               0.70
# 308         Nordisk Bergteknik        0.63               0.71
# 176                   Fragbite        0.64               0.71
# 6                     Acconeer        0.69               0.71
# 222                   Integrum        0.65               0.72
# 12                    Advenica        0.66               0.73
# 89                   Cantargia        0.64               0.74
# 118                       CTEK        0.68               0.74
# 339         Precise Biometrics        0.44               0.75
# 113              Cortus Energy        0.64               0.76
# 87     Calliditas Therapeutics        0.56               0.76
# 95                        CDON        0.65               0.76
# 126                       Doro        0.36               0.77
# 96                 Cell Impact        0.73               0.78
# 430                      Tourn        0.65               0.78
# 254     Leading Edge Materials        0.74               0.79
# 167                Filo Mining        0.61               0.80
# 105                 CoinShares        0.76               0.80
# 224                  Intervacc        0.56               0.81
# 142              Enad Global 7        0.68               0.82
# 233             Isofol Medical        0.61               0.82
# 230                     Inzile        0.67               0.82
# 122             Diamyd Medical        0.63               0.83
# 73                 Bonesupport        0.48               0.84
# 155         ExpreS2ion Biotech        0.76               0.84
# 138               Elos Medtech        0.68               0.86
# 459              Xspray Pharma        0.50               0.87
# 46                      Azelio        0.70               0.89
# 103                    Climeon        0.74               0.89
# 121                    Desenio        0.59               0.89
# 437                 Truecaller        0.76               0.95
# 179          Gaming Innovation        0.75               0.95
# 394                SpectraCure        0.70               0.97
# 177                       Fuud        0.79               0.97
# 28               Arcane Crypto        0.86               0.97
# 234                ISR Holding        0.80               1.00
# 117                 Crunchfish        0.95               1.07
# 98                 checkin.com        0.79               1.08
# 11            Advanced SolTech        0.92               1.08
# 318       Online Brands Nordic        0.79               1.24
# 406            Studentbostäder        0.45               1.33
# 452                    Vo2 Cap        1.04               1.34
# 283               Misen Energy        1.25               1.49
# 428                      Tobii        0.75               1.62
# 13                    AegirBio        1.41               1.79
# 317               Oncopeptides        1.08               2.07
# 350      Randviken Fastigheter        1.25               5.44

# %%
plt.scatter(momentum_tmp['1y Rank'],momentum_tmp['1y Res Mom Rank']);
plt.xlabel('Momentum Rank');
plt.ylabel('EA Rank');

# %% [markdown]
# #### Correlation heat map between selected Ranks

# %%
#corr = data_mom[['3m Rank', '6m Rank', '1y Rank' , 'Momentum Rank', 'EA Std Rank', 'Volatility Rank']].corr()

corr = data[['Quality Rank', 'Value Rank', 'Momentum Rank', 'EA Std Rank', 'Triple Sort']].corr()

# %%
corr
# Out:
#                Quality Rank  Value Rank  Momentum Rank  EA Std Rank  \
# Quality Rank           1.00        0.72           0.30         0.05
# Value Rank             0.72        1.00           0.26        -0.02
# Momentum Rank          0.30        0.26           1.00         0.55
# EA Std Rank            0.05       -0.02           0.55         1.00
# Triple Sort            0.85        0.84           0.66         0.24
#
#                Triple Sort
# Quality Rank          0.85
# Value Rank            0.84
# Momentum Rank         0.66
# EA Std Rank           0.24
# Triple Sort           1.00

# %% [markdown]
# ## Import data

# %%
#file_name =  "clean_data_2021-11-29.csv"
#folder = "../clean_equity_data/"
#data_tmp = pd.read_csv(folder + file_name)

# %%
momentum_tmp.sort_values(by='Res_Mom', ascending=False)[['Company', 'EA ret std','Res_Mom']].head(40)
# Out:
#                      Company  EA ret std  Res_Mom
# 217    InDex Pharmaceuticals        1.94     0.80
# 70                Björn Borg        3.24     0.70
# 163            Fastpartner D        0.99     0.63
# 302                    Nokia       -1.38     0.58
# 316                  Ogunsen       -2.24     0.51
# 157                   Fabege       -1.05     0.49
# 420                  Tele2 B       -3.16     0.48
# 313                   Nyfosa        1.17     0.47
# 38               AstraZeneca       -2.85     0.46
# 40          Atrium Ljungberg       -1.09     0.46
# 206           Hufvudstaden A       -1.74     0.46
# 109  Coor Service Management        1.61     0.45
# 49               Balco Group        1.77     0.45
# 124         Diös Fastigheter        0.25     0.44
# 47             B3 Consulting        2.91     0.44
# 398   Stendörren Fastigheter       -0.44     0.43
# 193            Hanza Holding        3.96     0.43
# 177                     Fuud       -0.81     0.39
# 160              Fast Balder       -0.59     0.37
# 143                Endomines       -1.33     0.37
# 312          NP3 Fastigheter        1.51     0.37
# 102              Clas Ohlson        3.15     0.37
# 444                Vertiseit        3.43     0.36
# 104                  Cloetta        0.85     0.36
# 51                  BE Group        2.28     0.36
# 111         Corem Property A       -0.42     0.36
# 52               Beijer Alma        2.73     0.35
# 240      Josemaria Resources       -0.62     0.34
# 30               Arion Banki       -0.23     0.34
# 301                   Nobina       -0.47     0.34
# 261                   Loomis        2.87     0.33
# 24                   Amasten        0.65     0.33
# 223  International Petroleum        0.18     0.33
# 138             Elos Medtech        0.58     0.33
# 100             Cibus Nordic        0.32     0.32
# 107                Concejo B        0.02     0.32
# 328                   Paxman       -1.55     0.31
# 53        Beijer Electronics       -0.65     0.31
# 289                    NCC B        1.12     0.31
# 365                      SAS       -1.72     0.30

# %%
data_tmp[['EA ret std', 'Return 3m', 'Return 6m' , 'Return 1y', 'Res_Mom']].corr(method = 'spearman')
# Out:
#             EA ret std  Return 3m  Return 6m  Return 1y  Res_Mom
# EA ret std        1.00       0.21       0.25       0.12     0.15
# Return 3m         0.21       1.00       0.58       0.26     0.31
# Return 6m         0.25       0.58       1.00       0.68     0.46
# Return 1y         0.12       0.26       0.68       1.00     0.44
# Res_Mom           0.15       0.31       0.46       0.44     1.00

# %%
opt = Optimize_Portfolio(data_mom[['EA Std Rank','3m Rank', '6m Rank' ,
                               '1y Rank', '1y Res Mom Rank']], objective = 'Kelly')

opt['x']
# Out:
# array([ 1.00892856e-02,  7.33941458e-03, -5.50093056e-13,  7.53107247e-03,
#         6.44556152e-03])

# %%
####

# %%
import scipy.optimize as sco
import scipy

from sklearn.covariance import LedoitWolf


def Optimize_Portfolio(data ,risk_free = 0, objective = 'Kelly'):
    

    
    
    if objective == 'Kelly':  
        #ret = (data).prod()**(1/len(data)) - 1 #cagr
        ret = (data-1).mean()
        #cov = data.cov().to_numpy()
        cov_fit = LedoitWolf().fit(data)
        cov = cov_fit.covariance_
        
        #need smaller step size
        num_assets = ret.shape[0]
        args = (ret, cov,risk_free)
        constraints = ({'type':'ineq', 'fun': lambda x: x},#all elements greater than one
                      {'type':'ineq', 'fun': lambda x: 1 - np.sum(x)}) # sum <= 1
                      #{'type': 'eq', 'fun': lambda x: np.sum(x) - 1})  
        
        
        result = sco.minimize(kelly_objective, num_assets*[1./num_assets,], args=args, 
                                  method='SLSQP', constraints=constraints, tol = 0.0000000000000000000000001) 
        
    elif objective == 'Sharpe':
        ret = (data-1).mean() 
      
        cov_fit = LedoitWolf().fit(data)
        cov = cov_fit.covariance_
        
        num_assets = ret.shape[0]
        args = (ret, cov,risk_free)
        constraints = ({'type':'ineq', 'fun': lambda x: x},#all elements greater than one
                  #{'type':'ineq', 'fun': lambda x: 1 - np.sum(x)} # sum <= 1
                  {'type': 'eq', 'fun': lambda x: np.sum(x) - 1})  
        result = sco.minimize(sharpe_objective, num_assets*[1./num_assets,], args=args, 
                              method='SLSQP', constraints=constraints, tol = 0.0000000000000000000000001)
    
    elif objective == 'Max Div':
        num_assets = len(data.columns)
        #cov = data.cov().to_numpy()
        
        cov_fit = LedoitWolf().fit(data)
        cov = cov_fit.covariance_
        
        args = (cov)
        constraints = ({'type':'ineq', 'fun': lambda x: x},#all elements greater than one
                  #{'type':'ineq', 'fun': lambda x: 1 - np.sum(x)} # sum <= 1
                  {'type': 'eq', 'fun': lambda x: np.sum(x) - 1}) 
        
        result = sco.minimize(calc_diversification_ratio, num_assets*[1./num_assets,], args=args, 
                              method='SLSQP', constraints=constraints, tol = 0.0000000000000000000000001)
        
    elif objective == "min var":
        num_assets = len(data.columns)
        
        
        cov_fit = LedoitWolf().fit(data)
        cov = cov_fit.covariance_
        
        args = (cov)
        constraints = ({'type':'ineq', 'fun': lambda x: x},#all elements greater than one
                  #{'type':'ineq', 'fun': lambda x: 1 - np.sum(x)} # sum <= 1
                  {'type': 'eq', 'fun': lambda x: np.sum(x) - 1}) 
        
        result = sco.minimize(port_var, num_assets*[1./num_assets,], args=args, 
                              method='SLSQP', constraints=constraints, tol = 0.0000000000000000000000001)
    elif objective == "erc":
        num_assets = len(data.columns)
        #cov = data.cov().to_numpy()
        
        cov_fit = LedoitWolf().fit(data)
        cov = cov_fit.covariance_
        
        args = (cov)
        constraints = ({'type':'ineq', 'fun': lambda x: x},#all elements greater than one
                  #{'type':'ineq', 'fun': lambda x: 1 - np.sum(x)} # sum <= 1
                  {'type': 'eq', 'fun': lambda x: np.sum(x) - 1}) 
        
        result = sco.minimize(erc, num_assets*[1./num_assets,], args=args, 
                              method='SLSQP', constraints=constraints, tol = 0.0000000000000000000000001)
        
        
        
    
    return (result)

def kelly_objective(weights,ret, cov, risk_free = 0):
    
    #kelly_ret = port_ret(weights, ret)
    kelly_ret = port_ret(weights, ret) - port_var(weights, cov)/2
    
    obj = -(kelly_ret)
    
    return(obj)

def sharpe_objective(weights,ret, cov, risk_free = 0):
    ret = port_ret(weights, ret)
    std = port_var(weights, cov)**(1/2)
    
    obj = - (ret/std)
    return(obj)


def port_var(weights, cov):
    var = weights.dot(cov).dot(weights)
    return(var)

def port_ret(weights, ret, risk_free = 0):
    #needs to be array
    ret = ret - risk_free
    port_ret = weights.dot(ret)
    return(port_ret)

def risk_parity(data):
    vol = np.log((data)).std()

    sum_vol = 0
    for i in range(len(vol)):
        sum_vol =sum_vol + (1/vol[i])
    
    weight = []
    for i in range(len(vol)):
        w = (1/vol[i])/(sum_vol)
        weight.append(w)
   
    weight = [round(num, 2) for num in weight]
    return(weight)


def calc_diversification_ratio(weights, cov):
    # average weighted vol
    w_vol = np.dot(np.sqrt(np.diag(cov)), weights.T)
    # portfolio vol
    port_vol = np.sqrt(port_var(weights, cov))
    
    diversification_ratio = w_vol/port_vol
    # return negative for minimization problem (maximize = minimize -)
    return -diversification_ratio

def erc(weights, cov):
        # these are non normalized risk contributions, i.e. not regularized
        # by total risk, seems to help numerically
        risk_contributions = np.dot(weights, cov) * weights
        a = np.reshape(risk_contributions, (len(risk_contributions), 1))
        # broadcasts so you get pairwise differences in risk contributions
        risk_diffs = a - a.transpose()
        sum_risk_diffs_squared = np.sum(np.square(np.ravel(risk_diffs)))
        # https://stackoverflow.com/a/36685019/1451311
        return sum_risk_diffs_squared #/ scale_factorcov
