# %%
import pandas as pd
from matplotlib import pylab as plt
import numpy as np
from datetime import datetime
import math
import seaborn as sns
import sys
import sys
import re
import os.path

# %% [markdown]
# ## data import

# %%
file_name =  "clean_data_2022-02-24.csv"
folder = "../clean_equity_data/"
data_tmp = pd.read_csv(folder + file_name)

# %%
# FUNCTIONS FOR VIEWING SINGLE COMPANY RANKINGS 

def company(company, data):
    for i in data['Company']:
        if company in i or company in i.lower():
            return data.loc[data['Company'] == i]
    print('No company found')
    
def Company(company, data):
    for i in data['Company']:
        if company in i or company in i.lower():
            stock = data.loc[data['Company'] == i]
            stock = stock[compact]
            return stock
    print('No company found')

# %%
### MOMENTUM
data_mom = data_tmp.copy()
#data_mom = data_mom.loc[(data_mom['Industry'] != 'Holding Companies')]


### GESTALT
data_gestalt = data_tmp.copy()
data_gestalt = data_gestalt.loc[(data_tmp['Sector'] != 'Financials')]

# %% [markdown]
# ### Momentum Rank

# %%
# RANK ON DIFFERENT METRICS 

data_mom['3m Rank'] = data_mom['Return 3m'].rank(ascending = False)
data_mom['6m Rank'] = data_mom['Return 6m'].rank(ascending = False)
data_mom['1y Rank'] = data_mom['Return 1y'].rank(ascending = False)
data_mom['EA Rank'] = data_mom['EA ret'].rank(ascending = False)
data_mom['EA Std Rank'] = data_mom['EA ret std'].rank(ascending = False)
data_mom['Volatility Rank'] = data_mom['1 Year Volatility'].rank(ascending = True)
data_mom['MAD Rank'] = data_mom['1 Year Volatility'].rank(ascending = True)

# MOMENTUM WITH WOLATILITY AND EA
data_mom['Momentum Rank'] = (data_mom['3m Rank'] + data_mom['6m Rank'] +  data_mom['1y Rank'] + data_mom['Volatility Rank'] + data_mom['EA Std Rank']).rank(ascending = True)

# %% [markdown]
# ### Gestalt Imputation and Rank

# %%
# MANAGE NaNs and NEGATIVE EARNINGS  

# set nan to median, only fundamental data
columns = ['P/E', 'EV/EBIT', 'P/FCF', 'P/S', 'P/B', 'ROC', 'ROE',
            'GPA', 'Assets Turn', 'FCFROE', 'Asset Growth']
for i in columns: 
    data_gestalt.loc[data_gestalt[i].isna() ,i] = data_gestalt[i].median()


    
# set negative values to max
for i in ['P/E', 'EV/EBIT', 'P/FCF', 'P/S', 'P/B']:
    data_gestalt.loc[data_gestalt[i] < 0 ,i] = data_gestalt[i].max()
    
# set nan yield & vol to 0
data_gestalt.loc[data_gestalt['Yield'].isna(),'Yield'] = 0

# %%
RANK_WEIGHTS = {"Momentum": 1/3, "Value": 1/3, "Quality": 1/3}

print(sum(RANK_WEIGHTS.values()))

data_gestalt['3m Rank'] = data_gestalt['Return 3m'].rank(ascending = False)
data_gestalt['6m Rank'] = data_gestalt['Return 6m'].rank(ascending = False)
data_gestalt['1y Rank'] = data_gestalt['Return 1y'].rank(ascending = False)
data_gestalt['EA Rank'] = data_gestalt['EA ret'].rank(ascending = False)
data_gestalt['EA Std Rank'] = data_gestalt['EA ret std'].rank(ascending = False)


data_gestalt['Momentum Rank'] = (data_gestalt['3m Rank'] + data_gestalt['6m Rank'] + 
                                 data_gestalt['1y Rank'] + data_gestalt['EA Std Rank']).rank(ascending = True)



# Ranking where lower value is better
for i in ['P/E', 'P/B', 'P/S', 'P/FCF', 'EV/EBIT', 'Asset Growth']:
    data_gestalt[i +' Rank'] = data_gestalt[i].rank()
    

for i in ['Yield', 'ROE', 'ROC', 'FCFROE', 'GPA', 'Assets Turn']:
    data_gestalt[i + ' Rank'] = (-data_gestalt[i]).rank()
    
# Composite ranks
data_gestalt['Quality Rank'] = (data_gestalt['ROE Rank'] + data_gestalt['ROC Rank'] + data_gestalt['FCFROE Rank'] + 
                        data_gestalt['GPA Rank'] + data_gestalt['Assets Turn Rank']).rank()

data_gestalt['Value Rank'] = (data_gestalt['P/E Rank'] + data_gestalt['P/B Rank'] + data_gestalt['P/S Rank'] + data_gestalt['P/FCF Rank'] + 
                      data_gestalt['EV/EBIT Rank'] + data_gestalt['Asset Growth Rank']).rank()
 

data_gestalt['Gestalt Rank'] = ((RANK_WEIGHTS['Value']*data_gestalt['Value Rank'] 
                                 + RANK_WEIGHTS['Momentum']*data_gestalt['Momentum Rank'] +
                                RANK_WEIGHTS['Quality']* data_gestalt['Quality Rank'])).rank()
# Out:
# 1.0

# %% [markdown]
# ### Data Error Check

# %%
#data_mom.isna().sum()
data_gestalt.isna().sum()
# Out:
# Unnamed: 0            0
# Börsdata ID           0
# Company               0
# Industry              0
# Volume                0
# P/FCF                 0
# Assets Turn           0
# Gross profit         15
# Tot. Assets           7
# ROC                   0
# Market Cap            0
# Volatility            0
# ROE                   0
# FCF                   7
# Total Equity          7
# Return 3m             0
# Return 6m             0
# Return 1y             0
# Country               0
# List                  0
# Tick                  0
# EV/EBIT               0
# Last Report           7
# Yahoo                 0
# Yield                 0
# P/E                   0
# P/S                   0
# P/B                   0
# Asset Growth          0
# Info - Report         0
# Sector                0
# FCFROE                0
# GPA                   0
# EA ret                0
# EA ret std            0
# 1 Year Volatility     0
# 1 Year MAD            0
# EA Volatility         0
# 3m Rank               0
# 6m Rank               0
# 1y Rank               0
# EA Rank               0
# EA Std Rank           0
# Momentum Rank         0
# P/E Rank              0
# P/B Rank              0
# P/S Rank              0
# P/FCF Rank            0
# EV/EBIT Rank          0
# Asset Growth Rank     0
# Yield Rank            0
# ROE Rank              0
# ROC Rank              0
# FCFROE Rank           0
# GPA Rank              0
# Assets Turn Rank      0
# Quality Rank          0
# Value Rank            0
# Gestalt Rank          0
# dtype: int64

# %% [markdown]
# ### Sorting

# %%
#### MOMENTUM DATA FRAME
momentum_tmp = data_mom.sort_values(by=['Momentum Rank'])
#### Gestalt Data Frame
gestalt_tmp = data_gestalt.sort_values(by=['Gestalt Rank'])

# %%
compact = ['Company', 'List','Tick', 'Gestalt Rank', 'Quality Rank', 'Value Rank', 'Momentum Rank', 'EA ret std', '1 Year Volatility']
compact_mom = ['Company', 'List','Tick','Momentum Rank','EA ret std', '1 Year Volatility']
# numbers of stocks to select for diff strategies

CURRENT_BUYOUTS = ['Aspire Global']


stocks = 30
stocks_mom = 25
## MOMENTUM ##
momentum = momentum_tmp[0:stocks_mom]
Momentum = momentum[compact_mom]


## TRIPLE SORT ##


gestalt=gestalt_tmp[ ~gestalt_tmp['Company'].isin(CURRENT_BUYOUTS)]
gestalt = gestalt[0:stocks]
gestalt = gestalt[compact]

# %% [markdown]
# ### Print Stock Selection

# %%
#gestalt 
th_props = [
  ('font-size', '14px'),
  ('text-align', 'center'),
  ('font-weight', 'bold'),
  ('color', 'Black'),
  ('background-color', '#f7f7f9')
  ]
# Set CSS properties for td elements in dataframe
td_props = [('font-size', '12px'), ('text-align', 'center')]
#set caption props
caption_props = [('color', 'black'),('font-size', '22px'),
        ("text-align", "center"),
        ('font-weight', 'bold')]
# Set table styles
styles = [
    dict(selector="th", props=th_props),
    dict(selector="td", props=td_props),
    dict(selector="caption", props=caption_props)
]
gestalt.index = range(1, len(gestalt)+1)
gestalt_view = (gestalt.style.apply(lambda x: ['background: lightgreen' if x.name in range(1, 15+1) 
                              else '' for i in x], axis=1).set_table_styles(styles)
                 .format({'Gestalt Rank': "{:.0f}",'Quality Rank': "{:.0f}", 'Value Rank': "{:.0f}",
                          'Momentum Rank': "{:.0f}",
                          'EA ret std': "{:.1f}",'1 Year Volatility': "{:.1%}"})
                 .set_caption("Gestalt"))
gestalt_view
# Out:
# <style type="text/css">
# #T_d838a_ th {
#   font-size: 14px;
#   text-align: center;
#   font-weight: bold;
#   color: Black;
#   background-color: #f7f7f9;
# }
# #T_d838a_ td {
#   font-size: 12px;
#   text-align: center;
# }
# #T_d838a_ caption {
#   color: black;
#   font-size: 22px;
#   text-align: center;
#   font-weight: bold;
# }
# #T_d838a_row0_col0, #T_d838a_row0_col1, #T_d838a_row0_col2, #T_d838a_row0_col3, #T_d838a_row0_col4, #T_d838a_row0_col5, #T_d838a_row0_col6, #T_d838a_row0_col7, #T_d838a_row0_col8, #T_d838a_row1_col0, #T_d838a_row1_col1, #T_d838a_row1_col2, #T_d838a_row1_col3, #T_d838a_row1_col4, #T_d838a_row1_col5, #T_d838a_row1_col6, #T_d838a_row1_col7, #T_d838a_row1_col8, #T_d838a_row2_col0, #T_d838a_row2_col1, #T_d838a_row2_col2, #T_d838a_row2_col3, #T_d838a_row2_col4, #T_d838a_row2_col5, #T_d838a_row2_col6, #T_d838a_row2_col7, #T_d838a_row2_col8, #T_d838a_row3_col0, #T_d838a_row3_col1, #T_d838a_row3_col2, #T_d838a_row3_col3, #T_d838a_row3_col4, #T_d838a_row3_col5, #T_d838a_row3_col6, #T_d838a_row3_col7, #T_d838a_row3_col8, #T_d838a_row4_col0, #T_d838a_row4_col1, #T_d838a_row4_col2, #T_d838a_row4_col3, #T_d838a_row4_col4, #T_d838a_row4_col5, #T_d838a_row4_col6, #T_d838a_row4_col7, #T_d838a_row4_col8, #T_d838a_row5_col0, #T_d838a_row5_col1, #T_d838a_row5_col2, #T_d838a_row5_col3, #T_d838a_row5_col4, #T_d838a_row5_col5, #T_d838a_row5_col6, #T_d838a_row5_col7, #T_d838a_row5_col8, #T_d838a_row6_col0, #T_d838a_row6_col1, #T_d838a_row6_col2, #T_d838a_row6_col3, #T_d838a_row6_col4, #T_d838a_row6_col5, #T_d838a_row6_col6, #T_d838a_row6_col7, #T_d838a_row6_col8, #T_d838a_row7_col0, #T_d838a_row7_col1, #T_d838a_row7_col2, #T_d838a_row7_col3, #T_d838a_row7_col4, #T_d838a_row7_col5, #T_d838a_row7_col6, #T_d838a_row7_col7, #T_d838a_row7_col8, #T_d838a_row8_col0, #T_d838a_row8_col1, #T_d838a_row8_col2, #T_d838a_row8_col3, #T_d838a_row8_col4, #T_d838a_row8_col5, #T_d838a_row8_col6, #T_d838a_row8_col7, #T_d838a_row8_col8, #T_d838a_row9_col0, #T_d838a_row9_col1, #T_d838a_row9_col2, #T_d838a_row9_col3, #T_d838a_row9_col4, #T_d838a_row9_col5, #T_d838a_row9_col6, #T_d838a_row9_col7, #T_d838a_row9_col8, #T_d838a_row10_col0, #T_d838a_row10_col1, #T_d838a_row10_col2, #T_d838a_row10_col3, #T_d838a_row10_col4, #T_d838a_row10_col5, #T_d838a_row10_col6, #T_d838a_row10_col7, #T_d838a_row10_col8, #T_d838a_row11_col0, #T_d838a_row11_col1, #T_d838a_row11_col2, #T_d838a_row11_col3, #T_d838a_row11_col4, #T_d838a_row11_col5, #T_d838a_row11_col6, #T_d838a_row11_col7, #T_d838a_row11_col8, #T_d838a_row12_col0, #T_d838a_row12_col1, #T_d838a_row12_col2, #T_d838a_row12_col3, #T_d838a_row12_col4, #T_d838a_row12_col5, #T_d838a_row12_col6, #T_d838a_row12_col7, #T_d838a_row12_col8, #T_d838a_row13_col0, #T_d838a_row13_col1, #T_d838a_row13_col2, #T_d838a_row13_col3, #T_d838a_row13_col4, #T_d838a_row13_col5, #T_d838a_row13_col6, #T_d838a_row13_col7, #T_d838a_row13_col8, #T_d838a_row14_col0, #T_d838a_row14_col1, #T_d838a_row14_col2, #T_d838a_row14_col3, #T_d838a_row14_col4, #T_d838a_row14_col5, #T_d838a_row14_col6, #T_d838a_row14_col7, #T_d838a_row14_col8 {
#   background: lightgreen;
# }
# </style>
# <table id="T_d838a_">
#   <caption>Gestalt</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Company</th>
#       <th class="col_heading level0 col1" >List</th>
#       <th class="col_heading level0 col2" >Tick</th>
#       <th class="col_heading level0 col3" >Gestalt Rank</th>
#       <th class="col_heading level0 col4" >Quality Rank</th>
#       <th class="col_heading level0 col5" >Value Rank</th>
#       <th class="col_heading level0 col6" >Momentum Rank</th>
#       <th class="col_heading level0 col7" >EA ret std</th>
#       <th class="col_heading level0 col8" >1 Year Volatility</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d838a_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_d838a_row0_col0" class="data row0 col0" >BE Group</td>
#       <td id="T_d838a_row0_col1" class="data row0 col1" >Small Cap</td>
#       <td id="T_d838a_row0_col2" class="data row0 col2" >BEGR</td>
#       <td id="T_d838a_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_d838a_row0_col4" class="data row0 col4" >40</td>
#       <td id="T_d838a_row0_col5" class="data row0 col5" >27</td>
#       <td id="T_d838a_row0_col6" class="data row0 col6" >3</td>
#       <td id="T_d838a_row0_col7" class="data row0 col7" >2.3</td>
#       <td id="T_d838a_row0_col8" class="data row0 col8" >52.8%</td>
#     </tr>
#     <tr>
#       <th id="T_d838a_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_d838a_row1_col0" class="data row1 col0" >Poolia</td>
#       <td id="T_d838a_row1_col1" class="data row1 col1" >Small Cap</td>
#       <td id="T_d838a_row1_col2" class="data row1 col2" >POOL B</td>
#       <td id="T_d838a_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_d838a_row1_col4" class="data row1 col4" >17</td>
#       <td id="T_d838a_row1_col5" class="data row1 col5" >46</td>
#       <td id="T_d838a_row1_col6" class="data row1 col6" >17</td>
#       <td id="T_d838a_row1_col7" class="data row1 col7" >0.5</td>
#       <td id="T_d838a_row1_col8" class="data row1 col8" >47.5%</td>
#     </tr>
#     <tr>
#       <th id="T_d838a_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_d838a_row2_col0" class="data row2 col0" >Björn Borg</td>
#       <td id="T_d838a_row2_col1" class="data row2 col1" >Small Cap</td>
#       <td id="T_d838a_row2_col2" class="data row2 col2" >BORG</td>
#       <td id="T_d838a_row2_col3" class="data row2 col3" >3</td>
#       <td id="T_d838a_row2_col4" class="data row2 col4" >22</td>
#       <td id="T_d838a_row2_col5" class="data row2 col5" >49</td>
#       <td id="T_d838a_row2_col6" class="data row2 col6" >14</td>
#       <td id="T_d838a_row2_col7" class="data row2 col7" >3.2</td>
#       <td id="T_d838a_row2_col8" class="data row2 col8" >41.3%</td>
#     </tr>
#     <tr>
#       <th id="T_d838a_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_d838a_row3_col0" class="data row3 col0" >B3 Consulting</td>
#       <td id="T_d838a_row3_col1" class="data row3 col1" >Small Cap</td>
#       <td id="T_d838a_row3_col2" class="data row3 col2" >B3</td>
#       <td id="T_d838a_row3_col3" class="data row3 col3" >4</td>
#       <td id="T_d838a_row3_col4" class="data row3 col4" >15</td>
#       <td id="T_d838a_row3_col5" class="data row3 col5" >71</td>
#       <td id="T_d838a_row3_col6" class="data row3 col6" >1</td>
#       <td id="T_d838a_row3_col7" class="data row3 col7" >4.7</td>
#       <td id="T_d838a_row3_col8" class="data row3 col8" >43.0%</td>
#     </tr>
#     <tr>
#       <th id="T_d838a_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_d838a_row4_col0" class="data row4 col0" >Nilörngruppen</td>
#       <td id="T_d838a_row4_col1" class="data row4 col1" >Small Cap</td>
#       <td id="T_d838a_row4_col2" class="data row4 col2" >NIL B</td>
#       <td id="T_d838a_row4_col3" class="data row4 col3" >6</td>
#       <td id="T_d838a_row4_col4" class="data row4 col4" >9</td>
#       <td id="T_d838a_row4_col5" class="data row4 col5" >76</td>
#       <td id="T_d838a_row4_col6" class="data row4 col6" >7</td>
#       <td id="T_d838a_row4_col7" class="data row4 col7" >1.8</td>
#       <td id="T_d838a_row4_col8" class="data row4 col8" >41.7%</td>
#     </tr>
#     <tr>
#       <th id="T_d838a_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_d838a_row5_col0" class="data row5 col0" >Clas Ohlson</td>
#       <td id="T_d838a_row5_col1" class="data row5 col1" >Mid Cap</td>
#       <td id="T_d838a_row5_col2" class="data row5 col2" >CLAS B</td>
#       <td id="T_d838a_row5_col3" class="data row5 col3" >6</td>
#       <td id="T_d838a_row5_col4" class="data row5 col4" >20</td>
#       <td id="T_d838a_row5_col5" class="data row5 col5" >56</td>
#       <td id="T_d838a_row5_col6" class="data row5 col6" >16</td>
#       <td id="T_d838a_row5_col7" class="data row5 col7" >3.1</td>
#       <td id="T_d838a_row5_col8" class="data row5 col8" >36.1%</td>
#     </tr>
#     <tr>
#       <th id="T_d838a_level0_row6"

# %%
th_props = [
  ('font-size', '14px'),
  ('text-align', 'center'),
  ('font-weight', 'bold'),
  ('color', 'Black'),
  ('background-color', '#f7f7f9')
  ]
# Set CSS properties for td elements in dataframe
td_props = [('font-size', '12px'), ('text-align', 'center')]
#set caption props
caption_props = [('color', 'black'),('font-size', '22px'),
        ("text-align", "center"),
        ('font-weight', 'bold')]
# Set table styles
styles = [
    dict(selector="th", props=th_props),
    dict(selector="td", props=td_props),
    dict(selector="caption", props=caption_props)
]
Momentum.index = range(1,len(Momentum)+1)
Momentum_view = (Momentum.style.apply(lambda x: ['background: lightgreen' if x.name in range(1,10+1) 
                              else '' for i in x], axis=1).set_table_styles(styles).format({'EA ret std': "{:.1f}",'1 Year Volatility': "{:.1%}"})
                 .set_caption("Focused Momentum"))
#Momentum_view

# %% [markdown]
# ## Reversed Ranks

# %%
stocks = 20
## MOMENTUM ##
momentum = momentum_tmp[0:stocks]
Momentum = momentum[compact_mom]


## TRIPLE SORT ##
gestalt = gestalt_tmp[0:stocks]
gestalt = gestalt[compact]

neg_momentum = momentum_tmp.tail(stocks)[::-1][compact_mom]
neg_gestalt = gestalt_tmp.tail(stocks)[::-1][compact]

# %%
neg_momentum
# Out:
#                    Company         List        Tick  Momentum Rank  \
# 85                 Careium  First North        CARE          450.0
# 117                Desenio  First North        DSNO          449.0
# 205              Immunovia      Mid Cap      IMMNOV          448.0
# 91                    CDON  First North        CDON          447.0
# 388             Storskogen    Large Cap      STOR B          446.0
# 114                   CTEK      Mid Cap        CTEK          445.0
# 92             Cell Impact  First North        CI B          444.0
# 367                  Sinch    Large Cap       SINCH          443.0
# 41                  Azelio  First North      AZELIO          442.0
# 369  Sivers Semiconductors      Mid Cap        SIVE          441.0
# 389               Storytel  First North     STORY B          440.0
# 45                Bambuser  First North       BUSER          439.0
# 433           Vimian Group  First North      VIMIAN          438.0
# 10        Advanced SolTech  First North        ASAB          437.0
# 204              Immunicum    Small Cap        IMMU          436.0
# 385             Stillfront    Large Cap          SF          435.0
# 142             Eolus Vind      Mid Cap      EOLU B          434.0
# 118    Devyser Diagnostics  First North       DVYSR          433.0
# 375            Smart Wires  First North  GOGRID SDB          432.0
# 185        Hansa Biopharma      Mid Cap        HNSA          431.0
#
#      EA ret std  1 Year Volatility
# 85    -4.041624           0.611422
# 117   -1.451702           0.894005
# 205   -2.567681           0.686126
# 91    -4.214828           0.763234
# 388   -2.839057           0.607001
# 114   -2.011138           0.735418
# 92    -1.581751           0.785965
# 367   -4.281777           0.644769
# 41    -0.782825           0.900127
# 369   -3.353981           0.589761
# 389   -3.603523           0.604387
# 45    -3.298516           0.674176
# 433   -2.802934           0.550248
# 10    -0.163898           1.102866
# 204   -1.084141           0.687340
# 385   -3.642266           0.630457
# 142   -2.370864           0.545353
# 118   -0.017028           0.701100
# 375   -0.017028           0.799010
# 185   -1.255551           0.589490

# %%
#neg_gestalt
# Out:
#                    Company         List       Tick  Gestalt Rank  \
# 339             Re:NewCell  First North      RENEW         361.0
# 45                Bambuser  First North      BUSER         360.0
# 173               Gapwaves  First North     GAPW B         359.0
# 150     ExpreS2ion Biotech  First North     EXPRS2         358.0
# 369  Sivers Semiconductors      Mid Cap       SIVE         357.0
# 207             Implantica  First North  IMP A SDB         356.0
# 109          Cortus Energy  First North         CE         355.0
# 92             Cell Impact  First North       CI B         354.0
# 185        Hansa Biopharma      Mid Cap       HNSA         353.0
# 113             Crunchfish  First North      CFISH         352.0
# 374              Smart Eye  First North       SEYE         351.0
# 94             checkin.com  First North      CHECK         350.0
# 199           Humble Group  First North     HUMBLE         349.0
# 222                Irisity  First North       IRIS         348.0
# 165              FluoGuide  First North       FLUO         347.0
# 360         Sedana Medical  First North     SEDANA         346.0
# 423                 Urb-it  First North      URBIT         345.0
# 205              Immunovia      Mid Cap     IMMNOV         344.0
# 5                 Acconeer  First North      ACCON         342.5
# 328              PowerCell  First North      PCELL         342.5
#
#      Quality Rank  Value Rank  Momentum Rank  EA ret std  1 Year Volatility
# 339         346.0       353.0          333.0   -1.244330           0.530526
# 45          340.0       323.0          350.0   -3.298516           0.674176
# 173         323.5       351.0          332.0   -1.150851           0.480124
# 150         344.0       354.5          299.0    0.767921           0.850680
# 369         332.5       302.0          357.5   -3.353981           0.589761
# 207         332.5       311.0          342.0   -1.287672           0.477048
# 109         361.0       319.0          303.0   -0.974547           0.760436
# 92          331.0       282.0          352.0   -1.581751           0.785965
# 185         355.0       256.0          346.0   -1.255551           0.589490
# 113         350.0       359.0          246.0   -0.520237           1.073501
# 374         316.0       335.0          300.0   -0.269491           0.551882
# 94          279.5       356.5          314.0    0.588886           1.077593
# 199         328.0       314.0          306.0   -0.818260           0.570008
# 222         293.0       320.0          334.0   -3.640120           0.579895
# 165         273.0       361.0          312.0   -0.123561           0.506425
# 360         301.0       356.5          288.0   -1.570212           0.516947
# 423         357.0       348.0          238.5   -2.609011           0.550723
# 205         351.0       230.5          360.0   -2.567681           0.686126
# 5           327.0       354.5          259.0   -1.725424           0.715269
# 328         308.0       315.5          317.0   -0.680029           0.637839

# %%
save = "YES"
if save == "YES":
    data_date  = re.search(r'\d{4}-\d{2}-\d{2}', file_name)
    folder = '../clean_equity_data'
    exp_file_name = "rank_data_{}".format(data_date.group(0))+ ".csv"
    data_tmp.to_csv(os.path.join(folder, exp_file_name))

# %%
company('Byggma', gestalt_tmp)[compact]
# Out:
#     Company     List  Tick  Gestalt Rank  Quality Rank  Value Rank  \
# 79  Byggmax  Mid Cap  BMAX          49.0          33.0        20.0
#
#     Momentum Rank  EA ret std  1 Year Volatility
# 79          191.0   -1.532103           0.374279

# %%
gestalt_tmp[['Momentum Rank', 'Quality Rank', 'Value Rank', 'Gestalt Rank']].corr(method = 'spearman')
# Out:
#                Momentum Rank  Quality Rank  Value Rank  Gestalt Rank
# Momentum Rank       1.000000      0.388999    0.349949      0.721533
# Quality Rank        0.388999      1.000000    0.639158      0.840646
# Value Rank          0.349949      0.639158    1.000000      0.830110
# Gestalt Rank        0.721533      0.840646    0.830110      1.000000
