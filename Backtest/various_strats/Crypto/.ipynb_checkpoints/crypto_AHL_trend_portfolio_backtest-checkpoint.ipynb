# %%
import yfinance as yf 
import pandas as pd
from matplotlib import pylab as plt
import numpy as np
from datetime import datetime
import seaborn as sns
from scipy.stats import norm
import scipy.optimize as sco
import scipy
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.8) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %% [markdown]
# # Crypto Trend Following
#
# Using the MAN AHL method of combined signal. May try to use different lookbacks and weights in the future.
#
# Sk=(8,16,32) and Lk=(24,48,96).
#
# you need faster MAs than 16 and 32 I belive

# %%
# load help function

# %run crypto_help.ipynb

# %%
dat_tmp = yf.download('BTC-USD')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
dat = dat_tmp['Close']

# %%
def AHL_signal(data, lookback = [4,4,4]):

    short  = data.ewm(span=lookback[0]).mean() - data.ewm(span=4*lookback[0]).mean()
    medium = data.ewm(span=lookback[1]).mean() - data.ewm(span=4*lookback[1]).mean()
    long = data.ewm(span=lookback[2]).mean() - data.ewm(span=4*lookback[2]).mean()

    #vol = dat.pct_change(1).rolling(63).std()
    vol = data.rolling(63).std()

    short_scld = short/vol
    medium_scld = medium/vol
    long_scld = long/vol

    short_norm = short_scld/short_scld.rolling(252).std()
    medium_norm = medium_scld/medium_scld.rolling(252).std()
    long_norm = long_scld/long_scld.rolling(252).std()

    short_sig = (short_norm * np.exp((-short_norm**2)/4))/0.89
    medium_sig = (medium_norm * np.exp((-medium_norm**2)/4))/0.89
    long_sig = (long_norm * np.exp((-long_norm**2)/4))/0.89

    short_sig = short_sig.dropna()
    medium_sig = medium_sig.dropna()
    long_sig = long_sig.dropna()

    comb_signal = (short_sig + medium_sig + long_sig)/3
    
    return(comb_signal)

# %% [markdown]
# ### Backtest of signal for singel currency

# %%
back_dat = pd.concat([AHL_signal(dat), dat], axis=1)
back_dat = back_dat.dropna()
back_dat.columns = ['signal', 'price']

# %%
back_dat.loc[:, 'ret'] = back_dat['price'].pct_change().shift(-1)
back_dat.loc[:,'position'] = np.where(back_dat['signal']>0, 1,0)
back_dat.loc[:,'strategy_ret'] = back_dat['ret']*back_dat['position']
back_dat.loc[:,'strategy_cum'] = (back_dat['strategy_ret']+1).cumprod()
back_dat.loc[:,'bench_cum'] = (back_dat['ret']+1).cumprod()

# %%
plt.plot(back_dat['bench_cum'], label = 'BTC');
plt.plot(back_dat['strategy_cum'], label = 'Strategy');
plt.legend();

# %%
trade_analysis(back_dat['position'])
# Out:
# Number of Trades:  74.0
# Average holding time:  19.0
# Trades per Year:  11.3

# %%
res = back_dat[['strategy_cum', 'bench_cum']].dropna()
strategy_evaluation(res, ['bench_cum'], 3000, freq = 'D')
# Out:
# <style type="text/css">
# #T_903a5_ th {
#   font-size: 20px;
#   text-align: center;
#   font-weight: bold;
#   color: Black;
#   background-color: #f7f7f9;
# }
# #T_903a5_ td {
#   font-size: 20px;
#   text-align: center;
# }
# #T_903a5_row0_col0, #T_903a5_row0_col1, #T_903a5_row0_col2, #T_903a5_row0_col3, #T_903a5_row0_col4, #T_903a5_row0_col5, #T_903a5_row0_col6, #T_903a5_row0_col7, #T_903a5_row1_col8 {
#   background-color: #4ebf8f;
#   color: #f1f1f1;
# }
# #T_903a5_row0_col8, #T_903a5_row1_col0, #T_903a5_row1_col1, #T_903a5_row1_col2, #T_903a5_row1_col3, #T_903a5_row1_col4, #T_903a5_row1_col5, #T_903a5_row1_col6, #T_903a5_row1_col7 {
#   background-color: #f29094;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_903a5_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >CAGR</th>
#       <th class="col_heading level0 col1" >Volatility</th>
#       <th class="col_heading level0 col2" >Sharpe</th>
#       <th class="col_heading level0 col3" >Sortino</th>
#       <th class="col_heading level0 col4" >Max DD</th>
#       <th class="col_heading level0 col5" >MAR</th>
#       <th class="col_heading level0 col6" >SWR</th>
#       <th class="col_heading level0 col7" >Skew</th>
#       <th class="col_heading level0 col8" >Kurtosis</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_903a5_level0_row0" class="row_heading level0 row0" >Portfolio</th>
#       <td id="T_903a5_row0_col0" class="data row0 col0" >71.4%</td>
#       <td id="T_903a5_row0_col1" class="data row0 col1" >43.8%</td>
#       <td id="T_903a5_row0_col2" class="data row0 col2" >1.45</td>
#       <td id="T_903a5_row0_col3" class="data row0 col3" >1.51</td>
#       <td id="T_903a5_row0_col4" class="data row0 col4" >-54%</td>
#       <td id="T_903a5_row0_col5" class="data row0 col5" >1.32</td>
#       <td id="T_903a5_row0_col6" class="data row0 col6" >55.7%</td>
#       <td id="T_903a5_row0_col7" class="data row0 col7" >0.741000</td>
#       <td id="T_903a5_row0_col8" class="data row0 col8" >9.396000</td>
#     </tr>
#     <tr>
#       <th id="T_903a5_level0_row1" class="row_heading level0 row1" >bench_cum</th>
#       <td id="T_903a5_row1_col0" class="data row1 col0" >69.2%</td>
#       <td id="T_903a5_row1_col1" class="data row1 col1" >62.6%</td>
#       <td id="T_903a5_row1_col2" class="data row1 col2" >1.15</td>
#       <td id="T_903a5_row1_col3" class="data row1 col3" >1.40</td>
#       <td id="T_903a5_row1_col4" class="data row1 col4" >-83%</td>
#       <td id="T_903a5_row1_col5" class="data row1 col5" >0.83</td>
#       <td id="T_903a5_row1_col6" class="data row1 col6" >46.8%</td>
#       <td id="T_903a5_row1_col7" class="data row1 col7" >-0.128000</td>
#       <td id="T_903a5_row1_col8" class="data row1 col8" >7.322000</td>
#     </tr>
#   </tbody>
# </table>

# %%
plot(res, "log")

# %% [markdown]
# ### Backtest of several crypto currencies

# %%
tickers = ['ETH-USD', 'BTC-USD', 'DOGE-USD', 'ADA-USD', 'XRP-USD', 'SOL-USD']
#tickers = ['ETH-USD', 'BTC-USD']
df_tick = pd.DataFrame()

# %%
for tick in tickers:
    coin_tmp = yf.download(tick)
    df_tick.loc[:,tick] = coin_tmp['Close']
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
# generate signal 
df_signal = df_tick.apply(AHL_signal, axis = 0)
df_tick_ret = df_tick.pct_change().shift(-1)[:-1]


for col in df_tick_ret.columns:

    
    df_signal[col] = np.where(df_signal[col]>0, 1,0)

# %%
port_ret = np.multiply(df_signal[:-1],df_tick_ret[len(df_tick_ret) - len(df_signal) +1:]).sum(axis =1)
position_df = pd.DataFrame(df_signal[:-1].sum(axis =1))

#port_ret = port_ret.div(df_signal[:-1].sum(axis =1).values)
port_ret = port_ret.div(len(df_signal.columns))

port_ret = pd.DataFrame(port_ret)
port_ret.columns = ['port']
port_ret = port_ret.fillna(0) #fill with zero for no positions held


port_ret = (port_ret+1).cumprod()

bench_port = df_tick_ret[len(df_tick_ret) - len(df_signal) +1:].sum(axis =1)/len(df_tick_ret.columns)
bench_port = pd.DataFrame(bench_port)
bench_port.columns = ['bench']
bench_port = (bench_port+1).cumprod()

multi_df = pd.concat([port_ret,bench_port], axis = 1)

# %%
strategy_evaluation(multi_df, ['bench'], 3000, freq = 'D')
# Out:
# <style type="text/css">
# #T_b7477_ th {
#   font-size: 20px;
#   text-align: center;
#   font-weight: bold;
#   color: Black;
#   background-color: #f7f7f9;
# }
# #T_b7477_ td {
#   font-size: 20px;
#   text-align: center;
# }
# #T_b7477_row0_col0, #T_b7477_row0_col6, #T_b7477_row0_col7, #T_b7477_row1_col1, #T_b7477_row1_col2, #T_b7477_row1_col3, #T_b7477_row1_col4, #T_b7477_row1_col5, #T_b7477_row1_col8 {
#   background-color: #f29094;
#   color: #f1f1f1;
# }
# #T_b7477_row0_col1, #T_b7477_row0_col2, #T_b7477_row0_col3, #T_b7477_row0_col4, #T_b7477_row0_col5, #T_b7477_row0_col8, #T_b7477_row1_col0, #T_b7477_row1_col6, #T_b7477_row1_col7 {
#   background-color: #4ebf8f;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b7477_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >CAGR</th>
#       <th class="col_heading level0 col1" >Volatility</th>
#       <th class="col_heading level0 col2" >Sharpe</th>
#       <th class="col_heading level0 col3" >Sortino</th>
#       <th class="col_heading level0 col4" >Max DD</th>
#       <th class="col_heading level0 col5" >MAR</th>
#       <th class="col_heading level0 col6" >SWR</th>
#       <th class="col_heading level0 col7" >Skew</th>
#       <th class="col_heading level0 col8" >Kurtosis</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b7477_level0_row0" class="row_heading level0 row0" >Portfolio</th>
#       <td id="T_b7477_row0_col0" class="data row0 col0" >94.6%</td>
#       <td id="T_b7477_row0_col1" class="data row0 col1" >41.9%</td>
#       <td id="T_b7477_row0_col2" class="data row0 col2" >1.80</td>
#       <td id="T_b7477_row0_col3" class="data row0 col3" >2.03</td>
#       <td id="T_b7477_row0_col4" class="data row0 col4" >-34%</td>
#       <td id="T_b7477_row0_col5" class="data row0 col5" >2.78</td>
#       <td id="T_b7477_row0_col6" class="data row0 col6" >79.6%</td>
#       <td id="T_b7477_row0_col7" class="data row0 col7" >0.239000</td>
#       <td id="T_b7477_row0_col8" class="data row0 col8" >8.698000</td>
#     </tr>
#     <tr>
#       <th id="T_b7477_level0_row1" class="row_heading level0 row1" >bench</th>
#       <td id="T_b7477_row1_col0" class="data row1 col0" >117.0%</td>
#       <td id="T_b7477_row1_col1" class="data row1 col1" >71.0%</td>
#       <td id="T_b7477_row1_col2" class="data row1 col2" >1.45</td>
#       <td id="T_b7477_row1_col3" class="data row1 col3" >1.87</td>
#       <td id="T_b7477_row1_col4" class="data row1 col4" >-57%</td>
#       <td id="T_b7477_row1_col5" class="data row1 col5" >2.05</td>
#       <td id="T_b7477_row1_col6" class="data row1 col6" >91.6%</td>
#       <td id="T_b7477_row1_col7" class="data row1 col7" >1.931000</td>
#       <td id="T_b7477_row1_col8" class="data row1 col8" >35.615000</td>
#     </tr>
#   </tbody>
# </table>

# %%
plot(multi_df, "log")

# %% [markdown]
# ## LONG/SHORT

# %%
# generate signal 
df_signal_ls = df_tick.apply(AHL_signal, axis = 0)
df_tick_ret = df_tick.pct_change().shift(-1)[:-1]


for col in df_tick_ret.columns:

    
    df_signal_ls[col] = np.where(df_signal_ls[col]>0, 1,-1)

# %%
port_ret_ls = np.multiply(df_signal_ls[:-1],df_tick_ret[len(df_tick_ret) - len(df_signal_ls) +1:]).sum(axis =1)
position_df = pd.DataFrame(df_signal_ls[:-1].sum(axis =1))

port_ret_ls = port_ret_ls.div(len(df_signal_ls.columns))

port_ret_ls = pd.DataFrame(port_ret_ls)
port_ret_ls.columns = ['port']
port_ret_ls = port_ret_ls.fillna(0) #fill with zero for no positions held


port_ret_ls = (port_ret_ls+1).cumprod()

bench_port_ls = df_tick_ret[len(df_tick_ret) - len(df_signal_ls) +1:].sum(axis =1)/len(df_tick_ret.columns)
bench_port_ls = pd.DataFrame(bench_port_ls)
bench_port_ls.columns = ['bench']
bench_port_ls = (bench_port_ls+1).cumprod()

multi_df = pd.concat([port_ret_ls,bench_port_ls], axis = 1)
