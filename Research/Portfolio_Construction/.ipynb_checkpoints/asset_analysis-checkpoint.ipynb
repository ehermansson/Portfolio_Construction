# %%
import yfinance as yf 
import pandas as pd
import numpy as np 
import seaborn as sns
from matplotlib import pylab as plt

# %%
def correlation_map(result):
    corr = result
    #ret = calc_port_ret(result)
    #ret = np.log(ret)
    #corr = ret.corr()
    corr = round(corr, 3)
    th_props = [
      ('font-size', '20px'),
      ('text-align', 'center'),
      ('font-weight', 'bold'),
      ('color', 'Black'),
      ('background-color', '#f7f7f9')
      ]

    
        # Set CSS properties for td elements in dataframe
    td_props = [
          ('font-size', '20px'), ('text-align', 'center')
          ]
    
        # Set table styles
    styles = [
          dict(selector="th", props=th_props),
          dict(selector="td", props=td_props)
          ]
    
    cm_neg_good = sns.diverging_palette(150, 10, s=80, l=70, n=len(corr.columns)**2, as_cmap=True)#sns.light_palette("green", as_cmap=True)
    cm_pos_good = sns.diverging_palette(10, 150, s=80, l=70, n=len(corr.columns)**2, as_cmap=True)
    
    
    corr = (corr.style
          .background_gradient(axis = 0 ,cmap=cm_neg_good)
          .format("{:.2f}")
          .set_table_styles(styles)
          .set_properties(**{'color': 'black'}))
    
    return corr

# %%
### Assets 
tickers = ['GLD', 'TLT', 'SPY', 'DBC', 'HYG', 'BTC-USD', 'EEM', 'LQD', 'GDX']

prices_df = pd.DataFrame()

for tick in tickers:
    
    price = yf.download(tick,start='2000-01-01', progress = False, threads = False)
    price = price['Close']
    prices_df[tick] = price

# %%
monthly_df = prices_df.resample('M').last()
ret_df = monthly_df.pct_change().dropna()

# %%
cond_asset = 'SPY'

neg_ret = ret_df[ret_df[cond_asset]<0]
pos_ret = ret_df[ret_df[cond_asset]>0]

# %%
#neg_corr = correlation_map(neg_ret.corr(method='spearman'))
#neg_corr.set_caption("Correlation conditional on negative stock returns")

# %%
#pos_corr = correlation_map(pos_ret.corr(method='spearman'))
#pos_corr.set_caption("Correlation conditional on positive stock returns")

# %%
#Assymetry, you want it to be as negative as possible, then it has positive assymetry
asym_corr = (neg_ret.corr() - pos_ret.corr())
asym_corr = correlation_map(asym_corr)
asym_corr.set_caption("Correlation Assymetery: Negative assymetry is good")
# Out:
# <style type="text/css">
# #T_a34d7_ th {
#   font-size: 20px;
#   text-align: center;
#   font-weight: bold;
#   color: Black;
#   background-color: #f7f7f9;
# }
# #T_a34d7_ td {
#   font-size: 20px;
#   text-align: center;
# }
# #T_a34d7_row0_col0, #T_a34d7_row1_col1, #T_a34d7_row2_col6, #T_a34d7_row3_col2, #T_a34d7_row3_col4, #T_a34d7_row3_col7, #T_a34d7_row4_col5, #T_a34d7_row7_col3, #T_a34d7_row8_col8 {
#   background-color: #f29094;
#   color: #f1f1f1;
#   color: black;
# }
# #T_a34d7_row0_col1 {
#   background-color: #f2d8d9;
#   color: #000000;
#   color: black;
# }
# #T_a34d7_row0_col2, #T_a34d7_row4_col1 {
#   background-color: #7dceac;
#   color: #000000;
#   color: black;
# }
# #T_a34d7_row0_col3 {
#   background-color: #76cca7;
#   color: #000000;
#   color: black;
# }
# #T_a34d7_row0_col4, #T_a34d7_row0_col5, #T_a34d7_row0_col6, #T_a34d7_row1_col2, #T_a34d7_row1_col3, #T_a34d7_row1_col7, #T_a34d7_row4_col0, #T_a34d7_row4_col8, #T_a34d7_row5_col0, #T_a34d7_row5_col1 {
#   background-color: #4ebf8f;
#   color: #f1f1f1;
#   color: black;
# }
# #T_a34d7_row0_col7 {
#   background-color: #80cfad;
#   color: #000000;
#   color: black;
# }
# #T_a34d7_row0_col8 {
#   background-color: #f2969a;
#   color: #000000;
#   color: black;
# }
# #T_a34d7_row1_col0, #T_a34d7_row2_col5 {
#   background-color: #f2cbcd;
#   color: #000000;
#   color: black;
# }
# #T_a34d7_row1_col4 {
#   background-color: #90d4b7;
#   color: #000000;
#   color: black;
# }
# #T_a34d7_row1_col5 {
#   background-color: #7ecfac;
#   color: #000000;
#   color: black;
# }
# #T_a34d7_row1_col6 {
#   background-color: #68c79f;
#   color: #000000;
#   color: black;
# }
# #T_a34d7_row1_col8 {
#   background-color: #f2edee;
#   color: #000000;
#   color: black;
# }
# #T_a34d7_row2_col0, #T_a34d7_row8_col1 {
#   background-color: #f2e3e3;
#   color: #000000;
#   color: black;
# }
# #T_a34d7_row2_col1 {
#   background-color: #a5dbc4;
#   color: #000000;
#   color: black;
# }
# #T_a34d7_row2_col2, #T_a34d7_row6_col8 {
#   background-color: #f2eaeb;
#   color: #000000;
#   color: black;
# }
# #T_a34d7_row2_col3 {
#   background-color: #f29da1;
#   color: #000000;
#   color: black;
# }
# #T_a34d7_row2_col4 {
#   background-color: #f2a8ab;
#   color: #000000;
#   color: black;
# }
# #T_a34d7_row2_col7, #T_a34d7_row6_col6, #T_a34d7_row7_col2 {
#   background-color: #f2cacb;
#   color: #000000;
#   color: black;
# }
# #T_a34d7_row2_col8 {
#   background-color: #f2dbdc;
#   color: #000000;
#   color: black;
# }
# #T_a34d7_row3_col0 {
#   background-color: #f2d4d5;
#   color: #000000;
#   color: black;
# }
# #T_a34d7_row3_col1 {
#   background-color: #cfe9dd;
#   color: #000000;
#   color: black;
# }
# #T_a34d7_row3_col3, #T_a34d7_row5_col6 {
#   background-color: #dcede5;
#   color: #000000;
#   color: black;
# }
# #T_a34d7_row3_col5 {
#   background-color: #f29296;
#   color: #000000;
#   color: black;
# }
# #T_a34d7_row3_col6 {
#   background-color: #f2b9bb;
#   color: #000000;
#   color: black;
# }
# #T_a34d7_row3_col8 {
#   background-color: #f2b7ba;
#   color: #000000;
#   color: black;
# }
# #T_a34d7_row4_col2, #T_a34d7_row6_col4 {
#   background-color: #f2c1c3;
#   color: #000000;
#   color: black;
# }
# #T_a34d7_row4_col3 {
#   background-color: #f2b0b3;
#   color: #000000;
#   color: black;
# }
# #T_a34d7_row4_col4 {
#   background-color: #f2c9cb;
#   color: #000000;
#   color: black;
# }
# #T_a34d7_row4_col6 {
#   background-color: #f2c0c2;
#   color: #000000;
#   color: black;
# }
# #T_a34d7_row4_col7 {
#   background-color: #f2b4b7;
#   color: #000000;
#   color: black;
# }
# #T_a34d7_row5_col2 {
#   background-color: #bbe3d1;
#   color: #000000;
#   color: black;
# }
# #T_a34d7_row5_col3 {
#   background-color: #f2e5e6;
#   color: #000000;
#   color: black;
# }
# #T_a34d7_row5_col4 {
#   background-color: #f2b6b8;
#   color: #000000;
#   color: black;
# }
# #T_a34d7_row5_col5 {
#   background-color: #f2a6a9;
#   color: #000000;
#   color: black;
# }
# #T_a34d7_row5_col7 {
#   background-color: #d4ebe0;
#   color: #000000;
#   color: black;
# }
# #T_a34d7_row5_col8 {
#   background-color: #66c69d;
#   color: #000000;
#   color: black;
# }
# #T_a34d7_row6_col0 {
#   background-color: #9bd8be;
#   color: #000000;
#   color: black;
# }
# #T_a34d7_row6_col1 {
#   background-color: #8cd3b5;
#   color: #000000;
#   color: black;
# }
# #T_a34d7_row6_col2 {
#   background-color: #f2b2b4;
#   color: #000000;
#   color: black;
# }
# #T_a34d7_row6_col3 {
#   background-color: #f2eaea;
#   color: #000000;
#   color: black;
# }
# #T_a34d7_row6_col5 {
#   background-color: #f2d6d7;
#   color: #000000;
#   color: black;
# }
# #T_a34d7_row6_col7 {
#   background-color: #f2c7c9;
#   color: #000000;
#   color: black;
# }
# #T_a34d7_row7_col0 {
#   background-color: #d8ece3;
#   color: #000000;
#   color: black;
# }
# #T_a34d7_row7_col1 {
#   background-color: #5ec499;
#   color: #000000;
#   color: black;
# }
# #T_a34d7_row7_col4 {
#   background-color: #f2999d;
#   color: #000000;
#   color: black;
# }
# #T_a34d7_row7_col5 {
#   background-color: #f2c8ca;
#   color: #000000;
#   color: black;
# }
# #T_a34d7_row7_col6 {
#   background-color: #f2a5a8;
#   color: #000000;
#   color: black;
# }
# #T_a34d7_row7_col7 {
#   background-color: #f2e4e5;
#   color: #000000;
#   color: black;
# }
# #T_a34d7_row7_col8 {
#   background-color: #f2e9e9;
#   color: #000000;
#   color: black;
# }
# #T_a34d7_row8_col0 {
#   background-color: #f29498;
#   color: #000000;
#   color: black;
# }
# #T_a34d7_row8_col2 {
#   background-color: #a6dcc5;
#   color: #000000;
#   color: black;
# }
# #T_a34d7_row8_col3 {
#   background-color: #b0dfcb;
#   color: #000000;
#   color: black;
# }
# #T_a34d7_row8_col4 {
#   background-color: #89d2b3;
#   color: #000000;
#   color: black;
# }
# #T_a34d7_row8_col5 {
#   background-color: #a8dcc5;
#   color: #000000;
#   color: black;
# }
# #T_a34d7_row8_col6 {
#   background-color: #c7e6d8;
#   color: #000000;
#   color: black;
# }
# #T_a34d7_row8_col7 {
#   background-color: #b4e0cd;
#   color: #000000;
#   color: black;
# }
# </style>
# <table id="T_a34d7_">
#   <caption>Correlation Assymetery: Negative assymetry is good</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >GLD</th>
#       <th class="col_heading level0 col1" >TLT</th>
#       <th class="col_heading level0 col2" >SPY</th>
#       <th class="col_heading level0 col3" >DBC</th>
#       <th class="col_heading level0 col4" >HYG</th>
#       <th class="col_heading level0 col5" >BTC-USD</th>
#       <th class="col_heading level0 col6" >EEM</th>
#       <th class="col_heading level0 col7" >LQD</th>
#       <th class="col_heading level0 col8" >GDX</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a34d7_level0_row0" class="row_heading level0 row0" >GLD</th>
#       <td id="T_a34d7_row0_col0" class="data row0 col0" >0.00</td>
#       <td id="T_a34d7_row0_col1" class="data row0 col1" >-0.15</td>
#       <td id="T_a34d7_row0_col2" class="data row0 col2" >-0.20</td>
#       <td id="T_a34d7_row0_col3" class="data row0 col3" >-0.17</td>
#       <td id="T_a34d7_row0_col4" class="data row0 col4" >-0.48</td>
#       <td id="T_a34d7_row0_col5" class="data row0 col5" >-0.48</td>
#       <td id="T_a34d7_row0_col6" class="data row0 col6" >-0.36</td>
#       <td id="T_a34d7_row0_col7" class="data row0 col7" >-0.27</td>
#       <td id="T_a34d7_row0_col8" class="data row0 col8" >-0.01</td>
#     </tr>
#     <tr>
#       <th id="T_a34d7_level0_row1" class="row_heading level0 row1" >TLT</th>
#       <td id="T_a34d7_row1_col0" class="data row1 col0" >-0.15</td>
#       <td id="T_a34d7_row1_col1" class="data row1 col1" >0.00</td>
#       <td id="T_a34d7_row1_col2" class="data row1 col2" >-0.28</td>
#       <td id="T_a34d7_row1_col3" class="data row1 col3" >-0.23</td>
#       <td id="T_a34d7_row1_col4" class="data row1 col4" >-0.33</td>
#       <td id="T_a34d7_row1_col5" class="data row1 col5" >-0.39</td>
#       <td id="T_a34d7_row1_col6" class="data row1 col6" >-0.32</td>
#       <td id="T_a34d7_row1_col7" class="data row1 col7" >-0.37</td>
#       <td id="T_a34d7_row1_col8" class="data row1 col8" >-0.17</td>
#     </tr>
#     <tr>
#       <th id="T_a34d7_level0_row2" class="row_heading level0 row2" >SPY</th>
#       <td id="T_a34d7_row2_col0" class="data row2 col0" >-0.20</td>
#       <td id="T_a34d7_row2_col1" class="data row2 col1" >-0.28</td>
#       <td id="T_a34d7_row2_col2" class="data row2 col2" >0.00</td>
#       <td id="T_a34d7_row2_col3" class="data row2 col3" >0.25</td>
#       <td id="T_a34d7_row2_col4" class=
