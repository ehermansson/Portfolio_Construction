# %%
import pandas as pd
from matplotlib import pylab as plt
import numpy as np
from datetime import datetime
import math
import seaborn as sns
import sys
import sys
import re
import os.path

# %% [markdown]
# ## data import

# %%
file_name =  "clean_data_2022-05-24.csv"
folder = "../clean_equity_data/"
save = "YES"

data_tmp = pd.read_csv(folder + file_name)

# %%
data_tmp.columns
# Out:
# Index(['Unnamed: 0', 'Börsdata ID', 'Company', 'Industry', 'Volume', 'P/FCF',
#        'Assets Turn', 'Gross profit', 'Tot. Assets', 'ROC', 'Market Cap',
#        'Volatility', 'ROE', 'FCF', 'Total Equity', 'Return 3m', 'Return 6m',
#        'Return 1y', 'Country', 'List', 'Tick', 'EV/EBIT', 'Last Report',
#        'Yahoo', 'Yield', 'P/E', 'P/S', 'P/B', 'Asset Growth',
#        'Info - Stock price', 'Info - Report', 'Sector', 'FCFROE', 'GPA',
#        'EA ret', 'EA ret std', '1 Year Volatility', '1 Year MAD',
#        'EA Volatility', 'Beta', 'Res_Mom_1Y', 'Res_Mom_6m', 'Total_Mom_6m'],
#       dtype='object')

# %%
# FUNCTIONS FOR VIEWING SINGLE COMPANY RANKINGS 

def company(company, data):
    for i in data['Company']:
        if company in i or company in i.lower():
            return data.loc[data['Company'] == i]
    print('No company found')
    
def Company(company, data):
    for i in data['Company']:
        if company in i or company in i.lower():
            stock = data.loc[data['Company'] == i]
            stock = stock[compact]
            return stock
    print('No company found')

# %%
### GESTALT
data_gestalt = data_tmp.copy()
data_gestalt = data_gestalt.loc[(data_tmp['Sector'] != 'Financials')]

# %% [markdown]
# ### Gestalt Imputation and Rank

# %%
# MANAGE NaNs and NEGATIVE EARNINGS  

# set nan to median, only fundamental data
columns = ['P/E', 'EV/EBIT', 'P/FCF', 'P/S', 'P/B', 'ROC', 'ROE',
            'GPA', 'Assets Turn', 'FCFROE', 'Asset Growth']
for i in columns: 
    data_gestalt.loc[data_gestalt[i].isna() ,i] = data_gestalt[i].median()
    
# set negative values to max
for i in ['P/E', 'EV/EBIT', 'P/FCF', 'P/S', 'P/B']:
    data_gestalt.loc[data_gestalt[i] < 0 ,i] = data_gestalt[i].max()
    
# set nan yield & vol to 0
data_gestalt.loc[data_gestalt['Yield'].isna(),'Yield'] = 0

# %%
RANK_WEIGHTS = {"Momentum": 1, "Value": 1, "Quality": 1}


factor=1.0/sum(RANK_WEIGHTS.values())
for k in RANK_WEIGHTS:
    RANK_WEIGHTS[k] = RANK_WEIGHTS[k]*factor
    
    
print(sum(RANK_WEIGHTS.values()))
# Out:
# 1.0

# %%
####### CALCULATE RANKS ###########
for i in ['Total_Mom_6m','Return 3m', 'Return 6m', 'Return 1y', 'EA ret std', 'Res_Mom_1Y', 'Res_Mom_6m']:
    data_gestalt[i +' Rank'] = data_gestalt[i].rank(ascending = False)

# Ranking where lower value is better
for i in ['P/E', 'P/B', 'P/S', 'P/FCF', 'EV/EBIT', 'Asset Growth']:
    data_gestalt[i +' Rank'] = data_gestalt[i].rank()
    

for i in ['Yield', 'ROE', 'ROC', 'FCFROE', 'GPA', 'Assets Turn']:
    data_gestalt[i + ' Rank'] = (data_gestalt[i]).rank(ascending = False)
    
##################### Composite ranks #######################
data_gestalt['PMOM Rank'] = (data_gestalt['Total_Mom_6m Rank'] + data_gestalt['Return 1y Rank']).rank(ascending = True)
data_gestalt['IMOM Rank'] = (data_gestalt['Res_Mom_1Y Rank'] + data_gestalt['Res_Mom_6m Rank']).rank(ascending = True)
data_gestalt['Momentum Rank'] = (data_gestalt['EA ret std Rank'] + 
                                 data_gestalt['IMOM Rank'] + data_gestalt['PMOM Rank']).rank(ascending = True)


data_gestalt['Quality Rank'] = (data_gestalt['ROE Rank'] + data_gestalt['ROC Rank'] + data_gestalt['FCFROE Rank'] + 
                        data_gestalt['GPA Rank'] + data_gestalt['Assets Turn Rank']).rank()

data_gestalt['Value Rank'] = (data_gestalt['P/E Rank'] + data_gestalt['P/B Rank'] + data_gestalt['P/S Rank'] + data_gestalt['P/FCF Rank'] + 
                      data_gestalt['EV/EBIT Rank'] + data_gestalt['Asset Growth Rank']).rank()
 


    
data_gestalt['Gestalt Rank'] = ((RANK_WEIGHTS['Value']*data_gestalt['Value Rank'] 
                                 + RANK_WEIGHTS['Momentum']*data_gestalt['Momentum Rank'] +
                                RANK_WEIGHTS['Quality']* data_gestalt['Quality Rank'])).rank()

# %% [markdown]
# ### Data Error Check

# %%
#data_mom.isna().sum()
data_gestalt.isna().sum()
# Out:
# Unnamed: 0       0
# Börsdata ID      0
# Company          0
# Industry         0
# Volume           0
#                 ..
# IMOM Rank        0
# Momentum Rank    0
# Quality Rank     0
# Value Rank       0
# Gestalt Rank     0
# Length: 68, dtype: int64

# %% [markdown]
# ### Sorting

# %%
CURRENT_BUYOUTS = ['Aspire Global', 'LeoVegas']

#### Gestalt Data Frame
gestalt_tmp = data_gestalt.sort_values(by=['Gestalt Rank'])
gestalt_tmp=gestalt_tmp[ ~gestalt_tmp['Company'].isin(CURRENT_BUYOUTS)]

# %%
save = "YES"
if save == "YES":
    data_date  = re.search(r'\d{4}-\d{2}-\d{2}', file_name)
    folder = '../clean_equity_data'
    exp_file_name = "GESTALT_{}".format(data_date.group(0))+ ".csv"
    gestalt_tmp.to_csv(os.path.join(folder, exp_file_name))

# %%
compact = ['Company', 'List','Tick', 'Gestalt Rank', 'Quality Rank', 'Value Rank', 'Momentum Rank', 'EA ret std', '1 Year Volatility']
compact_mom = ['Company', 'List','Tick','Momentum Rank','EA ret std', '1 Year Volatility']
# numbers of stocks to select for diff strategies

stocks = 30


## TRIPLE SORT ##

gestalt = gestalt_tmp[0:stocks]
gestalt = gestalt[compact]

# %% [markdown]
# ### Print Stock Selection

# %%
#gestalt 
th_props = [
  ('font-size', '14px'),
  ('text-align', 'center'),
  ('font-weight', 'bold'),
  ('color', 'Black'),
  ('background-color', '#f7f7f9')
  ]
# Set CSS properties for td elements in dataframe
td_props = [('font-size', '12px'), ('text-align', 'center')]
#set caption props
caption_props = [('color', 'black'),('font-size', '22px'),
        ("text-align", "center"),
        ('font-weight', 'bold')]
# Set table styles
styles = [
    dict(selector="th", props=th_props),
    dict(selector="td", props=td_props),
    dict(selector="caption", props=caption_props)
]
gestalt.index = range(1, len(gestalt)+1)
gestalt_view = (gestalt.style.apply(lambda x: ['background: lightgreen' if x.name in range(1, 15+1) 
                              else '' for i in x], axis=1).set_table_styles(styles)
                 .format({'Gestalt Rank': "{:.0f}",'Quality Rank': "{:.0f}", 'Value Rank': "{:.0f}",
                          'Momentum Rank': "{:.0f}",
                          'EA ret std': "{:.1f}",'1 Year Volatility': "{:.1%}"})
                 .set_caption("Gestalt"))
gestalt_view
# Out:
# <style type="text/css">
# #T_04799_ th {
#   font-size: 14px;
#   text-align: center;
#   font-weight: bold;
#   color: Black;
#   background-color: #f7f7f9;
# }
# #T_04799_ td {
#   font-size: 12px;
#   text-align: center;
# }
# #T_04799_ caption {
#   color: black;
#   font-size: 22px;
#   text-align: center;
#   font-weight: bold;
# }
# #T_04799_row0_col0, #T_04799_row0_col1, #T_04799_row0_col2, #T_04799_row0_col3, #T_04799_row0_col4, #T_04799_row0_col5, #T_04799_row0_col6, #T_04799_row0_col7, #T_04799_row0_col8, #T_04799_row1_col0, #T_04799_row1_col1, #T_04799_row1_col2, #T_04799_row1_col3, #T_04799_row1_col4, #T_04799_row1_col5, #T_04799_row1_col6, #T_04799_row1_col7, #T_04799_row1_col8, #T_04799_row2_col0, #T_04799_row2_col1, #T_04799_row2_col2, #T_04799_row2_col3, #T_04799_row2_col4, #T_04799_row2_col5, #T_04799_row2_col6, #T_04799_row2_col7, #T_04799_row2_col8, #T_04799_row3_col0, #T_04799_row3_col1, #T_04799_row3_col2, #T_04799_row3_col3, #T_04799_row3_col4, #T_04799_row3_col5, #T_04799_row3_col6, #T_04799_row3_col7, #T_04799_row3_col8, #T_04799_row4_col0, #T_04799_row4_col1, #T_04799_row4_col2, #T_04799_row4_col3, #T_04799_row4_col4, #T_04799_row4_col5, #T_04799_row4_col6, #T_04799_row4_col7, #T_04799_row4_col8, #T_04799_row5_col0, #T_04799_row5_col1, #T_04799_row5_col2, #T_04799_row5_col3, #T_04799_row5_col4, #T_04799_row5_col5, #T_04799_row5_col6, #T_04799_row5_col7, #T_04799_row5_col8, #T_04799_row6_col0, #T_04799_row6_col1, #T_04799_row6_col2, #T_04799_row6_col3, #T_04799_row6_col4, #T_04799_row6_col5, #T_04799_row6_col6, #T_04799_row6_col7, #T_04799_row6_col8, #T_04799_row7_col0, #T_04799_row7_col1, #T_04799_row7_col2, #T_04799_row7_col3, #T_04799_row7_col4, #T_04799_row7_col5, #T_04799_row7_col6, #T_04799_row7_col7, #T_04799_row7_col8, #T_04799_row8_col0, #T_04799_row8_col1, #T_04799_row8_col2, #T_04799_row8_col3, #T_04799_row8_col4, #T_04799_row8_col5, #T_04799_row8_col6, #T_04799_row8_col7, #T_04799_row8_col8, #T_04799_row9_col0, #T_04799_row9_col1, #T_04799_row9_col2, #T_04799_row9_col3, #T_04799_row9_col4, #T_04799_row9_col5, #T_04799_row9_col6, #T_04799_row9_col7, #T_04799_row9_col8, #T_04799_row10_col0, #T_04799_row10_col1, #T_04799_row10_col2, #T_04799_row10_col3, #T_04799_row10_col4, #T_04799_row10_col5, #T_04799_row10_col6, #T_04799_row10_col7, #T_04799_row10_col8, #T_04799_row11_col0, #T_04799_row11_col1, #T_04799_row11_col2, #T_04799_row11_col3, #T_04799_row11_col4, #T_04799_row11_col5, #T_04799_row11_col6, #T_04799_row11_col7, #T_04799_row11_col8, #T_04799_row12_col0, #T_04799_row12_col1, #T_04799_row12_col2, #T_04799_row12_col3, #T_04799_row12_col4, #T_04799_row12_col5, #T_04799_row12_col6, #T_04799_row12_col7, #T_04799_row12_col8, #T_04799_row13_col0, #T_04799_row13_col1, #T_04799_row13_col2, #T_04799_row13_col3, #T_04799_row13_col4, #T_04799_row13_col5, #T_04799_row13_col6, #T_04799_row13_col7, #T_04799_row13_col8, #T_04799_row14_col0, #T_04799_row14_col1, #T_04799_row14_col2, #T_04799_row14_col3, #T_04799_row14_col4, #T_04799_row14_col5, #T_04799_row14_col6, #T_04799_row14_col7, #T_04799_row14_col8 {
#   background: lightgreen;
# }
# </style>
# <table id="T_04799_">
#   <caption>Gestalt</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Company</th>
#       <th class="col_heading level0 col1" >List</th>
#       <th class="col_heading level0 col2" >Tick</th>
#       <th class="col_heading level0 col3" >Gestalt Rank</th>
#       <th class="col_heading level0 col4" >Quality Rank</th>
#       <th class="col_heading level0 col5" >Value Rank</th>
#       <th class="col_heading level0 col6" >Momentum Rank</th>
#       <th class="col_heading level0 col7" >EA ret std</th>
#       <th class="col_heading level0 col8" >1 Year Volatility</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_04799_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_04799_row0_col0" class="data row0 col0" >Rottneros</td>
#       <td id="T_04799_row0_col1" class="data row0 col1" >Mid Cap</td>
#       <td id="T_04799_row0_col2" class="data row0 col2" >RROS</td>
#       <td id="T_04799_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_04799_row0_col4" class="data row0 col4" >54</td>
#       <td id="T_04799_row0_col5" class="data row0 col5" >14</td>
#       <td id="T_04799_row0_col6" class="data row0 col6" >4</td>
#       <td id="T_04799_row0_col7" class="data row0 col7" >1.5</td>
#       <td id="T_04799_row0_col8" class="data row0 col8" >37.0%</td>
#     </tr>
#     <tr>
#       <th id="T_04799_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_04799_row1_col0" class="data row1 col0" >Arctic Paper</td>
#       <td id="T_04799_row1_col1" class="data row1 col1" >Small Cap</td>
#       <td id="T_04799_row1_col2" class="data row1 col2" >ARP</td>
#       <td id="T_04799_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_04799_row1_col4" class="data row1 col4" >59</td>
#       <td id="T_04799_row1_col5" class="data row1 col5" >4</td>
#       <td id="T_04799_row1_col6" class="data row1 col6" >11</td>
#       <td id="T_04799_row1_col7" class="data row1 col7" >1.3</td>
#       <td id="T_04799_row1_col8" class="data row1 col8" >48.1%</td>
#     </tr>
#     <tr>
#       <th id="T_04799_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_04799_row2_col0" class="data row2 col0" >Bilia</td>
#       <td id="T_04799_row2_col1" class="data row2 col1" >Large Cap</td>
#       <td id="T_04799_row2_col2" class="data row2 col2" >BILI A</td>
#       <td id="T_04799_row2_col3" class="data row2 col3" >3</td>
#       <td id="T_04799_row2_col4" class="data row2 col4" >20</td>
#       <td id="T_04799_row2_col5" class="data row2 col5" >16</td>
#       <td id="T_04799_row2_col6" class="data row2 col6" >44</td>
#       <td id="T_04799_row2_col7" class="data row2 col7" >2.3</td>
#       <td id="T_04799_row2_col8" class="data row2 col8" >33.1%</td>
#     </tr>
#     <tr>
#       <th id="T_04799_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_04799_row3_col0" class="data row3 col0" >SSAB B</td>
#       <td id="T_04799_row3_col1" class="data row3 col1" >Large Cap</td>
#       <td id="T_04799_row3_col2" class="data row3 col2" >SSAB B</td>
#       <td id="T_04799_row3_col3" class="data row3 col3" >4</td>
#       <td id="T_04799_row3_col4" class="data row3 col4" >55</td>
#       <td id="T_04799_row3_col5" class="data row3 col5" >8</td>
#       <td id="T_04799_row3_col6" class="data row3 col6" >20</td>
#       <td id="T_04799_row3_col7" class="data row3 col7" >0.7</td>
#       <td id="T_04799_row3_col8" class="data row3 col8" >39.1%</td>
#     </tr>
#     <tr>
#       <th id="T_04799_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_04799_row4_col0" class="data row4 col0" >Björn Borg</td>
#       <td id="T_04799_row4_col1" class="data row4 col1" >Small Cap</td>
#       <td id="T_04799_row4_col2" class="data row4 col2" >BORG</td>
#       <td id="T_04799_row4_col3" class="data row4 col3" >5</td>
#       <td id="T_04799_row4_col4" class="data row4 col4" >15</td>
#       <td id="T_04799_row4_col5" class="data row4 col5" >45</td>
#       <td id="T_04799_row4_col6" class="data row4 col6" >26</td>
#       <td id="T_04799_row4_col7" class="data row4 col7" >0.6</td>
#       <td id="T_04799_row4_col8" class="data row4 col8" >41.7%</td>
#     </tr>
#     <tr>
#       <th id="T_04799_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_04799_row5_col0" class="data row5 col0" >B3 Consulting</td>
#       <td id="T_04799_row5_col1" class="data row5 col1" >Small Cap</td>
#       <td id="T_04799_row5_col2" class="data row5 col2" >B3</td>
#       <td id="T_04799_row5_col3" class="data row5 col3" >6</td>
#       <td id="T_04799_row5_col4" class="data row5 col4" >7</td>
#       <td id="T_04799_row5_col5" class="data row5 col5" >81</td>
#       <td id="T_04799_row5_col6" class="data row5 col6" >3</td>
#       <td id="T_04799_row5_col7" class="data row5 col7" >2.1</td>
#       <td id="T_04799_row5_col8" class="data row5 col8" >50.8%</td>
#     </tr>
#     <tr>
#       <th id="T_04799_level0_row6" class="ro

# %% [markdown]
# ## Reversed Ranks

# %%
stocks = 20

## TRIPLE SORT ##
gestalt = gestalt_tmp[0:stocks]
gestalt = gestalt[compact]

neg_gestalt = gestalt_tmp.tail(stocks)[::-1][compact]

# %%
gestalt_tmp.sort_values(by = 'Value Rank').head(30)
# Out:
#      Unnamed: 0  Börsdata ID        Company                       Industry  \
# 2             2         1323     AcadeMedia                      Education
# 331         331         1377        Serneke  Construction & Infrastructure
# 209         209          117           Kabe               Auto & Equipment
# 26           26          381   Arctic Paper         Forest & Wood Products
# 241         241          137      Mekonomen               Auto & Equipment
# 206         206          116             JM                   Homebuilding
# 375         375          224      TietoEVRY                  IT Consulting
# 346         346         1632         SSAB B      Mining - Steel & Aluminum
# 182         182         1010         Humana          Healthcare Facilities
# 254         254          151          NCC B  Construction & Infrastructure
# 130         130           75        EnQuest         Oil & Gas -Exploration
# 198         198          424         Inwido          Construction Supplies
# 335         335          207        Skanska  Construction & Infrastructure
# 311         311          191      Rottneros         Forest & Wood Products
# 345         345          421         Speqta                Online Services
# 56           56           33          Bilia               Auto & Equipment
# 149         149         1546    Ferronordic          Industrial Components
# 327         327          201      Securitas                       Security
# 167         167           93         Haldex          Industrial Components
# 263         263          157          Nobia               Home Furnishings
# 46           46           27       BE Group          Industrial Components
# 98           98           52        Cloetta                Food Processing
# 52           52           32        Betsson             Gambling & Casinos
# 126         126          596          Eltel                   Installation
# 19           19          739         Alimak                   Installation
# 288         288          175           Peab  Construction & Infrastructure
# 400         400          236        Volvo B           Industrial Machinery
# 13           13          258     Africa Oil         Oil & Gas -Exploration
# 301         301         1896       QleanAir             Energy & Recycling
# 234         234          131  Lundin Mining                         Mining
#
#       Volume     P/FCF  Assets Turn  Gross profit  Tot. Assets      ROC  ...  \
# 2     10.308     2.151        0.775     11542.000    18274.000  0.09078  ...
# 331    0.716    10.179        1.272       415.000     6946.000  0.08785  ...
# 209    1.358     5.853        1.509       502.000     2277.000  0.27829  ...
# 26     1.034    12.347        1.428      1909.339     5839.342  0.21394  ...
# 241   11.003     8.740        0.937      5970.000    13304.000  0.09588  ...
# 206   79.076     5.761        0.866      2875.000    17457.000  0.27028  ...
# 375    2.123     6.424        0.774     24537.689    37844.262  0.15962  ...
# 346  440.232     3.876        0.870     30234.000   123870.000  0.32426  ...
# 182    3.469     6.227        0.916      1979.000     9101.000  0.06780  ...
# 254   53.343    14.363        1.900      4547.000    28095.000  0.15487  ...
# 130   35.135     2.402        0.290      3463.601    42215.672  0.18789  ...
# 198   23.150    10.395        0.923      2108.300     8836.500  0.16683  ...
# 335  225.461    17.523        1.041     15306.000   140458.000  0.16536  ...
# 311    2.731    15.339        0.948      1328.000     2555.000  0.20713  ...
# 345    7.171     1.158        0.245        98.370      399.425  0.32423  ...
# 56    21.116     8.658        1.998      6086.000    17440.000  0.20017  ...
# 149   11.624  4299.147        1.952      1196.261     3428.000  0.48977  ...
# 327  154.831    23.911        1.679     20376.000    65177.000  0.12296  ...
# 167    4.543    45.198        0.986      1276.000     4873.000  0.09993  ...
# 263   16.890    20.553        1.132      5442.000    12473.000  0.13466  ...
# 46    17.805    33.926        1.709      1222.000     3589.000  0.33567  ...
# 98    21.516    10.127        0.626      2244.000     9878.000  0.08101  ...
# 52    30.716    14.265        0.722      4392.827     9484.402  0.22539  ...
# 126    0.570     4.284        1.336       908.355     6433.390  0.04237  ...
# 19     7.469    10.016        0.648      1311.500     5889.000  0.09907  ...
# 288   43.767    30.522        1.267      6050.000    47313.000  0.16947  ...
# 400  797.621    12.374        0.694     90674.000   552392.000  0.14720  ...
# 13    60.681     3.631        0.220      2094.192     9264.420  0.24053  ...
# 301    1.412     9.379        0.725       327.629      628.571  0.23607  ...
# 234   65.560     7.284        0.456     13502.860    67441.773  0.23451  ...
#
#      ROC Rank  FCFROE Rank  GPA Rank  Assets Turn Rank  PMOM Rank  IMOM Rank  \
# 2       178.0         14.0      29.0             140.0      220.0      266.0
# 331     185.0        122.0     289.0              44.0      140.0      100.5
# 209      50.0         35.0     190.0              25.0       77.0       91.5
# 26       78.0        109.0     113.0              28.0        7.5       36.0
# 241     176.0         70.0      72.0              98.0      199.5      264.0
# 206      51.0         32.0     237.0             118.0      248.0      304.5
# 375     111.0         37.0      25.0             141.0      128.0       71.0
# 346      36.0         55.0     158.0             117.0       22.0       10.0
# 182     215.0         67.0     194.0             103.0      251.0      281.0
# 254     114.0         60.0     239.0              13.0      151.0       68.0
# 130      92.0          4.0     280.0             258.0       13.5       16.5
# 198     104.0         63.0     171.0             101.0      117.5      222.0
# 335     107.0         95.0     265.0              78.0      197.5      262.5
# 311      81.0         97.0      58.0              94.0        9.0        2.0
# 345      37.0          3.0     156.0             270.0       29.5       22.5
# 56       83.0         21.0      97.0               9.0      103.0      110.0
# 149      23.0        174.0      98.0              11.5      320.0      306.0
# 327     141.0        104.0     118.0              18.0      189.5      106.0
# 167     159.0        137.0     149.0              88.0      203.0       86.5
# 263     134.0        119.0      76.0              63.0      275.0      290.0
# 46       34.0        129.0     103.0              17.0        6.0       45.0
# 98      198.0         71.0     183.0             194.0      152.0      108.0
# 52       72.0         84.0      69.0             154.5       88.5       78.0
# 126     226.0         72.0     252.0              38.0      303.5      329.0
# 19      171.0         74.0     189.0             189.0      242.5      224.0
# 288     102.0        118.0     259.0              46.0      196.0      205.0
# 400     119.0         54.0     238.0             179.0      170.0      196.0
# 13       63.0         30.0     184.0             275.0       11.0       27.0
# 301      68.0         34.0      57.0             151.0      277.0      299.5
# 234      69.0         40.0     207.0             229.0       67.5       67.0
#
#      Momentum Rank  Quality Rank Value Rank Gestalt Rank
# 2            300.0          73.5        1.0         99.0
# 331          100.0         160.5        2.0         54.0
# 209           67.0          47.0        3.0         10.0
# 26            11.0          59.0        4.0          2.0
# 241          171.0          93.5        5.0         56.0
# 206          280.5          72.0        6.0         95.0
# 375          127.0          52.0        7.0         28.5
# 346           20.0          55.0        8.0          4.0
# 182          218.0         154.0        9.0        104.0
# 254           86.0          62.0       10.0         21.0
# 130            5.0         115.0       11.0         13.0
# 198          102.0          85.5       12.0         35.0
# 335          282.5         124.0       13.0        133.5
# 311            4.0          54.0       14.0          1.0
# 345           30.0         123.0       15.0         23.0
# 56            44.0          20.0       16.0          3.0
# 149          221.0          34.0       17.0         57.0
# 327          156.0          70.0       18.0         48.5
# 167          184.0         132.0       19.0         78.0
# 263          301.0          78.0       20.0        117.0
# 46            55.0          29.0       21.0          7.0
# 98           167.0         171.0       22.0         96.0
# 52            51.0          63.0       23.0         15.0
# 126          330.0         175.0       24.0        185.0
# 19           210.0         174.0       25.0        124.0
# 288          271.5         106.0       26.5        119.5
# 400          153.0         125.0       26.5         66.5
# 13            48.0         110.0       28.0         28.5
# 301          311.0          41.0       29.0        105.0
# 234           77.0         109.0       30.5         41.0
#
# [30 rows x 68 columns]

# %%
neg_gestalt
# Out:
#                    Company         List     Tick  Gestalt Rank  Quality Rank  \
# 302                Q-Linea      Mid Cap   QLINEA         330.0         330.0
# 328         Sedana Medical  First North   SEDANA         329.0         283.0
# 158               Gapwaves  First North   GAPW B         328.0         296.5
# 91             Cell Impact  First North       CI         327.0         306.0
# 133        Episurf Medical    Small Cap   EPIS B         326.0         314.0
# 404       Xbrane Biopharma      Mid Cap   XBRANE         324.5         328.0
# 139     ExpreS2ion Biotech  First North   EXPRS2         324.5         319.0
# 338              Smart Eye  First North     SEYE         323.0         296.5
# 409                  Zwipe  First North    ZWIPE         322.0         299.0
# 113         Diamyd Medical  First North   DMYD B         321.0         326.0
# 279  OptiCept Technologies  First North     OPTI         320.0         292.0
# 201                Irisity  First North     IRIS         319.0         274.0
# 360             Swedencare  First North   SECARE         318.0         295.0
# 396              Vitrolife    Large Cap     VITR         317.0         281.0
# 43              Bactiguard      Mid Cap  BACTI B         316.0         262.0
# 108             Crunchfish  First North    CFISH         315.0         325.0
# 307             Re:NewCell  First North    RENEW         314.0         322.0
# 45                Bambuser  First North    BUSER         313.0         309.0
# 281            OrganoClick  First North     ORGC         312.0         288.0
# 321    Scandinavian Enviro  First North      SES         310.5         316.0
#
#      Value Rank  Momentum Rank  EA ret std  1 Year Volatility
# 302       297.0          313.0   -1.041710           0.499167
# 328       313.0          326.0   -3.371080           0.675940
# 158       321.0          303.0   -0.461411           0.501393
# 91        306.0          308.0   -0.197534           0.794254
# 133       308.0          292.0   -1.480082           0.599328
# 404       319.0          261.0    0.172249           0.579533
# 139       301.0          288.0    0.292186           0.827458
# 338       279.0          329.0   -3.256216           0.570003
# 409       298.0          302.0   -0.741177           0.600903
# 113       326.0          246.5   -0.231016           0.824996
# 279       314.0          275.0   -1.428968           0.651995
# 201       272.0          328.0   -3.744615           0.717577
# 360       268.0          308.0   -1.319513           0.580950
# 396       280.0          304.0   -2.567292           0.542508
# 43        311.0          290.5   -0.087645           0.407694
# 108       317.0          217.0    0.230886           0.861311
# 307       324.5          201.5    0.275008           0.568926
# 45        210.0          327.0   -1.789569           0.726464
# 281       271.0          271.5    0.067674           0.648522
# 321       323.0          191.0    0.929316           0.520187

# %%
if save == "YES":
    data_date  = re.search(r'\d{4}-\d{2}-\d{2}', file_name)
    folder = '../clean_equity_data'
    exp_file_name = "rank_data_{}".format(data_date.group(0))+ ".csv"
    data_tmp.to_csv(os.path.join(folder, exp_file_name))

# %%
company('TietoEVRY', gestalt_tmp)[compact + ['Return 3m Rank', 'Return 6m Rank',
       'Return 1y Rank', 'EA ret std Rank']]
# Out:
#        Company       List    Tick  Gestalt Rank  Quality Rank  Value Rank  \
# 375  TietoEVRY  Large Cap  TIETOS          28.5          52.0         7.0
#
#      Momentum Rank  EA ret std  1 Year Volatility  Return 3m Rank  \
# 375          127.0   -0.607437           0.230957           202.0
#
#      Return 6m Rank  Return 1y Rank  EA ret std Rank
# 375           102.0           127.0            212.0

# %%
gestalt_tmp[['Momentum Rank', 'Quality Rank', 'Value Rank', 'Gestalt Rank']].corr(method = 'spearman')
# Out:
#                Momentum Rank  Quality Rank  Value Rank  Gestalt Rank
# Momentum Rank       1.000000      0.322677    0.269265      0.686825
# Quality Rank        0.322677      1.000000    0.564131      0.811014
# Value Rank          0.269265      0.564131    1.000000      0.797028
# Gestalt Rank        0.686825      0.811014    0.797028      1.000000
