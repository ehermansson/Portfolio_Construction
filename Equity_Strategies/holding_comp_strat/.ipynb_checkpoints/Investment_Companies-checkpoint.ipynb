# %% [markdown]
# # Investment Comp Screener
#
# Premia/ Discount (P/D)
#
# Sector 3 year Z Score (S3ZS)
#
# Company 3 year Z Score (C3ZS)

# %%
import yfinance as yf 
import pandas as pd
from matplotlib import pylab as plt
import numpy as np
from datetime import datetime
import math
from time import sleep
import quandl
import seaborn as sns
import sys
from scipy.stats import norm
import os
import glob
import re
import seaborn as sns

from statsmodels.distributions.empirical_distribution import ECDF
from sklearn.linear_model import LinearRegression
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.8) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
def calc_ecdf(data):
    #low is good
    ecdf= ECDF(data)
    current_perc = ecdf(data[-1])
    
    return(current_perc)

# %%
def color_negative_red(value):
    """
      Colors elements in a dateframe
      green if positive and red if
      negative. Does not color NaN
      values.
      """

    if value < 0:
        color = 'red'
    elif value > 0:
        color = 'green'
    else:
        color = 'black'

    return 'color: %s' % color

# %%
def Z_score(data):
    # not including the current observation
    std = data.iloc[:-1].std()
    mean = data.iloc[:-1].mean()
    Z = (data[-1:] - mean)/std
    return Z

# %%
def mod_Z_score(data):
    mean = np.mean(data.iloc[:-1])
    deviation_from_med = np.array(data.iloc[:-1]) - mean
    MAD = np.mean(np.abs(deviation_from_med))
    mod_Z = (data[-1:] - mean)/(MAD * 1.4826)
    return mod_Z

# %%
def signal(rank):
    if rank <= 2: return 1
    if rank <= 4: return 0.5
    if rank <= 7: return 0
    if rank <= 9: return -0.5
    if rank > 9: return -1

# %% [markdown]
# ## Data Import

# %%
path = "holding_companies_data"
arr = [x for x in os.listdir(path) if x.endswith(".csv")]

# %%
for f in arr:
    print(f)
# Out:
# 2022-08-15_kinv b_pris_historik.csv
# 2022-08-15_bure_pris_historik.csv
# 2022-08-15_lato b_pris_historik.csv
# 2022-08-15_ores_pris_historik.csv
# 2022-08-15_cred a_pris_historik.csv
# 2022-08-15_inve b_pris_historik.csv
# 2022-08-15_indu c_pris_historik.csv
# 2022-08-15_svol b_pris_historik.csv
# 2022-08-15_lund b_pris_historik.csv
# 2022-08-15_vnv_pris_historik.csv
# 2022-08-15_trac b_pris_historik.csv

# %%
for k in arr:
    if "trac" in k:
        traction = pd.read_csv(os.path.join(path,k))
    if "lund" in k:
        lundbergs = pd.read_csv(os.path.join(path,k))
    if "hav" in k:
        havsfrun = pd.read_csv(os.path.join(path,k))
    if "ores" in k:
        oresund = pd.read_csv(os.path.join(path,k))
    if "indu" in k:
        industri = pd.read_csv(os.path.join(path,k))
    if "svol" in k:
        svolder = pd.read_csv(os.path.join(path,k))
    if "bure" in k:
        bure = pd.read_csv(os.path.join(path,k))
    if "cred" in k:
        creades = pd.read_csv(os.path.join(path,k))
    if "inve" in k:
        investor = pd.read_csv(os.path.join(path,k))
    if "kinv" in k:
        kinnevik = pd.read_csv(os.path.join(path,k))
    if "vnv" in k:
        vnv = pd.read_csv(os.path.join(path,k))
    if "naxs" in k:
        naxs = pd.read_csv(os.path.join(path,k))
    if "lato" in k:
        latour = pd.read_csv(os.path.join(path,k))

# %% [markdown]
# ## Calculate Metrics

# %%
look_back = 4*252 #4 years
ST_look_back = 10

companies = [traction, lundbergs, oresund, industri,
             svolder, bure, creades, investor, kinnevik, vnv,latour]

companies_names = ['Traction', 'Lundbergsföretagen', 'Öresund', 'Industrivärden',
             'Svolder', 'Bure', 'Creades', 'Investor', 'Kinnevik', 'VNV Global','Latour']

for comp in companies:
    
    comp['DATUM'] = pd.to_datetime(comp['DATUM'])
    comp.set_index(['DATUM'], inplace=True, drop=True)
    comp['P/D']=comp['PRIS']/comp['BERÄKNAT_SUBSTANSVÄRDE'] - 1

# %%
for comp in companies:
    comp['ADJ PRIS'] = comp['PRIS']
    comp['ADJ NAV'] = comp['BERÄKNAT_SUBSTANSVÄRDE']

 #KINNEVIK ZALANDO 
ZALANDO_DATE= companies[8].index.searchsorted(datetime(2021, 5, 17))
ZALANDO_AMOUNT= 864.60 * (28/143)
companies[8]['ADJ PRIS'].iloc[ZALANDO_DATE:] = companies[8]['ADJ PRIS'].iloc[ZALANDO_DATE:] + ZALANDO_AMOUNT
companies[8]['ADJ NAV'].iloc[ZALANDO_DATE:] = companies[8]['ADJ NAV'].iloc[ZALANDO_DATE:] + ZALANDO_AMOUNT  


## CREADES SPLIT (6)
SPLIT_DATE = companies[6].index.searchsorted(datetime(2021, 4, 27))
SPLIT_FACTOR = 10
companies[6]['ADJ PRIS'].iloc[SPLIT_DATE:] = companies[6]['ADJ PRIS'].iloc[SPLIT_DATE:] * SPLIT_FACTOR
companies[6]['ADJ NAV'].iloc[SPLIT_DATE:] = companies[6]['ADJ NAV'].iloc[SPLIT_DATE:] * SPLIT_FACTOR


### INVESTOR SPLIT (7)

SPLIT_DATE_INVESTOR = companies[7].index.searchsorted(datetime(2021, 5, 19))
SPLIT_FACTOR_INVESTOR = 4
companies[7]['ADJ PRIS'].iloc[SPLIT_DATE_INVESTOR:] = companies[7]['ADJ PRIS'].iloc[SPLIT_DATE_INVESTOR:] * SPLIT_FACTOR_INVESTOR
companies[7]['ADJ NAV'].iloc[SPLIT_DATE_INVESTOR:] = companies[7]['ADJ NAV'].iloc[SPLIT_DATE_INVESTOR:] * SPLIT_FACTOR_INVESTOR

# %%
#high DSSP and HIDI is good

AVG_DISC = pd.DataFrame(latour['PRIS'].copy())
AVG_DISC['PRIS'] = 0
AVG_DISC.columns = ['AVG_DISC']

for comp in companies:

    AVG_DISC['AVG_DISC'] = AVG_DISC['AVG_DISC'] + comp['P/D']

AVG_DISC = AVG_DISC/len(companies)

for comp in companies:
    comp['SPREAD'] = comp['P/D'] - AVG_DISC['AVG_DISC']
    #comp['DSSP'] = -comp['SPREAD'].rolling(look_back).apply(lambda x: calc_ecdf(x),raw=False) + 1
    comp['S3ZS'] = -comp['SPREAD'].rolling(look_back).apply(lambda x: mod_Z_score(x),raw=False) 
    #comp['HIDI'] = -comp['R/P'].rolling(look_back).apply(lambda x: calc_ecdf(x),raw=False) + 1
    comp['C3ZS'] = -comp['P/D'].rolling(look_back).apply(lambda x: mod_Z_score(x),raw=False)
    ### USe adjusted Pris and NAV
    comp['MOM'] = (comp['ADJ PRIS'].pct_change(252) + comp['ADJ PRIS'].pct_change(126) + comp['ADJ PRIS'].pct_change(63))/3
    comp['NAV MOM'] = (comp['ADJ NAV'].pct_change(252) + comp['ADJ NAV'].pct_change(126) + comp['ADJ NAV'].pct_change(63))/3
    comp['ST'] = comp['ADJ PRIS'].pct_change(ST_look_back)

# %%
### ALTERNATIVE SHORT TERM SIGNAL
comp_tickers = ['TRAC-B.ST', 'LUND-B.ST', 'ORES.ST', 'INDU-C.ST', 'SVOL-B.ST', 'BURE.ST', 'CRED-A.ST',
               'INVE-B.ST', 'KINV-B.ST', 'VNV.ST', 'LATO-B.ST']


START_DATE = '2018-01-01'
error_count = 0
error_list = []
data_tmp = pd.DataFrame()
data_tmp['Res_Mom_1M'] = np.nan
data_tmp['Res_Mom_12M'] = np.nan
data_tmp['Res_Mom_6M'] = np.nan
index = yf.download('^OMXSPI',start=START_DATE, threads = False, progress = False)
index = index['Adj Close']

for tick in comp_tickers:
    try:
        stock = yf.download(tick,start=START_DATE, progress = False, threads = False)
        stock = stock['Adj Close']
        import_data = pd.concat([stock, index], axis = 1)
        import_data.columns = ['stock', 'index']
        import_data = import_data.dropna()
        
        ### RESIDUAL MOMENTUM
        
        long_df = import_data.copy()
        ret_df = np.log(import_data/import_data.shift()).dropna()
        reg_df = ret_df.tail(3*252)
        ## Identify Report 

        if len(reg_df)>(252):
            y = reg_df['stock']
            X = np.array(reg_df['index']).reshape(-1, 1)
            reg = LinearRegression().fit(X, y)
            beta = reg.coef_[0]
            residuals = y - reg.predict(X)
            std_residuals = residuals/residuals.std()
            data_tmp.loc[tick,"Res_Mom_1M"] = std_residuals.tail(21).sum()
            data_tmp.loc[tick,"Res_Mom_12M"] = std_residuals.tail(252).sum()
            data_tmp.loc[tick,"Res_Mom_6M"] = std_residuals.tail(126).sum()
            data_tmp.loc[tick,"Res_Mom_10d"] = std_residuals.tail(10).sum()
    except:
        error_count = error_count + 1
        error_list.append(tick)
        
data_tmp.index = companies_names

# %%
data_tmp
# Out:
#                     Res_Mom_1M  Res_Mom_12M  Res_Mom_6M  Res_Mom_10d
# Traction             -3.091739     0.598014   -2.150671    -2.836975
# Lundbergsföretagen   -0.523653     4.184052    7.140206     0.174980
# Öresund               2.384703    -9.279793    0.849830     2.858960
# Industrivärden       -3.208418     6.301531    4.888075    -1.983052
# Svolder              -2.426095    -7.032911   -1.256330     2.166187
# Bure                 -6.011434   -16.609325   -9.950123    -0.456591
# Creades              -4.744617    -7.423995  -12.268000    -1.662430
# Investor             -1.342682     7.167854   -2.884124    -0.278266
# Kinnevik             -1.443728    -5.417436   -6.720927     0.205432
# VNV Global           -4.961169   -26.721954  -21.715039    -1.956113
# Latour               -3.836627    -9.836936  -11.750358     0.071657

# %%
INV_COMP = None

for comp in companies:
    
    INV_COMP = pd.concat([INV_COMP, comp.tail(1)], axis = 0)

INV_COMP['Company'] = companies_names
INV_COMP.set_index(['Company'], inplace=True, drop=True)

INV_COMP['P/D']=-INV_COMP['P/D']

# %%
INV_COMP['VRANK'] = (INV_COMP['P/D'].rank(ascending = False) + INV_COMP['S3ZS'].rank(ascending = False) +
 INV_COMP['C3ZS'].rank(ascending = False)).rank()

INV_COMP['MRANK'] = (INV_COMP['MOM'].rank(ascending = False)+INV_COMP['NAV MOM'].rank(ascending = False)).rank()


###### NOTE NOT EQUAL WEIGHT SCORES #############

INV_COMP['CRANK'] = (0.6*INV_COMP['VRANK'] + 0.4*INV_COMP['MRANK']).rank()


#################

INV_COMP['SIGNAL'] = INV_COMP.apply(lambda x: signal(x['CRANK']), axis=1)



weight_factor = 0.5

#INV_COMP['TARGET'] = INV_COMP['DEFWEIGHT']+INV_COMP['DEFWEIGHT']*INV_COMP['SIGNAL']*weight_factor

compact = ['P/D', 'C3ZS', 'S3ZS', 'MOM', 'NAV MOM', 'VRANK', 'MRANK', 'CRANK', 'ST', 'SIGNAL']

INV_COMP = INV_COMP[compact]

# %%
average = pd.DataFrame(INV_COMP.mean(axis = 0)).transpose()
average.index = ['Average'] 
INV_COMP = pd.concat([INV_COMP, average], axis = 0)

# %% [markdown]
# ## Display Results

# %%
data_date  = re.match(r'\d{4}-\d{2}-\d{2}',f)

th_props = [
  ('font-size', '16px'),
  ('text-align', 'center'),
  ('font-weight', 'bold'),
  ('color', 'Black'),
  ('background-color', '#f7f7f9')
  ]


# Set CSS properties for td elements in dataframe
td_props = [('font-size', '16px'), ('text-align', 'center')]
#set caption props
caption_props = [('color', 'black'),('font-size', '22px'),
        ("text-align", "center"),
        ('font-weight', 'bold')]

# Set table styles
styles = [
    dict(selector="th", props=th_props),
    dict(selector="td", props=td_props),
    dict(selector="caption", props=caption_props)
]

cm_low_good = sns.diverging_palette(150, 10, s=80, l=70, n=len(INV_COMP.columns), as_cmap=True)#sns.light_palette("green", as_cmap=True)
cm_high_good = sns.diverging_palette(10, 150, s=80, l=70, n=len(INV_COMP.columns), as_cmap=True)

INV_COMP_VIEW = (INV_COMP.style
    .applymap(color_negative_red, subset=['P/D', 'MOM', 'NAV MOM'])           
    .background_gradient(axis = 0 ,subset = ['S3ZS', 'C3ZS'],cmap=cm_high_good)
    .background_gradient(axis = 0 ,subset = ['VRANK', 'MRANK','CRANK', 'ST'],cmap=cm_low_good)
    #.set_caption('Performance Metrics')
    .format({'P/D': "{:.1%}", 'S3ZS': "{:.2f}", 'C3ZS': "{:.2f}", 'MOM':"{:.1%}", 'NAV MOM': "{:.1%}",
            'Sortino': "{:.2f}", 'MAR': "{:.2f}", 'VRANK': "{:.0f}", 'MRANK': "{:.0f}", 'CRANK': "{:.0f}",
             'ST':"{:.1%}",'SIGNAL': "{:.1f}"})
    .set_caption("Investmentbolag Rank {}".format(data_date.group(0)))
    .set_table_styles(styles)
    .set_properties(**{'color': 'black'}, subset = ['C3ZS','S3ZS','VRANK', 'MRANK','CRANK', 'ST']) 
    )

# %%
INV_COMP_VIEW
# Out:
# <style type="text/css">
# #T_73adf_ th {
#   font-size: 16px;
#   text-align: center;
#   font-weight: bold;
#   color: Black;
#   background-color: #f7f7f9;
# }
# #T_73adf_ td {
#   font-size: 16px;
#   text-align: center;
# }
# #T_73adf_ caption {
#   color: black;
#   font-size: 22px;
#   text-align: center;
#   font-weight: bold;
# }
# #T_73adf_row0_col0, #T_73adf_row0_col4, #T_73adf_row1_col0, #T_73adf_row2_col0, #T_73adf_row3_col0, #T_73adf_row7_col0, #T_73adf_row8_col0, #T_73adf_row9_col0, #T_73adf_row11_col0 {
#   color: green;
# }
# #T_73adf_row0_col1 {
#   background-color: #b2dfcb;
#   color: #000000;
#   color: black;
# }
# #T_73adf_row0_col2, #T_73adf_row1_col1, #T_73adf_row7_col8, #T_73adf_row8_col1 {
#   background-color: #f2ecec;
#   color: #000000;
#   color: black;
# }
# #T_73adf_row0_col3, #T_73adf_row1_col3, #T_73adf_row1_col4, #T_73adf_row2_col3, #T_73adf_row2_col4, #T_73adf_row3_col3, #T_73adf_row3_col4, #T_73adf_row4_col0, #T_73adf_row4_col3, #T_73adf_row4_col4, #T_73adf_row5_col0, #T_73adf_row5_col3, #T_73adf_row5_col4, #T_73adf_row6_col0, #T_73adf_row6_col3, #T_73adf_row6_col4, #T_73adf_row7_col3, #T_73adf_row7_col4, #T_73adf_row8_col3, #T_73adf_row8_col4, #T_73adf_row9_col3, #T_73adf_row9_col4, #T_73adf_row10_col0, #T_73adf_row10_col3, #T_73adf_row10_col4, #T_73adf_row11_col3, #T_73adf_row11_col4 {
#   color: red;
# }
# #T_73adf_row0_col5, #T_73adf_row1_col6, #T_73adf_row8_col7 {
#   background-color: #8dd3b5;
#   color: #000000;
#   color: black;
# }
# #T_73adf_row0_col6, #T_73adf_row1_col7, #T_73adf_row8_col5 {
#   background-color: #6dc9a2;
#   color: #000000;
#   color: black;
# }
# #T_73adf_row0_col7, #T_73adf_row4_col8, #T_73adf_row7_col6, #T_73adf_row9_col1, #T_73adf_row9_col2, #T_73adf_row9_col5 {
#   background-color: #4ebf8f;
#   color: #f1f1f1;
#   color: black;
# }
# #T_73adf_row0_col8 {
#   background-color: #f2e7e8;
#   color: #000000;
#   color: black;
# }
# #T_73adf_row1_col2 {
#   background-color: #f2eaeb;
#   color: #000000;
#   color: black;
# }
# #T_73adf_row1_col5, #T_73adf_row2_col5 {
#   background-color: #bde3d2;
#   color: #000000;
#   color: black;
# }
# #T_73adf_row1_col8 {
#   background-color: #f2e4e4;
#   color: #000000;
#   color: black;
# }
# #T_73adf_row2_col1 {
#   background-color: #dfefe7;
#   color: #000000;
#   color: black;
# }
# #T_73adf_row2_col2, #T_73adf_row2_col7, #T_73adf_row4_col5, #T_73adf_row8_col6 {
#   background-color: #f2ddde;
#   color: #000000;
#   color: black;
# }
# #T_73adf_row2_col6, #T_73adf_row4_col7, #T_73adf_row6_col5 {
#   background-color: #f2b6b9;
#   color: #000000;
#   color: black;
# }
# #T_73adf_row2_col8 {
#   background-color: #f2eaea;
#   color: #000000;
#   color: black;
# }
# #T_73adf_row3_col1 {
#   background-color: #f2b1b4;
#   color: #000000;
#   color: black;
# }
# #T_73adf_row3_col2, #T_73adf_row10_col2 {
#   background-color: #f2bfc1;
#   color: #000000;
#   color: black;
# }
# #T_73adf_row3_col5, #T_73adf_row3_col7, #T_73adf_row5_col6, #T_73adf_row11_col5, #T_73adf_row11_col6, #T_73adf_row11_col7, #T_73adf_row11_col8 {
#   background-color: #f2f1f1;
#   color: #000000;
#   color: black;
# }
# #T_73adf_row3_col6, #T_73adf_row7_col7 {
#   background-color: #cde8dc;
#   color: #000000;
#   color: black;
# }
# #T_73adf_row3_col8 {
#   background-color: #f2dcdd;
#   color: #000000;
#   color: black;
# }
# #T_73adf_row4_col1 {
#   background-color: #f2bdbf;
#   color: #000000;
#   color: black;
# }
# #T_73adf_row4_col2, #T_73adf_row6_col2 {
#   background-color: #f2c1c3;
#   color: #000000;
#   color: black;
# }
# #T_73adf_row4_col6, #T_73adf_row6_col7, #T_73adf_row10_col5 {
#   background-color: #f2a3a6;
#   color: #000000;
#   color: black;
# }
# #T_73adf_row5_col1, #T_73adf_row5_col2, #T_73adf_row5_col5, #T_73adf_row5_col7, #T_73adf_row9_col6, #T_73adf_row9_col8 {
#   background-color: #f29094;
#   color: #f1f1f1;
#   color: black;
# }
# #T_73adf_row5_col8 {
#   background-color: #eff2f0;
#   color: #000000;
#   color: black;
# }
# #T_73adf_row6_col1, #T_73adf_row7_col1 {
#   background-color: #f2a6a9;
#   color: #000000;
#   color: black;
# }
# #T_73adf_row6_col6, #T_73adf_row7_col5, #T_73adf_row10_col7 {
#   background-color: #f2cacb;
#   color: #000000;
#   color: black;
# }
# #T_73adf_row6_col8 {
#   background-color: #79cda9;
#   color: #000000;
#   color: black;
# }
# #T_73adf_row7_col2 {
#   background-color: #f2bcbe;
#   color: #000000;
#   color: black;
# }
# #T_73adf_row8_col2 {
#   background-color: #c8e7d9;
#   color: #000000;
#   color: black;
# }
# #T_73adf_row8_col8 {
#   background-color: #f2d6d7;
#   color: #000000;
#   color: black;
# }
# #T_73adf_row9_col7, #T_73adf_row10_col6 {
#   background-color: #addec8;
#   color: #000000;
#   color: black;
# }
# #T_73adf_row10_col1 {
#   background-color: #f2a7aa;
#   color: #000000;
#   color: black;
# }
# #T_73adf_row10_col8 {
#   background-color: #dcede5;
#   color: #000000;
#   color: black;
# }
# #T_73adf_row11_col1 {
#   background-color: #f2d5d6;
#   color: #000000;
#   color: black;
# }
# #T_73adf_row11_col2 {
#   background-color: #f2dadb;
#   color: #000000;
#   color: black;
# }
# </style>
# <table id="T_73adf_">
#   <caption>Investmentbolag Rank 2022-08-15</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >P/D</th>
#       <th class="col_heading level0 col1" >C3ZS</th>
#       <th class="col_heading level0 col2" >S3ZS</th>
#       <th class="col_heading level0 col3" >MOM</th>
#       <th class="col_heading level0 col4" >NAV MOM</th>
#       <th class="col_heading level0 col5" >VRANK</th>
#       <th class="col_heading level0 col6" >MRANK</th>
#       <th class="col_heading level0 col7" >CRANK</th>
#       <th class="col_heading level0 col8" >ST</th>
#       <th class="col_heading level0 col9" >SIGNAL</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_73adf_level0_row0" class="row_heading level0 row0" >Traction</th>
#       <td id="T_73adf_row0_col0" class="data row0 col0" >9.6%</td>
#       <td id="T_73adf_row0_col1" class="data row0 col1" >0.94</td>
#       <td id="T_73adf_row0_col2" class="data row0 col2" >0.18</td>
#       <td id="T_73adf_row0_col3" class="data row0 col3" >-4.4%</td>
#       <td id="T_73adf_row0_col4" class="data row0 col4" >0.8%</td>
#       <td id="T_73adf_row0_col5" class="data row0 col5" >3</td>
#       <td id="T_73adf_row0_col6" class="data row0 col6" >2</td>
#       <td id="T_73adf_row0_col7" class="data row0 col7" >1</td>
#       <td id="T_73adf_row0_col8" class="data row0 col8" >-0.4%</td>
#       <td id="T_73adf_row0_col9" class="data row0 col9" >1.0</td>
#     </tr>
#     <tr>
#       <th id="T_73adf_level0_row1" class="row_heading level0 row1" >Lundbergsföretagen</th>
#       <td id="T_73adf_row1_col0" class="data row1 col0" >4.0%</td>
#       <td id="T_73adf_row1_col1" class="data row1 col1" >0.51</td>
#       <td id="T_73adf_row1_col2" class="data row1 col2" >0.14</td>
#       <td id="T_73adf_row1_col3" class="data row1 col3" >-3.1%</td>
#       <td id="T_73adf_row1_col4" class="data row1 col4" >-3.8%</td>
#       <td id="T_73adf_row1_col5" class="data row1 col5" >4</td>
#       <td id="T_73adf_row1_col6" class="data row1 col6" >3</td>
#       <td id="T_73adf_row1_col7" class="data row1 col7" >2</td>
#       <td id="T_73adf_row1_col8" class="data row1 col8" >-0.2%</td>
#       <td id="T_73adf_row1_col9" class="data row1 col9" >1.0</td>
#     </tr>
#     <tr>
#       <th id="T_73adf_level0_row2" class="row_heading level0 row2" >Öresund</th>
#       <td id="T_73adf_row2_col0" class="data row2 col0" >2.2%</td>
#       <td id="T_73adf_row2_col1" class="data row2 col1" >0.64</td>
#       <td id="T_73adf_row2_col2" class="data row2 col2" >-0.04</td>
#       <td id="T_73adf_row2_col3" class="data row2 col3" >-17.0%</td>
#       <td id="T_73adf_row2_col4" class="data row2 col4" >-14.3%</td>
#       <td id="T_73adf_row2_col5" class="data row2 col5" >4</td>
#       <td id="T_73adf_row2_col6" class="data row2 col6" >9</td>
#       <td id="T_73adf_row2_col7" class="data row2 col7" >7</td>
#       <td id="T_73adf_row2_col8" class="data row2 col8" >-0.5%</td>
#       <td id="T_73adf_row2_col9" class="data row2 col9" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_73adf_level0_row3" class="row_heading level0 row3" >Industrivärden</th>
#       <td id="T_73adf_row3_col0" class="data row3 col0" >9.0%</td>
#       <td id="T_73adf_row3_col1" class="data row3 col1" >

# %%
import dataframe_image as dfi
exp_file_name = "results/inv_comp_{}".format(data_date.group(0)) + ".png"
dfi.export(INV_COMP_VIEW, exp_file_name)

# %%
#### ERC weighting

from typing import Tuple
import numpy as np
from scipy.stats import norm
import ezodf
import scipy.optimize as sco
import scipy

from sklearn.covariance import LedoitWolf



def Optimize_Portfolio(data ,lookback = 126, risk_free = 0, objective = 'Kelly'):

    ret = (data-1).mean()
    #cov_fit = LedoitWolf().fit(data)
    #cov = cov_fit.covariance_
    cov, average_cor, shrink = shrinkage_EMW(data, lookback = lookback)
    #cov = PCA_cov(data, N=5)
   
  
    if objective == 'Max Div':
        num_assets = len(data.columns)
        args = (cov)
        constraints = ({'type':'ineq', 'fun': lambda x: x},#all elements greater than one
                  #{'type':'ineq', 'fun': lambda x: 1 - np.sum(x)} # sum <= 1
                  {'type': 'eq', 'fun': lambda x: np.sum(x) - 1}) 
        
        result = sco.minimize(calc_diversification_ratio, num_assets*[1./num_assets,], args=args, 
                              method='SLSQP', constraints=constraints, tol = 0.0000000000000000000000001)
        
    elif objective == "min var":
        num_assets = len(data.columns)
        args = (cov)
        constraints = ({'type':'ineq', 'fun': lambda x: x},#all elements greater than one
                  #{'type':'ineq', 'fun': lambda x: 1 - np.sum(x)} # sum <= 1
                  {'type': 'eq', 'fun': lambda x: np.sum(x) - 1}) 
        
        result = sco.minimize(port_var, num_assets*[1./num_assets,], args=args, 
                              method='SLSQP', constraints=constraints, tol = 0.0000000000000000000000001)
    elif objective == "erc":
        num_assets = len(data.columns) 
        args = (cov)
        constraints = ({'type':'ineq', 'fun': lambda x: x},#all elements greater than one
                  #{'type':'ineq', 'fun': lambda x: 1 - np.sum(x)} # sum <= 1
                  {'type': 'eq', 'fun': lambda x: np.sum(x) - 1},
                      {'type':'ineq', 'fun': lambda x: x-(1/num_assets)*0.7}, # min position
                      {'type':'ineq', 'fun': lambda x: (1/num_assets)*1.3-x}) # max position
        
        result = sco.minimize(erc, num_assets*[1./num_assets,], args=args, 
                              method='SLSQP', constraints=constraints, tol = 0.0000000000000000000000001)
        

    return (result)




def port_var(weights, cov):
    var = weights.dot(cov).dot(weights)
    return(var)

def port_ret(weights, ret, risk_free = 0):
    #needs to be array
    ret = ret - risk_free
    port_ret = weights.dot(ret)
    return(port_ret)

def risk_parity(data):
    vol = np.log((data)).std()

    sum_vol = 0
    for i in range(len(vol)):
        sum_vol =sum_vol + (1/vol[i])
    
    weight = []
    for i in range(len(vol)):
        w = (1/vol[i])/(sum_vol)
        weight.append(w)
   
    weight = [round(num, 2) for num in weight]
    return(weight)




def calc_diversification_ratio(weights, cov):
    # average weighted vol
    w_vol = np.dot(np.sqrt(np.diag(cov)), weights.T)
    # portfolio vol
    port_vol = np.sqrt(port_var(weights, cov))
    
    diversification_ratio = w_vol/port_vol
    # return negative for minimization problem (maximize = minimize -)
    return -diversification_ratio

def erc(weights, cov):
        # these are non normalized risk contributions, i.e. not regularized
        # by total risk, seems to help numerically
        risk_contributions = np.dot(weights, cov) * weights
        a = np.reshape(risk_contributions, (len(risk_contributions), 1))
        # broadcasts so you get pairwise differences in risk contributions
        risk_diffs = a - a.transpose()
        sum_risk_diffs_squared = np.sum(np.square(np.ravel(risk_diffs)))
        # https://stackoverflow.com/a/36685019/1451311
        return sum_risk_diffs_squared #/ scale_factorcov
    

def shrinkage_EMW(returns_tmp: np.array, lookback = 126) -> Tuple[np.array, float, float]:
    """Shrinks sample covariance matrix towards constant correlation unequal variance matrix.
    Ledoit & Wolf ("Honey, I shrunk the sample covariance matrix", Portfolio Management, 30(2004),
    110-119) optimal asymptotic shrinkage between 0 (sample covariance matrix) and 1 (constant
    sample average correlation unequal sample variance matrix).
    Paper:
    http://www.ledoit.net/honey.pdf
    Matlab code:
    https://www.econ.uzh.ch/dam/jcr:ffffffff-935a-b0d6-ffff-ffffde5e2d4e/covCor.m.zip
    Special thanks to Evgeny Pogrebnyak https://github.com/epogrebnyak
    :param returns:
        t, n - returns of t observations of n shares.
    :return:
        Covariance matrix, sample average correlation, shrinkage.
    """
    returns = returns_tmp.tail(lookback).values
    t, n = returns.shape
    mean_returns = np.mean(returns, axis=0, keepdims=True) # make EWMA
    returns -= mean_returns
    COV_tmp = returns_tmp.ewm(span = lookback).cov()
    idx = returns_tmp.index.get_level_values(0)[-1]
    sample_cov = COV_tmp[COV_tmp.index.get_level_values(0) == idx]
    sample_cov = sample_cov.values
    #sample_cov = returns.transpose() @ returns / t

    # sample average correlation
    var = np.diag(sample_cov).reshape(-1, 1)
    sqrt_var = var ** 0.5
    unit_cor_var = sqrt_var * sqrt_var.transpose()
    average_cor = ((sample_cov / unit_cor_var).sum() - n) / n / (n - 1)
    prior = average_cor * unit_cor_var
    np.fill_diagonal(prior, var)

    # pi-hat
    y = returns ** 2
    phi_mat = (y.transpose() @ y) / t - sample_cov ** 2
    phi = phi_mat.sum()

    # rho-hat
    theta_mat = ((returns ** 3).transpose() @ returns) / t - var * sample_cov
    np.fill_diagonal(theta_mat, 0)
    rho = (
        np.diag(phi_mat).sum()
        + average_cor * (1 / sqrt_var @ sqrt_var.transpose() * theta_mat).sum()
    )

    # gamma-hat
    gamma = np.linalg.norm(sample_cov - prior, "fro") ** 2

    # shrinkage constant
    kappa = (phi - rho) / gamma
    shrink = max(0, min(1, kappa / t))

    # estimator
    sigma = shrink * prior + (1 - shrink) * sample_cov

    return sigma, average_cor, shrink

# %%
def ERC_INV(TICKERS, lookback = 126):
    
    prices_df = pd.DataFrame()
    for tick in TICKERS:
    
        price = yf.download(tick,start='2000-01-01', progress = False, threads = False)
        price = price['Adj Close']
        prices_df[tick] = price
    
    log_ret = np.log(prices_df) - np.log(prices_df.shift(1))
    log_ret = log_ret.dropna()
    weight = Optimize_Portfolio(log_ret, lookback = lookback, objective='erc')['x'].round(3)

    return(weight)

# %%
# CONSTRUCT THE PORTFOLIO THROUGH 50% OF ERC AND 50% OF L/S PORTFOLIO
INV_COMP_ERC = INV_COMP[:-1].copy()

INV_COMP_ERC.loc[:,'ERC_weight'] = ERC_INV(comp_tickers)

# %%
portf_w = 0.5*(INV_COMP_ERC['SIGNAL'] * INV_COMP_ERC['ERC_weight'])  + INV_COMP_ERC['ERC_weight']

INV_COMP_ERC['Portfolio_w'] = (portf_w/portf_w.sum()).round(2)

# %%
INV_COMP_ERC
# Out:
#                          P/D      C3ZS      S3ZS       MOM   NAV MOM  VRANK  \
# Traction            0.095676  0.940947  0.175866 -0.044042  0.007571    3.0
# Lundbergsföretagen  0.039548  0.507081  0.144346 -0.031064 -0.038429    4.5
# Öresund             0.022356  0.643097 -0.040225 -0.169540 -0.142540    4.5
# Industrivärden      0.089972 -0.102313 -0.495892 -0.063514 -0.077749    6.0
# Svolder            -0.011502  0.023733 -0.475100 -0.284180 -0.254788    7.0
# Bure               -0.211278 -0.456397 -1.200060 -0.101012 -0.124369   11.0
# Creades            -0.330138 -0.212212 -0.462816 -0.113005 -0.188457    9.0
# Investor            0.154492 -0.211703 -0.533935 -0.027717 -0.010188    8.0
# Kinnevik            0.181526  0.508858  0.581542 -0.147302 -0.080182    2.0
# VNV Global          0.565649  1.581877  1.691261 -0.438649 -0.303218    1.0
# Latour             -0.370759 -0.202429 -0.497560 -0.062227 -0.037359   10.0
#
#                     MRANK  CRANK        ST  SIGNAL  ERC_weight  Portfolio_w
# Traction              2.0    1.0 -0.004184     1.0       0.118         0.17
# Lundbergsföretagen    3.0    2.0 -0.002331     1.0       0.105         0.15
# Öresund               9.0    7.0 -0.005415     0.0       0.118         0.11
# Industrivärden        5.0    6.0  0.001956     0.0       0.115         0.11
# Svolder              10.0    9.0 -0.062549    -0.5       0.075         0.05
# Bure                  6.0   11.0 -0.009856    -1.0       0.064         0.03
# Creades               8.0   10.0 -0.047721    -1.0       0.070         0.03
# Investor              1.0    5.0 -0.006757     0.0       0.118         0.11
# Kinnevik              7.0    3.0  0.005202     0.5       0.071         0.09
# VNV Global           11.0    4.0  0.043509     0.5       0.064         0.08
# Latour                4.0    8.0 -0.014986    -0.5       0.081         0.06
