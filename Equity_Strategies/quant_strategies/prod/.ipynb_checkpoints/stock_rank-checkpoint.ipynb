# %%
import pandas as pd
from matplotlib import pylab as plt
import numpy as np
from datetime import datetime
import math
import seaborn as sns
import sys
import sys
import re
import os.path

# %% [markdown]
# ## data import

# %%
file_name =  "clean_data_2021-11-29.csv"
folder = "../clean_equity_data/"
data_tmp = pd.read_csv(folder + file_name)

# %%
### MOMENTUM
data_mom = data_tmp.copy()
data_mom = data_mom.loc[(data_mom['Industry'] != 'Holding Companies')]


### GESTALT
data_gestalt = data_tmp.copy()
data_gestalt = data_gestalt.loc[(data_tmp['Sector'] != 'Financials')]

# %% [markdown]
# ### Momentum Rank

# %%
# RANK ON DIFFERENT METRICS 

data_mom['3m Rank'] = data_mom['Return 3m'].rank(ascending = False)
data_mom['6m Rank'] = data_mom['Return 6m'].rank(ascending = False)
data_mom['1y Rank'] = data_mom['Return 1y'].rank(ascending = False)
data_mom['EA Rank'] = data_mom['EA ret'].rank(ascending = False)
data_mom['EA Std Rank'] = data_mom['EA ret std'].rank(ascending = False)
data_mom['Volatility Rank'] = data_mom['1 Year Volatility'].rank(ascending = True)
data_mom['MAD Rank'] = data_mom['1 Year Volatility'].rank(ascending = True)

# MOMENTUM WITH WOLATILITY AND EA
data_mom['Momentum Rank'] = (data_mom['3m Rank'] + data_mom['6m Rank'] +  data_mom['1y Rank'] + data_mom['Volatility Rank'] + data_mom['EA Std Rank']).rank(ascending = True)

# %% [markdown]
# ### Gestalt Imputation and Rank

# %%
# MANAGE NaNs and NEGATIVE EARNINGS  

# set nan to median, only fundamental data
columns = ['P/E', 'EV/EBIT', 'P/FCF', 'P/S', 'P/B', 'ROC', 'ROE',
            'GPA', 'Assets Turn', 'FCFROE']
for i in columns: 
    data_gestalt.loc[data_gestalt[i].isna() ,i] = data_gestalt[i].median()


    
# set negative values to max
for i in ['P/E', 'EV/EBIT', 'P/FCF', 'P/S', 'P/B']:
    data_gestalt.loc[data_gestalt[i] < 0 ,i] = data_gestalt[i].max()
    
# set nan yield & vol to 0
data_gestalt.loc[data_gestalt['Yield'].isna(),'Yield'] = 0

# %%
data_gestalt['3m Rank'] = data_gestalt['Return 3m'].rank(ascending = False)
data_gestalt['6m Rank'] = data_gestalt['Return 6m'].rank(ascending = False)
data_gestalt['1y Rank'] = data_gestalt['Return 1y'].rank(ascending = False)
data_gestalt['EA Rank'] = data_gestalt['EA ret'].rank(ascending = False)
data_gestalt['EA Std Rank'] = data_gestalt['EA ret std'].rank(ascending = False)


data_gestalt['Momentum Rank'] = (data_gestalt['3m Rank'] + data_gestalt['6m Rank'] + 
                                 data_gestalt['1y Rank'] + data_gestalt['EA Std Rank']).rank(ascending = True)



# Ranking where lower value is better
for i in ['P/E', 'P/B', 'P/S', 'P/FCF', 'EV/EBIT']:
    data_gestalt[i +' Rank'] = data_gestalt[i].rank()
    

for i in ['Yield', 'ROE', 'ROC', 'FCFROE', 'GPA', 'Assets Turn']:
    data_gestalt[i + ' Rank'] = (-data_gestalt[i]).rank()
    
# Composite ranks
data_gestalt['Quality Rank'] = (data_gestalt['ROE Rank'] + data_gestalt['ROC Rank'] + data_gestalt['FCFROE Rank'] + 
                        data_gestalt['GPA Rank'] + data_gestalt['Assets Turn Rank']).rank()

data_gestalt['Value Rank'] = (data_gestalt['P/E Rank'] + data_gestalt['P/B Rank'] + data_gestalt['P/S Rank'] + data_gestalt['P/FCF Rank'] + 
                      data_gestalt['EV/EBIT Rank'] + data_gestalt['Yield Rank']).rank()
 

data_gestalt['Gestalt Rank'] = ((data_gestalt['Value Rank'] + data_gestalt['Momentum Rank'] + data_gestalt['Quality Rank'])).rank()

# %% [markdown]
# ### Data Error Check

# %%
#data_mom.isna().sum()
data_gestalt.isna().sum()
# Out:
# Unnamed: 0                      0
# Börsdata ID                     0
# Company                         0
# Industry                        0
# Volume                          0
# P/FCF                           0
# Assets Turn                     0
# Gross profit                   11
# Tot. Assets                     2
# ROC                             0
# Market Cap                      0
# Volatility                      0
# ROE                             0
# FCF                             2
# Total Equity                    2
# Return 3m                       0
# Return 6m                       0
# Return 1y                       0
# Country                         0
# List                            0
# Tick                            0
# EV/EBIT                         0
# Last Report                     2
# Yahoo                           0
# Performance - Perform. 1y.1    26
# Yield                           0
# P/E                             0
# P/S                             0
# P/B                             0
# Info - Time                     0
# Info - Stock price              0
# Info - Report                   0
# Sector                          0
# FCFROE                          0
# GPA                             0
# EA ret                          0
# EA ret std                      0
# 1 Year Volatility               0
# 1 Year MAD                      0
# EA Volatility                   0
# 3m Rank                         0
# 6m Rank                         0
# 1y Rank                         0
# EA Rank                         0
# EA Std Rank                     0
# Momentum Rank                   0
# P/E Rank                        0
# P/B Rank                        0
# P/S Rank                        0
# P/FCF Rank                      0
# EV/EBIT Rank                    0
# Yield Rank                      0
# ROE Rank                        0
# ROC Rank                        0
# FCFROE Rank                     0
# GPA Rank                        0
# Assets Turn Rank                0
# Quality Rank                    0
# Value Rank                      0
# Gestalt Rank                    0
# dtype: int64

# %% [markdown]
# ### Sorting

# %%
#### MOMENTUM DATA FRAME
momentum_tmp = data_mom.sort_values(by=['Momentum Rank'])
#### Gestalt Data Frame
gestalt_tmp = data_gestalt.sort_values(by=['Gestalt Rank'])

# %%
compact = ['Company', 'List','Tick', 'Gestalt Rank', 'Quality Rank', 'Value Rank', 'Momentum Rank', 'EA ret std', '1 Year Volatility']
compact_mom = ['Company', 'List','Tick','Momentum Rank','EA ret std', '1 Year Volatility']
# numbers of stocks to select for diff strategies

stocks = 20
## MOMENTUM ##
momentum = momentum_tmp[0:stocks]
Momentum = momentum[compact_mom]


## TRIPLE SORT ##
gestalt = gestalt_tmp[0:stocks]
gestalt = gestalt[compact]

# %% [markdown]
# ### Print Stock Selection

# %%
#gestalt 
th_props = [
  ('font-size', '14px'),
  ('text-align', 'center'),
  ('font-weight', 'bold'),
  ('color', 'Black'),
  ('background-color', '#f7f7f9')
  ]
# Set CSS properties for td elements in dataframe
td_props = [('font-size', '12px'), ('text-align', 'center')]
#set caption props
caption_props = [('color', 'black'),('font-size', '22px'),
        ("text-align", "center"),
        ('font-weight', 'bold')]
# Set table styles
styles = [
    dict(selector="th", props=th_props),
    dict(selector="td", props=td_props),
    dict(selector="caption", props=caption_props)
]
gestalt.index = range(1, len(gestalt)+1)
gestalt_view = (gestalt.style.apply(lambda x: ['background: lightgreen' if x.name in range(1, 10+1) 
                              else '' for i in x], axis=1).set_table_styles(styles)
                 .format({'EA ret std': "{:.1f}",'1 Year Volatility': "{:.1%}"})
                 .set_caption("Gestalt"))
gestalt_view
# Out:
# <style type="text/css">
# #T_dd6fc_ th {
#   font-size: 14px;
#   text-align: center;
#   font-weight: bold;
#   color: Black;
#   background-color: #f7f7f9;
# }
# #T_dd6fc_ td {
#   font-size: 12px;
#   text-align: center;
# }
# #T_dd6fc_ caption {
#   color: black;
#   font-size: 22px;
#   text-align: center;
#   font-weight: bold;
# }
# #T_dd6fc_row0_col0, #T_dd6fc_row0_col1, #T_dd6fc_row0_col2, #T_dd6fc_row0_col3, #T_dd6fc_row0_col4, #T_dd6fc_row0_col5, #T_dd6fc_row0_col6, #T_dd6fc_row0_col7, #T_dd6fc_row0_col8, #T_dd6fc_row1_col0, #T_dd6fc_row1_col1, #T_dd6fc_row1_col2, #T_dd6fc_row1_col3, #T_dd6fc_row1_col4, #T_dd6fc_row1_col5, #T_dd6fc_row1_col6, #T_dd6fc_row1_col7, #T_dd6fc_row1_col8, #T_dd6fc_row2_col0, #T_dd6fc_row2_col1, #T_dd6fc_row2_col2, #T_dd6fc_row2_col3, #T_dd6fc_row2_col4, #T_dd6fc_row2_col5, #T_dd6fc_row2_col6, #T_dd6fc_row2_col7, #T_dd6fc_row2_col8, #T_dd6fc_row3_col0, #T_dd6fc_row3_col1, #T_dd6fc_row3_col2, #T_dd6fc_row3_col3, #T_dd6fc_row3_col4, #T_dd6fc_row3_col5, #T_dd6fc_row3_col6, #T_dd6fc_row3_col7, #T_dd6fc_row3_col8, #T_dd6fc_row4_col0, #T_dd6fc_row4_col1, #T_dd6fc_row4_col2, #T_dd6fc_row4_col3, #T_dd6fc_row4_col4, #T_dd6fc_row4_col5, #T_dd6fc_row4_col6, #T_dd6fc_row4_col7, #T_dd6fc_row4_col8, #T_dd6fc_row5_col0, #T_dd6fc_row5_col1, #T_dd6fc_row5_col2, #T_dd6fc_row5_col3, #T_dd6fc_row5_col4, #T_dd6fc_row5_col5, #T_dd6fc_row5_col6, #T_dd6fc_row5_col7, #T_dd6fc_row5_col8, #T_dd6fc_row6_col0, #T_dd6fc_row6_col1, #T_dd6fc_row6_col2, #T_dd6fc_row6_col3, #T_dd6fc_row6_col4, #T_dd6fc_row6_col5, #T_dd6fc_row6_col6, #T_dd6fc_row6_col7, #T_dd6fc_row6_col8, #T_dd6fc_row7_col0, #T_dd6fc_row7_col1, #T_dd6fc_row7_col2, #T_dd6fc_row7_col3, #T_dd6fc_row7_col4, #T_dd6fc_row7_col5, #T_dd6fc_row7_col6, #T_dd6fc_row7_col7, #T_dd6fc_row7_col8, #T_dd6fc_row8_col0, #T_dd6fc_row8_col1, #T_dd6fc_row8_col2, #T_dd6fc_row8_col3, #T_dd6fc_row8_col4, #T_dd6fc_row8_col5, #T_dd6fc_row8_col6, #T_dd6fc_row8_col7, #T_dd6fc_row8_col8, #T_dd6fc_row9_col0, #T_dd6fc_row9_col1, #T_dd6fc_row9_col2, #T_dd6fc_row9_col3, #T_dd6fc_row9_col4, #T_dd6fc_row9_col5, #T_dd6fc_row9_col6, #T_dd6fc_row9_col7, #T_dd6fc_row9_col8 {
#   background: lightgreen;
# }
# </style>
# <table id="T_dd6fc_">
#   <caption>Gestalt</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Company</th>
#       <th class="col_heading level0 col1" >List</th>
#       <th class="col_heading level0 col2" >Tick</th>
#       <th class="col_heading level0 col3" >Gestalt Rank</th>
#       <th class="col_heading level0 col4" >Quality Rank</th>
#       <th class="col_heading level0 col5" >Value Rank</th>
#       <th class="col_heading level0 col6" >Momentum Rank</th>
#       <th class="col_heading level0 col7" >EA ret std</th>
#       <th class="col_heading level0 col8" >1 Year Volatility</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dd6fc_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_dd6fc_row0_col0" class="data row0 col0" >Poolia</td>
#       <td id="T_dd6fc_row0_col1" class="data row0 col1" >Small Cap</td>
#       <td id="T_dd6fc_row0_col2" class="data row0 col2" >POOL B</td>
#       <td id="T_dd6fc_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_dd6fc_row0_col4" class="data row0 col4" >21.000000</td>
#       <td id="T_dd6fc_row0_col5" class="data row0 col5" >29.000000</td>
#       <td id="T_dd6fc_row0_col6" class="data row0 col6" >18.500000</td>
#       <td id="T_dd6fc_row0_col7" class="data row0 col7" >1.3</td>
#       <td id="T_dd6fc_row0_col8" class="data row0 col8" >45.0%</td>
#     </tr>
#     <tr>
#       <th id="T_dd6fc_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_dd6fc_row1_col0" class="data row1 col0" >Björn Borg</td>
#       <td id="T_dd6fc_row1_col1" class="data row1 col1" >Small Cap</td>
#       <td id="T_dd6fc_row1_col2" class="data row1 col2" >BORG</td>
#       <td id="T_dd6fc_row1_col3" class="data row1 col3" >2.000000</td>
#       <td id="T_dd6fc_row1_col4" class="data row1 col4" >25.000000</td>
#       <td id="T_dd6fc_row1_col5" class="data row1 col5" >42.000000</td>
#       <td id="T_dd6fc_row1_col6" class="data row1 col6" >14.500000</td>
#       <td id="T_dd6fc_row1_col7" class="data row1 col7" >3.2</td>
#       <td id="T_dd6fc_row1_col8" class="data row1 col8" >36.7%</td>
#     </tr>
#     <tr>
#       <th id="T_dd6fc_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_dd6fc_row2_col0" class="data row2 col0" >Ferronordic</td>
#       <td id="T_dd6fc_row2_col1" class="data row2 col1" >Mid Cap</td>
#       <td id="T_dd6fc_row2_col2" class="data row2 col2" >FNM</td>
#       <td id="T_dd6fc_row2_col3" class="data row2 col3" >3.000000</td>
#       <td id="T_dd6fc_row2_col4" class="data row2 col4" >22.000000</td>
#       <td id="T_dd6fc_row2_col5" class="data row2 col5" >44.000000</td>
#       <td id="T_dd6fc_row2_col6" class="data row2 col6" >25.000000</td>
#       <td id="T_dd6fc_row2_col7" class="data row2 col7" >1.6</td>
#       <td id="T_dd6fc_row2_col8" class="data row2 col8" >36.8%</td>
#     </tr>
#     <tr>
#       <th id="T_dd6fc_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_dd6fc_row3_col0" class="data row3 col0" >BE Group</td>
#       <td id="T_dd6fc_row3_col1" class="data row3 col1" >Small Cap</td>
#       <td id="T_dd6fc_row3_col2" class="data row3 col2" >BEGR</td>
#       <td id="T_dd6fc_row3_col3" class="data row3 col3" >4.000000</td>
#       <td id="T_dd6fc_row3_col4" class="data row3 col4" >37.000000</td>
#       <td id="T_dd6fc_row3_col5" class="data row3 col5" >19.000000</td>
#       <td id="T_dd6fc_row3_col6" class="data row3 col6" >43.000000</td>
#       <td id="T_dd6fc_row3_col7" class="data row3 col7" >-1.2</td>
#       <td id="T_dd6fc_row3_col8" class="data row3 col8" >47.0%</td>
#     </tr>
#     <tr>
#       <th id="T_dd6fc_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_dd6fc_row4_col0" class="data row4 col0" >Nilörngruppen</td>
#       <td id="T_dd6fc_row4_col1" class="data row4 col1" >Small Cap</td>
#       <td id="T_dd6fc_row4_col2" class="data row4 col2" >NIL B</td>
#       <td id="T_dd6fc_row4_col3" class="data row4 col3" >5.000000</td>
#       <td id="T_dd6fc_row4_col4" class="data row4 col4" >14.000000</td>
#       <td id="T_dd6fc_row4_col5" class="data row4 col5" >34.500000</td>
#       <td id="T_dd6fc_row4_col6" class="data row4 col6" >59.000000</td>
#       <td id="T_dd6fc_row4_col7" class="data row4 col7" >4.2</td>
#       <td id="T_dd6fc_row4_col8" class="data row4 col8" >40.7%</td>
#     </tr>
#     <tr>
#       <th id="T_dd6fc_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_dd6fc_row5_col0" class="data row5 col0" >B3 Consulting</td>
#       <td id="T_dd6fc_row5_col1" class="data row5 col1" >Small Cap</td>
#       <td id="T_dd6fc_row5_col2" class="data row5 col2" >B3</td>
#       <td id="T_dd6fc_row5_col3" class="data row5 col3" >6.000000</td>
#       <td id="T_dd6fc_row5_col4" class="data row5 col4" >27.500000</td>
#       <td id="T_dd6fc_row5_col5" class="data row5 col5" >71.000000</td>
#       <td id="T_dd6fc_row5_col6" class="data row5 col6" >39.000000</td>
#       <td id="T_dd6fc_row5_col7" class="data row5 col7" >2.9</td>
#       <td id="T_dd6fc_row5_col8" class="data row5 col8" >40.5%</td>
#     </tr>
#     <tr>
#       <th id="T_dd6fc_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_dd6fc_row6_col0" class="data row6 col0" >Transtema</td>
#       <td id="T_dd6fc_row6_col1" class="data row6 col1" >Small Cap</td>
#       <td id="T_dd6fc_row6_col2" class="data row6 col2" >TRANS</td>
#       <td id="T_dd6fc_row6_col3" class="data row6 col3" >7.000000</td>
#       <td id="T_dd6fc_row6_col4" class="data row6 col4" >4.000000</td>
#       <td id="T_dd6fc_row6_col5" class="data row6 col5" >135.000000</td>
#       <td id="T_dd6fc_row6_col6" class="data row6 col6" >2.000000</td>
#       <td id="T_dd6fc_row6_col7" class="data row6 col7" >2.8</td>
#       <td id="T_dd6fc_row6_col8" class="data row6 col8" >44.2%</td>
#     </tr>
#     <tr>
#       <th id="T_dd6fc_level0_row7" class="row_heading level0 row7" >8</th>
#       <td

# %%
th_props = [
  ('font-size', '14px'),
  ('text-align', 'center'),
  ('font-weight', 'bold'),
  ('color', 'Black'),
  ('background-color', '#f7f7f9')
  ]
# Set CSS properties for td elements in dataframe
td_props = [('font-size', '12px'), ('text-align', 'center')]
#set caption props
caption_props = [('color', 'black'),('font-size', '22px'),
        ("text-align", "center"),
        ('font-weight', 'bold')]
# Set table styles
styles = [
    dict(selector="th", props=th_props),
    dict(selector="td", props=td_props),
    dict(selector="caption", props=caption_props)
]
Momentum.index = range(1,len(Momentum)+1)
Momentum_view = (Momentum.style.apply(lambda x: ['background: lightgreen' if x.name in range(1,10+1) 
                              else '' for i in x], axis=1).set_table_styles(styles).format({'EA ret std': "{:.1f}",'1 Year Volatility': "{:.1%}"})
                 .set_caption("Focused Momentum"))
Momentum_view
# Out:
# <style type="text/css">
# #T_f11ab_ th {
#   font-size: 14px;
#   text-align: center;
#   font-weight: bold;
#   color: Black;
#   background-color: #f7f7f9;
# }
# #T_f11ab_ td {
#   font-size: 12px;
#   text-align: center;
# }
# #T_f11ab_ caption {
#   color: black;
#   font-size: 22px;
#   text-align: center;
#   font-weight: bold;
# }
# #T_f11ab_row0_col0, #T_f11ab_row0_col1, #T_f11ab_row0_col2, #T_f11ab_row0_col3, #T_f11ab_row0_col4, #T_f11ab_row0_col5, #T_f11ab_row1_col0, #T_f11ab_row1_col1, #T_f11ab_row1_col2, #T_f11ab_row1_col3, #T_f11ab_row1_col4, #T_f11ab_row1_col5, #T_f11ab_row2_col0, #T_f11ab_row2_col1, #T_f11ab_row2_col2, #T_f11ab_row2_col3, #T_f11ab_row2_col4, #T_f11ab_row2_col5, #T_f11ab_row3_col0, #T_f11ab_row3_col1, #T_f11ab_row3_col2, #T_f11ab_row3_col3, #T_f11ab_row3_col4, #T_f11ab_row3_col5, #T_f11ab_row4_col0, #T_f11ab_row4_col1, #T_f11ab_row4_col2, #T_f11ab_row4_col3, #T_f11ab_row4_col4, #T_f11ab_row4_col5, #T_f11ab_row5_col0, #T_f11ab_row5_col1, #T_f11ab_row5_col2, #T_f11ab_row5_col3, #T_f11ab_row5_col4, #T_f11ab_row5_col5, #T_f11ab_row6_col0, #T_f11ab_row6_col1, #T_f11ab_row6_col2, #T_f11ab_row6_col3, #T_f11ab_row6_col4, #T_f11ab_row6_col5, #T_f11ab_row7_col0, #T_f11ab_row7_col1, #T_f11ab_row7_col2, #T_f11ab_row7_col3, #T_f11ab_row7_col4, #T_f11ab_row7_col5, #T_f11ab_row8_col0, #T_f11ab_row8_col1, #T_f11ab_row8_col2, #T_f11ab_row8_col3, #T_f11ab_row8_col4, #T_f11ab_row8_col5, #T_f11ab_row9_col0, #T_f11ab_row9_col1, #T_f11ab_row9_col2, #T_f11ab_row9_col3, #T_f11ab_row9_col4, #T_f11ab_row9_col5 {
#   background: lightgreen;
# }
# </style>
# <table id="T_f11ab_">
#   <caption>Focused Momentum</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Company</th>
#       <th class="col_heading level0 col1" >List</th>
#       <th class="col_heading level0 col2" >Tick</th>
#       <th class="col_heading level0 col3" >Momentum Rank</th>
#       <th class="col_heading level0 col4" >EA ret std</th>
#       <th class="col_heading level0 col5" >1 Year Volatility</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f11ab_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_f11ab_row0_col0" class="data row0 col0" >Samhällsbyggnadsbolag B</td>
#       <td id="T_f11ab_row0_col1" class="data row0 col1" >Large Cap</td>
#       <td id="T_f11ab_row0_col2" class="data row0 col2" >SBB B</td>
#       <td id="T_f11ab_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_f11ab_row0_col4" class="data row0 col4" >1.1</td>
#       <td id="T_f11ab_row0_col5" class="data row0 col5" >27.2%</td>
#     </tr>
#     <tr>
#       <th id="T_f11ab_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_f11ab_row1_col0" class="data row1 col0" >NP3</td>
#       <td id="T_f11ab_row1_col1" class="data row1 col1" >Mid Cap</td>
#       <td id="T_f11ab_row1_col2" class="data row1 col2" >NP3</td>
#       <td id="T_f11ab_row1_col3" class="data row1 col3" >2.000000</td>
#       <td id="T_f11ab_row1_col4" class="data row1 col4" >1.5</td>
#       <td id="T_f11ab_row1_col5" class="data row1 col5" >36.2%</td>
#     </tr>
#     <tr>
#       <th id="T_f11ab_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_f11ab_row2_col0" class="data row2 col0" >Transtema</td>
#       <td id="T_f11ab_row2_col1" class="data row2 col1" >Small Cap</td>
#       <td id="T_f11ab_row2_col2" class="data row2 col2" >TRANS</td>
#       <td id="T_f11ab_row2_col3" class="data row2 col3" >3.000000</td>
#       <td id="T_f11ab_row2_col4" class="data row2 col4" >2.8</td>
#       <td id="T_f11ab_row2_col5" class="data row2 col5" >44.2%</td>
#     </tr>
#     <tr>
#       <th id="T_f11ab_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_f11ab_row3_col0" class="data row3 col0" >NOTE</td>
#       <td id="T_f11ab_row3_col1" class="data row3 col1" >Small Cap</td>
#       <td id="T_f11ab_row3_col2" class="data row3 col2" >NOTE</td>
#       <td id="T_f11ab_row3_col3" class="data row3 col3" >4.000000</td>
#       <td id="T_f11ab_row3_col4" class="data row3 col4" >6.4</td>
#       <td id="T_f11ab_row3_col5" class="data row3 col5" >45.1%</td>
#     </tr>
#     <tr>
#       <th id="T_f11ab_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_f11ab_row4_col0" class="data row4 col0" >Lindab</td>
#       <td id="T_f11ab_row4_col1" class="data row4 col1" >Mid Cap</td>
#       <td id="T_f11ab_row4_col2" class="data row4 col2" >LIAB</td>
#       <td id="T_f11ab_row4_col3" class="data row4 col3" >5.000000</td>
#       <td id="T_f11ab_row4_col4" class="data row4 col4" >4.1</td>
#       <td id="T_f11ab_row4_col5" class="data row4 col5" >29.1%</td>
#     </tr>
#     <tr>
#       <th id="T_f11ab_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_f11ab_row5_col0" class="data row5 col0" >Hanza</td>
#       <td id="T_f11ab_row5_col1" class="data row5 col1" >Small Cap</td>
#       <td id="T_f11ab_row5_col2" class="data row5 col2" >HANZA</td>
#       <td id="T_f11ab_row5_col3" class="data row5 col3" >6.000000</td>
#       <td id="T_f11ab_row5_col4" class="data row5 col4" >4.0</td>
#       <td id="T_f11ab_row5_col5" class="data row5 col5" >46.0%</td>
#     </tr>
#     <tr>
#       <th id="T_f11ab_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_f11ab_row6_col0" class="data row6 col0" >Sectra</td>
#       <td id="T_f11ab_row6_col1" class="data row6 col1" >Large Cap</td>
#       <td id="T_f11ab_row6_col2" class="data row6 col2" >SECT B</td>
#       <td id="T_f11ab_row6_col3" class="data row6 col3" >7.000000</td>
#       <td id="T_f11ab_row6_col4" class="data row6 col4" >4.8</td>
#       <td id="T_f11ab_row6_col5" class="data row6 col5" >37.9%</td>
#     </tr>
#     <tr>
#       <th id="T_f11ab_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_f11ab_row7_col0" class="data row7 col0" >Alcadon Group</td>
#       <td id="T_f11ab_row7_col1" class="data row7 col1" >First North</td>
#       <td id="T_f11ab_row7_col2" class="data row7 col2" >ALCA</td>
#       <td id="T_f11ab_row7_col3" class="data row7 col3" >8.000000</td>
#       <td id="T_f11ab_row7_col4" class="data row7 col4" >1.3</td>
#       <td id="T_f11ab_row7_col5" class="data row7 col5" >38.9%</td>
#     </tr>
#     <tr>
#       <th id="T_f11ab_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_f11ab_row8_col0" class="data row8 col0" >Nyfosa</td>
#       <td id="T_f11ab_row8_col1" class="data row8 col1" >Large Cap</td>
#       <td id="T_f11ab_row8_col2" class="data row8 col2" >NYF</td>
#       <td id="T_f11ab_row8_col3" class="data row8 col3" >9.000000</td>
#       <td id="T_f11ab_row8_col4" class="data row8 col4" >1.2</td>
#       <td id="T_f11ab_row8_col5" class="data row8 col5" >27.2%</td>
#     </tr>
#     <tr>
#       <th id="T_f11ab_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_f11ab_row9_col0" class="data row9 col0" >Thule</td>
#       <td id="T_f11ab_row9_col1" class="data row9 col1" >Large Cap</td>
#       <td id="T_f11ab_row9_col2" class="data row9 col2" >THULE</td>
#       <td id="T_f11ab_row9_col3" class="data row9 col3" >10.500000</td>
#       <td id="T_f11ab_row9_col4" class="data row9 col4" >5.8</td>
#       <td id="T_f11ab_row9_col5" class="data row9 col5" >27.7%</td>
#     </tr>
#     <tr>
#       <th id="T_f11ab_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_f11ab_row10_col0" class="data row10 col0" >Björn Borg</td>
#       <td id="T_f11ab_row10_col1" class="data row10 col1" >Small Cap</td>
#       <td id="T_f11ab_row10_col2" class="data row10 col2" >BORG</td>
#       <td id="T_f11ab_row10_col3" class="data row10 col3" >10.500000</td>
#       <td id="T_f11ab_row10_col4" class="data row10 col4" >3.2</td>
#       <td id="T_f11ab_row10_col5" class="data row10 col5" >36.7%</td>
#     </tr>
#     <tr>
#       <th id="T_f11ab_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_f11ab_row11_col0" class="data row11 col0" >Awardit</td>
#       <td id="T_f11ab_row11_col1" class="data row11 col1" >First North</td>
#       <td id="T_f11ab_row11_col2" class="data row11 col2" >AWRD</td>
#       <td id="T_f11ab_row11_

# %%
#### NEGATIVE RANKS

stocks = 20
## MOMENTUM ##
momentum = momentum_tmp[0:stocks]
Momentum = momentum[compact_mom]


## TRIPLE SORT ##
gestalt = gestalt_tmp[0:stocks]
gestalt = gestalt[compact]

neg_momentum = momentum_tmp.tail(stocks)[::-1][compact_mom]
neg_gestalt = gestalt_tmp.tail(stocks)[::-1][compact]

# %%
neg_momentum
# Out:
#                Company         List     Tick  Momentum Rank  EA ret std  \
# 120            Desenio  First North     DSNO          427.0   -3.629469
# 240            Kancera  First North      KAN          426.0   -4.734334
# 313       Oncopeptides      Mid Cap     ONCO          425.0   -0.731550
# 104            Climeon  First North  CLIME B          424.0   -1.587466
# 142      Enad Global 7  First North      EG7          423.0   -1.272416
# 347             Readly      Mid Cap     READ          422.0   -2.927363
# 434       Vimian Group  First North   VIMIAN          421.0   -2.185936
# 46              Azelio  First North   AZELIO          420.0   -0.782825
# 385        SpectraCure  First North     SPEC          419.0   -0.735108
# 121     Diamyd Medical  First North   DMYD B          418.0   -0.778326
# 146         Eolus Vind      Mid Cap   EOLU B          417.0   -2.319309
# 357            Saniona    Small Cap   SANION          416.0   -0.784732
# 167  Fingerprint Cards      Mid Cap   FING B          415.0   -3.392572
# 325         Physitrack  First North     PTRK          414.0   -0.537857
# 446            ZignSec  First North     ZIGN          413.0   -2.109148
# 117         Crunchfish  First North    CFISH          412.0   -2.849253
# 184           GomSpace  First North     GOMX          411.0   -2.273614
# 326       Pierce Group      Mid Cap   PIERCE          410.0   -2.331134
# 60           BHG Group    Large Cap      BHG          409.0   -4.398742
# 191    Hansa Biopharma      Mid Cap     HNSA          408.0   -0.862308
#
#      1 Year Volatility
# 120           0.931052
# 240           0.760562
# 313           2.006452
# 104           0.798432
# 142           0.739580
# 347           0.539057
# 434           0.487458
# 46            0.772498
# 385           0.998207
# 121           0.617148
# 146           0.500203
# 357           0.551978
# 167           0.734389
# 325           0.621084
# 446           0.559917
# 117           0.960145
# 184           0.650118
# 326           0.490174
# 60            0.426644
# 191           0.527858

# %%
neg_gestalt
# Out:
#                      Company         List      Tick  Gestalt Rank  \
# 340                  Q-Linea      Mid Cap    QLINEA         371.0
# 191          Hansa Biopharma      Mid Cap      HNSA         370.0
# 117               Crunchfish  First North     CFISH         369.0
# 240                  Kancera  First North       KAN         368.0
# 113            Cortus Energy  First North        CE         367.0
# 357                  Saniona    Small Cap    SANION         366.0
# 97               Cell Impact  First North      CI B         365.0
# 211                Immunovia      Mid Cap    IMMNOV         364.0
# 104                  Climeon  First North   CLIME B         363.0
# 362      Scandinavian Enviro  First North       SES         362.0
# 46                    Azelio  First North    AZELIO         361.0
# 444            Xspray Pharma      Mid Cap    XSPRAY         360.0
# 385              SpectraCure  First North      SPEC         359.0
# 445          Xvivo Perfusion      Mid Cap     XVIVO         358.0
# 69                   Biovica  First North  BIOVIC B         357.0
# 446                  ZignSec  First North      ZIGN         355.5
# 145               Enzymatica  First North      ENZY         355.5
# 316              OrganoClick  First North      ORGC         354.0
# 177                 Gapwaves  First North    GAPW B         353.0
# 89   Calliditas Therapeutics      Mid Cap     CALTX         352.0
#
#      Quality Rank  Value Rank  Momentum Rank  EA ret std  1 Year Volatility
# 340         365.0       348.0          358.0   -2.510544           0.427852
# 191         366.0       331.0          351.0   -0.862308           0.527858
# 117         346.0       363.5          335.0   -2.849253           0.960145
# 240         360.0       315.0          369.0   -4.734334           0.760562
# 113         371.0       365.0          298.0   -0.869394           0.817887
# 357         369.0       287.5          357.0   -0.784732           0.551978
# 97          336.0       360.0          301.5   -1.480502           0.767370
# 211         362.0       332.5          297.0   -0.358773           0.694951
# 104         355.0       267.0          365.5   -1.587466           0.798432
# 362         361.0       353.0          273.0   -0.084326           0.526077
# 46          337.0       293.0          353.0   -0.782825           0.772498
# 444         339.0       312.0          329.0   -0.198423           0.965850
# 385         317.0       316.0          346.0   -0.735108           0.998207
# 445         299.0       349.5          325.5   -1.437728           0.389108
# 69          340.5       343.0          285.5   -0.021311           0.583576
# 446         343.0       276.0          349.5   -2.109148           0.559917
# 145         281.0       349.5          338.0   -2.551911           0.580756
# 316         309.0       319.0          337.0   -1.166696           0.565395
# 177         335.0       344.0          280.0   -0.284474           0.462174
# 89          359.0       305.0          294.0    1.153951           0.621624
